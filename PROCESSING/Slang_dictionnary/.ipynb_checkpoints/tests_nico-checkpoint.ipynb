# %%
#packages
import pandas as pd
from tqdm import tqdm, tqdm_notebook
tqdm_notebook().pandas()
# Out:
# /var/folders/ll/9ks4sslj4hj9kg36pxlnc3xc0000gn/T/ipykernel_40184/82949107.py:4: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   tqdm_notebook().pandas()
# 0it [00:00, ?it/s]

# %%
#function to check if strin is contained and update dico
def isinside1(test_string,test_list):
    global dico
    res = [ele for ele in test_list if(ele in test_string)]
    #print(res)
    if res:
        for ele in res:
            i= test_list.index(ele)
            dico["occurences"].loc[i]= dico["occurences"].loc[i]+1
        return 1
    return 0

def isinside2(test_string,test_list):
    if any(ext in test_string for ext in test_list):
        return 1
    return 0

# %% [markdown]
# #function test (deprecated)
# a= isinside("au revoir",["salut","adieu"])
# a

# %%
#get dico
dico= pd.read_pickle("./Final_Dictionary.pkl")
dico["occurences"]=0
dico.head()
# Out:
#         word  occurences
# 0      Janky           0
# 1   slumpin'           0
# 2   yayeeyay           0
# 3  hard-core           0
# 4     brutal           0

# %%
#check strings lenths and describe dico
dico["strlen"]= dico["word"].apply(lambda x : len(x))
dico.describe()
# Out:
#        occurences        strlen
# count     20989.0  20989.000000
# mean          0.0      8.810520
# std           0.0      4.998863
# min           0.0      1.000000
# 25%           0.0      6.000000
# 50%           0.0      8.000000
# 75%           0.0     11.000000
# max           0.0    143.000000

# %%
#make list out of dico
dicolist= dico["word"].unique().tolist()
dicolist
# Out:
# ['Janky',
#  "slumpin'",
#  'yayeeyay',
#  'hard-core',
#  'brutal',
#  'ho-bag',
#  'Hazy',
#  'hork',
#  'hecka',
#  'hella',
#  'wet wagons',
#  'twomp',
#  'ducket',
#  'mad',
#  'A-hole',
#  'Ass Kisser',
#  'clap',
#  'cob',
#  'Dry hump',
#  'No Shit',
#  'puke',
#  'folks',
#  'holla',
#  'dog',
#  'raunchy',
#  'ENERGY',
#  'Toss salid',
#  'cassette',
#  'no way',
#  'raw',
#  '187',
#  'flower run',
#  'tofu',
#  'rim job',
#  'connected',
#  'riiiiiiight',
#  'tiiight',
#  'o.g.',
#  'panty',
#  'tweeks coffee',
#  'flipside',
#  'issues',
#  'whooped',
#  'hippy',
#  'tra la la',
#  'gaff tape',
#  'Lyons',
#  'talent',
#  'bounce',
#  'mind control',
#  'skilz',
#  'the game',
#  'player',
#  'shag',
#  'sweet',
#  'real men',
#  'watchers',
#  'warn',
#  'check',
#  'velcro',
#  'peeps',
#  'mah',
#  'Lets get started, shall we?',
#  'dealio',
#  'fits',
#  'Young',
#  'grill',
#  'scrilla',
#  'chedda',
#  'bank',
#  'blood',
#  'Intensity',
#  'flirt',
#  'B.A.F',
#  'dissed',
#  'Disco',
#  'fantabulous',
#  'prophylactic',
#  'guh',
#  'piscicles',
#  'Yen',
#  'yea',
#  'nincompoop',
#  'googlie',
#  'Real Women',
#  'iced-out',
#  'heezi',
#  'wiggle',
#  'wthn',
#  'sexiled',
#  'h2h',
#  'school',
#  'harlot',
#  'skivvies',
#  'bj',
#  'zone',
#  'Fully Cooked',
#  'funkadelic',
#  'Yuppie Food Stamps',
#  'boujouix',
#  'wai',
#  'la',
#  'inhtsa',
#  'craptacular',
#  'tap a kidney',
#  'squishy scale',
#  'big V',
#  '20',
#  'FUG',
#  'OOC',
#  'pinch a loaf',
#  'jump my bones',
#  'to get fresh with',
#  "o'dark hundred",
#  'East Jesus',
#  'all aces',
#  'unfadeable',
#  'legit',
#  'tail',
#  'wodie',
#  'beef',
#  'aightee',
#  'misspelt',
#  'deprecated',
#  '404',
#  'junk',
#  '25/8',
#  'riff-raff',
#  'achey-fakey',
#  'drumsteer',
#  'deep sex',
#  'bizznatch',
#  'scratchies',
#  "ruttin'",
#  'Gross Domestic Product',
#  'PEBCAK',
#  'BFD',
#  'zoom out',
#  'cack',
#  'money shot',
#  'strike',
#  'oodee',
#  'sorbet porn',
#  'clams',
#  'the curse',
#  'shamrock',
#  'high-tailin',
#  'lingam',
#  'yoni',
#  'mwagala',
#  'BYOC',
#  'rooted',
#  'wind in your leg',
#  'ish',
#  'walk of shame',
#  'on the level',
#  'pine',
#  'hurt',
#  'Dip Shit',
#  'Are you on crack?',
#  'Hit up',
#  'units',
#  'Gaff',
#  'brilliant',
#  'Hoopdashit',
#  'Good people',
#  'Pile of bricks',
#  'Hot as balls',
#  'Bitch switch',
#  'doofus',
#  'BYOB',
#  'me-time',
#  'choneys',
#  'dumpster diving',
#  'boxing',
#  'baloney',
#  'dig it',
#  'Reach Around',
#  'slide',
#  'whateves',
#  'sacto',
#  'Nottie',
#  'take one for the team',
#  'Ricockulous',
#  'Sellout',
#  'devirginizer',
#  'Sloppy Grandma',
#  'Umpa Lumpa',
#  'Idioteque',
#  'mouthasized',
#  'tenacious',
#  'Da Shits',
#  'Fuck on',
#  'bleavage',
#  'nasdawg',
#  'sick ass',
#  'Bippy-Twat',
#  'Scam',
#  'dropping V',
#  'chillaxin',
#  'nummy',
#  'Cutty',
#  'wiggedy-wiggedy-whacked',
#  'fungry',
#  'large',
#  'sketch',
#  'MPSI',
#  'serpentile',
#  'Flip a Bitch',
#  'Duce',
#  'POS',
#  'DPOC',
#  'moofie face',
#  'Snap!',
#  'home space',
#  'sick',
#  'chop it up',
#  'mofo',
#  'ass',
#  'berburder',
#  'boondocks',
#  'off the hook',
#  'bad times',
#  'ret',
#  'suck a duck',
#  'crib',
#  'pad',
#  'good deal',
#  'maintaining',
#  'trifling',
#  'kludge',
#  'boo',
#  'AIM',
#  'luser',
#  'AGP',
#  'substract',
#  'trappa',
#  'pudchizzer',
#  'Hot Diggity Dank',
#  'freak-out',
#  'schlep',
#  'bootsy',
#  'Clean The House',
#  'ghetto',
#  'PPP',
#  'moded',
#  'coolness',
#  'Scrimp',
#  'Buzzing The Tower',
#  'Divy',
#  'relationship porn',
#  'Mistake Daily',
#  'Fugly',
#  'squeeze',
#  'slump',
#  'penix',
#  'fucked',
#  'whacked',
#  'vampirela',
#  'tab',
#  'Dislexus',
#  'Lickity',
#  'cust',
#  'broken',
#  'whack',
#  'wank',
#  'bullshit',
#  'bork',
#  'pr0n',
#  'backshot',
#  'Vanish!',
#  'mush',
#  'samich',
#  'plur',
#  'lame',
#  'punani',
#  'Pfft',
#  'ugmo',
#  'asl',
#  'screwed',
#  'piss',
#  'pissed',
#  'bloke',
#  'scat',
#  'YAY!',
#  'clacker',
#  'Telstra monkeys',
#  'pepper',
#  'Dutch oven',
#  'Dutch football',
#  'MDMA',
#  'bah',
#  'classic',
#  'booya',
#  'Alcamahol',
#  'microcave',
#  'smoked',
#  'bitchin',
#  'ripped',
#  'Muffandankles',
#  'huge ass',
#  'loads',
#  'gobs',
#  'wail',
#  'HHGTTG',
#  'groovy',
#  'slick',
#  'One Eyed Willy',
#  'hinie',
#  'bootay',
#  'phuck',
#  'mightymouse',
#  'Knocked Up',
#  'IRC Chick',
#  'shiznay',
#  'digestive',
#  'the bomb',
#  'the man',
#  'dime sack',
#  'The Dog',
#  'skanky',
#  'loved up',
#  'Advanced Power Management (APM)',
#  'bersquillionpajillion',
#  'drongo',
#  'mate',
#  'heels',
#  'j/p',
#  'diu',
#  'lei',
#  'Chow',
#  'pat pat',
#  'moshi moshi',
#  'Fay gay',
#  'windows update',
#  'full of it',
#  'booty',
#  'coolio',
#  'Crapr',
#  'super tow truck',
#  'crimp',
#  'zerbert',
#  'pikachu',
#  'chimporchina',
#  "That's a good point",
#  'rogerthat',
#  'hoo hoos',
#  'chancre',
#  'smegma',
#  'spiffy',
#  'stoked',
#  'glass-plans',
#  'strapped',
#  'pussy',
#  'bump uglies',
#  'sex',
#  'backend',
#  'j/k',
#  'right on',
#  'courts',
#  'all over it',
#  'over it',
#  'tragic',
#  'making babies',
#  'smeg',
#  'tscrap',
#  'no no',
#  'green',
#  'good call',
#  'Tight',
#  "map o' Tassie",
#  'smurf',
#  'Yo!',
#  'DoS',
#  'phwoar',
#  'IRC',
#  'clueless newbie',
#  'selecta',
#  'spraff',
#  'lusers',
#  'flip the skins',
#  'inout',
#  'grouse',
#  'r0x',
#  'blows',
#  'Alchamahol',
#  'bush pig',
#  'slizzy',
#  'snog',
#  'nice shoes! Wanna fuck?',
#  'my ass',
#  'doubt-it',
#  'scooter',
#  'hump',
#  'benny',
#  'slutting it up',
#  'fantasterrific',
#  'bgs',
#  'goon',
#  'plonc',
#  'dhj',
#  'DVDA',
#  'fb',
#  'FUD',
#  'carnie',
#  'JC',
#  'Doh',
#  'fundie',
#  'butterhead',
#  'scuba-ing',
#  'stupid as shit',
#  'McMansion',
#  'scando',
#  'Tap dat Ass',
#  'chat it up',
#  "rockin'",
#  'tukus',
#  'remotate',
#  'shiznit',
#  'cool cool',
#  'deever',
#  'script kiddie',
#  'KIT',
#  'BFF',
#  'negative feature',
#  'punkin',
#  'gimongous',
#  'ginormous',
#  'fridge',
#  'the 101',
#  'Qui-Gon Jin',
#  'vuhjungle',
#  'gimmickry',
#  'Weaksauce',
#  'Sacs',
#  'flip a bit',
#  'Bitch',
#  'Wild Eep!',
#  'chubby',
#  'not bitch',
#  'shotgun',
#  "poopin' around",
#  'back in the day',
#  'get off',
#  'Gurpin',
#  'WD55',
#  'Goteam',
#  'carpet licker',
#  'absofuckinlutely',
#  'bever',
#  'blue balls',
#  'cock block',
#  'S.O.',
#  'drop the kids off at the pool',
#  'skitzing',
#  'Poontang',
#  "fuckin' A",
#  'nerd box',
#  'bling bling',
#  'Name Dropper',
#  'hoodie',
#  'Hoodie Theory',
#  'fo sho',
#  'audi',
#  'one time',
#  'put it to bed',
#  'near tears',
#  'peachy keen',
#  'superpope',
#  'nippley',
#  'veto',
#  'foolio',
#  'grub',
#  "grubbin'",
#  'b-ball',
#  'props',
#  'dark times',
#  'oh shit handle',
#  'cum',
#  'spooge',
#  'key',
#  'Fatty',
#  'smoke a pole',
#  'headlights on',
#  'old school',
#  'suckus',
#  'head',
#  'chuffed',
#  "big facin'",
#  'blow up',
#  'thwop',
#  'second feeding',
#  'scandalous',
#  'bacchanalia',
#  'phallic',
#  'the bird',
#  'hotansawa soup',
#  'the book',
#  'pee pee',
#  'baby-speak',
#  'Chuff Monkey!',
#  'Knob Jockey',
#  'Chunt',
#  'Quim',
#  'Spam Javelin',
#  'Flange/flanging',
#  'Spam Hatch',
#  'jump on it',
#  'dope',
#  'reefer',
#  'weed',
#  'ganja',
#  'peace pipe',
#  'toke',
#  'bong',
#  'buzzed',
#  'light-weight',
#  'hit',
#  'joint',
#  'doobie',
#  'Blass',
#  'Gerkin',
#  'Foodog',
#  'Uni-Ball',
#  'aie',
#  'nekked',
#  "stylin'",
#  'workee',
#  'Mack Daddy',
#  'mac',
#  'mac daddy',
#  'pimp',
#  'token black',
#  'left nut',
#  'right nut',
#  'just-got-fucked hair',
#  'play',
#  'Ownage',
#  'do you',
#  'coucher',
#  'unbeweavable',
#  'the rag',
#  'Lan Kwai Fong',
#  'rack',
#  'ability',
#  'CRS',
#  'skin flute',
#  'scratch',
#  'yatta',
#  'snow',
#  'my boys',
#  'I feel you',
#  'in',
#  'badness',
#  'chick',
#  'biff',
#  'turd cutter',
#  'cop out',
#  'present haunches',
#  'pop punk',
#  '.3',
#  'Pop Rocks',
#  'ButtHurt',
#  'Shibby!',
#  'woohoo an shit',
#  'Vin',
#  'V&L',
#  'guzzler',
#  'SnowBall',
#  'Sac',
#  'get it on',
#  'tripping',
#  'Dord',
#  'gank',
#  'Lift',
#  'gaydar',
#  'weirdo-meter',
#  'solid',
#  'frenetic',
#  'Tweaknut',
#  'Absolute',
#  'Hi Mom!',
#  'big ups',
#  'gangsta',
#  'transput',
#  'com-mitment',
#  'grimy',
#  'dong',
#  'drugfiend',
#  'AMF',
#  'piece',
#  'quarter water',
#  'half-woke',
#  'bombed',
#  'wasted',
#  'rear ended',
#  'hold up',
#  'TB',
#  'all about',
#  'evil',
#  'slobbernock',
#  'scoop',
#  'IM',
#  'jacked',
#  'log hound',
#  'sloshed',
#  'poop',
#  'Rammed',
#  'inthehood',
#  'badow',
#  'biznit',
#  'WPP',
#  'bizzle',
#  'Dreadford',
#  'geil',
#  'My nigga',
#  'clean',
#  'Boons',
#  'more better',
#  'swamp donkey',
#  'boogawoof',
#  'cake',
#  'killer',
#  'lurch',
#  'running pockets',
#  'vault',
#  'ralph',
#  'queaf',
#  'twisted',
#  'point',
#  '420',
#  'Chaa',
#  'damn skippy',
#  'fuck buddy',
#  'homofag',
#  'post',
#  'coin',
#  'bad news bears',
#  "sleepin'",
#  'stay',
#  'teabagging',
#  'skid mark',
#  'Chill Pill',
#  'Chnaa',
#  'titties',
#  'assbandit',
#  'fuckstick',
#  'cuntbucket',
#  'mobile homes',
#  'run',
#  'ya-meen',
#  'ten',
#  'litso',
#  'horrorshow',
#  'viddy',
#  'glazzies',
#  'slovo',
#  'rot',
#  'slooshy',
#  'addy',
#  'skinky',
#  'dentist guitar',
#  'howly',
#  'Ghetto Birds',
#  'swine',
#  'goshed',
#  'playa',
#  'yieogie',
#  'Wavlato',
#  'bootinize',
#  'bootinization',
#  'schway',
#  'near beer',
#  "d'oh",
#  'Beatbagging',
#  'Googling',
#  'delouse',
#  'Fartknocker',
#  'Four-ass',
#  'Fuckarini',
#  'Fuckfoot',
#  'DD',
#  'LTR',
#  'booty call',
#  'bump-in',
#  'craptastic',
#  'ricockulous',
#  'shady',
#  'shoddy',
#  'sheist/ sheisty',
#  'nummers',
#  'graze',
#  'RSN',
#  'jack off',
#  'twat',
#  'cum slut',
#  'Thong',
#  'paint eating monkey',
#  'automagically',
#  'log watcher',
#  'mixfused',
#  'lallergies',
#  'cyber',
#  'Iterate',
#  'can',
#  'pot',
#  'Hey Mister',
#  'boobie faker',
#  'ficky-fick',
#  'tanks',
#  'shagadelic',
#  'butt token',
#  'signage',
#  'arse',
#  'preslammed',
#  'domain snob',
#  'ultra-buzz',
#  'boob tube',
#  'idiot box',
#  'couch potato',
#  'whoopee',
#  'chronic',
#  'lot lizzard',
#  'man whore',
#  "'tard",
#  'postal',
#  'nerd',
#  'SOC',
#  'zoned',
#  'suburban forty',
#  'Square-Go',
#  'Frienemy',
#  'Toxic',
#  'dilly',
#  'PCD',
#  'Huzmo',
#  'UPI',
#  'ACS',
#  'destroy',
#  'tffs',
#  'circumvent',
#  'flabbergasted',
#  'coffee',
#  'poo chute',
#  'arse reamer',
#  'chocolate freeway',
#  'arse jammer',
#  'spandulick',
#  'Pillock',
#  'Naff',
#  'whuff the vape',
#  'doggy style',
#  'genis',
#  'Jarjazz',
#  'singles club',
#  'Blitch',
#  'kick it',
#  'the shit',
#  'pippie',
#  'wunning',
#  'car hummer',
#  'gf',
#  'woodie',
#  'barf',
#  'hurl',
#  'dilligaf',
#  'cluster fuck',
#  'damfino',
#  'FWB',
#  'thankee',
#  'format music',
#  'Rushmore',
#  'comeback',
#  'five by five',
#  'boink',
#  'bf',
#  'fuck fest',
#  'sex stain',
#  'DINS',
#  'minger',
#  'study liar',
#  'tang',
#  'huevos',
#  'robo-trip',
#  'rice rocket',
#  'pooning',
#  'freak hole',
#  'whack job',
#  'music pimp',
#  'getting it on',
#  'doing it',
#  'superfine',
#  'difficulty',
#  'times ten',
#  'dick around',
#  'Hizzy',
#  'Freeballin',
#  'Going Commando',
#  'Gat',
#  'Feces',
#  'Puss',
#  'Bum',
#  'kp',
#  'funk',
#  'bummed',
#  'CLM: Career Limiting Move',
#  'thick',
#  'Stacked',
#  'Sleep',
#  'Ginormous',
#  'Rear Jockey',
#  'kill a kitten',
#  'score',
#  'A+',
#  'AM',
#  'digging',
#  'moxy',
#  'dun dee',
#  'Mac-10',
#  'nine',
#  'dickpirillo',
#  'disco nap',
#  'suicide bomber',
#  'boobage',
#  'camel-toe',
#  'foody',
#  '69',
#  'game',
#  'ketchup sandwich',
#  'mayonaise sandwich',
#  'Muff',
#  'Muff Diving',
#  'Hot Shit',
#  'water sports',
#  'Counter Monkey',
#  'posh',
#  'tosser',
#  'poofter',
#  'frankenraver',
#  'adultery',
#  'Krod',
#  'jizz mopper',
#  'recockulous',
#  'keg stand',
#  'mug',
#  'shoot the one',
#  'disfumbled',
#  'HOT',
#  'eggs',
#  'tripod',
#  'crack-in-a-can',
#  '5-0',
#  'lopey',
#  'quantum dating',
#  'jumble sheek',
#  'o face',
#  'balloon knot',
#  'tumbleweed',
#  'shrizzo',
#  'balloon',
#  'fuzz',
#  'heat',
#  'fuck buddie',
#  'hooey',
#  'leg',
#  'op',
#  'kickass',
#  'assful',
#  'stepping',
#  'president',
#  'word that',
#  'baldie',
#  'thingy',
#  'whatta loser!',
#  'err',
#  'skirt alert',
#  'putzel',
#  'Peepster',
#  "P'diddle",
#  'Booty Raunch',
#  'Splooey',
#  'Bumjug',
#  'move your ass',
#  'bonehead',
#  'booger sugar',
#  'shiznito bim-bam snip snap sack',
#  'ROFLMGDMFSOBAO',
#  'taxed',
#  'Fart pipe',
#  'Fob',
#  'bufo',
#  'flossin',
#  'R/C car',
#  'benz',
#  'boss',
#  'pimpmobile',
#  'kewl',
#  'drifter',
#  'SOL',
#  'chasin skirt',
#  'shat',
#  'Pillick',
#  'ampidirtuous',
#  'twapper',
#  'outrageous',
#  'PB',
#  'ass cowboy',
#  'smash',
#  'science class',
#  'spunk',
#  'six shooter',
#  'time warp',
#  'awesomeicle',
#  'Krazy Sauce',
#  'sour pants',
#  'eh',
#  'vet',
#  'swiggy',
#  'Skulls',
#  'bones',
#  'funda',
#  'bufu',
#  'bobo',
#  'jibber jabber',
#  'spoot',
#  'dingus',
#  'cunnilingus',
#  'Darn',
#  'castrated',
#  'foo',
#  'bag',
#  'epididymis',
#  'bukkake',
#  'throw down',
#  'todger',
#  'arsewipe',
#  'Meh',
#  'rere',
#  'acine it',
#  'camel toe syndrome',
#  'snafu',
#  'stupid',
#  'tosspot',
#  'window licker',
#  'foot hag',
#  'thrush',
#  'nifkin',
#  'grass',
#  'hung like a horse',
#  'Dance Dance Revolution',
#  'DDR',
#  'Pump it Up',
#  'PIU',
#  '1337',
#  'Isopropyl',
#  'Ford',
#  'tweet',
#  'pigeon',
#  'pissbutt',
#  'buttfuck',
#  'toss salad',
#  'throwed',
#  'ghett',
#  'road head',
#  'West Bumblefuck',
#  'spliff',
#  'sex fight',
#  'sex fighter',
#  'snooby',
#  'granola',
#  'pumpy',
#  'feck',
#  'homeslice',
#  'death',
#  'Ricer',
#  'ABC',
#  'Nut',
#  'toungage',
#  'biscuteeran',
#  'Oh, my back!',
#  'untouchable',
#  'zero',
#  'peroxide abuser',
#  'lan party',
#  'sped',
#  'kosher',
#  "Don't Hate",
#  'Shorty',
#  'Skeezer',
#  'Baby Daddy',
#  'Playa Hata',
#  'sup yo',
#  'tappinass',
#  'Tappinass',
#  'pusois',
#  'taint',
#  'Wanker',
#  'boodissey',
#  'funna',
#  'aah-ite',
#  ...]

# %% [markdown]
# #testing with list
# b= isinside("Janky slumpin janky slumpin",dicolist)
# b
# dico.describe()

# %%
#importing dataset sample
df= pd.read_json("/Users/nicolasantacroce/Desktop/Desktop/EPFL/EPFL MA1/Applied Data Analysis/Sample.json.bz2",compression="bz2",lines=True)

# %%
df.head()
# Out:
#              quoteID                                          quotation  \
# 0  2015-11-11-109291  They'll call me lots of different things. Libe...
# 1  2015-11-04-105046                     The choices are not that easy,
# 2  2015-09-11-070666  It's kind of the same way it's been with the R...
# 3  2015-01-12-082489  We're now going back to the frozen tundra, and...
# 4  2015-11-09-033345  I had a chuckle: They were showing a video of ...
#
#              speaker                  qids                date  \
# 0     Chris Christie              [Q63879] 2015-11-11 00:55:12
# 1           Dr. John  [Q511074, Q54593093] 2015-11-04 18:13:06
# 2    Niklas Kronwall             [Q722939] 2015-09-11 19:54:00
# 3  Frances McDormand             [Q204299] 2015-01-12 01:40:00
# 4        Kris Draper             [Q948695] 2015-11-09 00:57:45
#
#    numOccurrences                                             probas  \
# 0               1  [[Chris Christie, 0.7395], [Bobby Jindal, 0.15...
# 1               2               [[Dr. John, 0.5531], [None, 0.4469]]
# 2               1  [[Niklas Kronwall, 0.7119], [None, 0.2067], [H...
# 3               3  [[Frances McDormand, 0.484], [None, 0.4495], [...
# 4               3  [[Kris Draper, 0.8782], [None, 0.1043], [Serge...
#
#                                                 urls phase
# 0  [http://thehill.com/blogs/ballot-box/259760-ch...     E
# 1  [http://delawareonline.com/story/news/health/2...     E
# 2  [http://redwings.nhl.com/club/news.htm?id=7787...     E
# 3  [http://feeds.people.com/~r/people/headlines/~...     E
# 4  [http://ca.rd.yahoo.com/sports/rss/nfl/SIG=13u...     E

# %% [markdown]
# c= isinside(df["quotation"].loc[1],dicolist)
# c

# %%
#separating quotes (really long so we try it on the first 10000)
df2= df.loc[0:9999]
df2["colloquial"]= df2["quotation"].progress_apply(lambda x : isinside1(x,dicolist))
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]
# /var/folders/ll/9ks4sslj4hj9kg36pxlnc3xc0000gn/T/ipykernel_40184/3222688001.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["colloquial"]= df2["quotation"].progress_apply(lambda x : isinside(x,dicolist))

# %%
df2.describe()
# Out:
#        numOccurrences  colloquial
# count    10000.000000  10000.0000
# mean         3.260400      0.9999
# std         18.155279      0.0100
# min          1.000000      0.0000
# 25%          1.000000      1.0000
# 50%          1.000000      1.0000
# 75%          2.000000      1.0000
# max       1125.000000      1.0000

# %%
#removing words present in more than 1% of quotes
tresh= 0.01
dico["occurence_fraction"]= dico["occurences"]/dico["occurences"].count()
dico.describe()
# Out:
#          occurences        strlen  occurence_fraction
# count  20989.000000  20989.000000        20989.000000
# mean      12.059317      8.810520            0.000575
# std      185.234902      4.998863            0.008825
# min        0.000000      1.000000            0.000000
# 25%        0.000000      6.000000            0.000000
# 50%        0.000000      8.000000            0.000000
# 75%        0.000000     11.000000            0.000000
# max     9928.000000    143.000000            0.473010

# %%
#creating new dictionary without most occuring words
dico2= dico[dico["occurence_fraction"]<tresh]
dicolist2= dico2["word"].unique().tolist()
dico2.describe()
# Out:
#          occurences        strlen  occurence_fraction
# count  20807.000000  20807.000000        20807.000000
# mean       1.984140      8.860960            0.000095
# std       12.976422      4.990363            0.000618
# min        0.000000      1.000000            0.000000
# 25%        0.000000      6.000000            0.000000
# 50%        0.000000      8.000000            0.000000
# 75%        0.000000     11.000000            0.000000
# max      208.000000    143.000000            0.009910

# %%
#re-evaluating quotes with reduced dictionary
df2["colloquial"]= df2["quotation"].progress_apply(lambda x : isinside2(x,dicolist2))
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]
# /var/folders/ll/9ks4sslj4hj9kg36pxlnc3xc0000gn/T/ipykernel_40184/1222409005.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["colloquial"]= df2["quotation"].progress_apply(lambda x : isinside2(x,dicolist2))

# %%
df2.describe()
# Out:
#        numOccurrences    colloquial
# count    10000.000000  10000.000000
# mean         3.260400      0.890600
# std         18.155279      0.312156
# min          1.000000      0.000000
# 25%          1.000000      1.000000
# 50%          1.000000      1.000000
# 75%          2.000000      1.000000
# max       1125.000000      1.000000
