# %% [markdown]
# # Retrieve metadata about speakers

# %% [markdown]
# This notebook is dedicated to the retrieve of the speakers metadata. First, it uses the parquet file that was provided to retrieve extra-information (occupation, date of birth, gender, religion) on speakers.

# %% [markdown]
# ## Using provided parquet file

# %% [markdown]
# Pandas requires pyarrow to read parquet files, which can be installed using conda install pyarrow -c conda-forge.
# You can load this file as a pandas dataframe using df = pd.read_parquet(<path_to_file>).

# %% [raw]
# Schema of parquet file :
#
#     Schema:
#  |-- aliases: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- date_of_birth: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- nationality: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- gender: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- lastrevid: long (nullable = true)
#  |-- ethnic_group: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- US_congress_bio_ID: string (nullable = true)
#  |-- occupation: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- party: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- academic_degree: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- id: string (nullable = true)
#  |-- label: string (nullable = true)
#  |-- candidacy: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- type: string (nullable = true)
#  |-- religion: array (nullable = true)
#  |    |-- element: string (containsNull = true)

# %%
#importing the required modules
import seaborn as sns
from IPython.display import display, HTML
import matplotlib.pyplot as plt
import scipy.stats as stats
import pandas as pd
import numpy as np
import seaborn as sns

# %%
# Small adjustments to default style of plots, making sure it's readable and colorblind-friendly everywhere
plt.style.use('seaborn-colorblind')
plt.rcParams.update({'font.size' : 12.5,
                     'figure.figsize':(10,7)})

# %% [markdown]
# ### Import data

# %%
#Define the path for folder containing data
#TO BE MODIFIED ACCORDING HIS OWN FOLER containing data in local
path = '../ADA_project_data/'
df_metadata = pd.read_parquet(path+'speaker_attributes.parquet')
df_metadata.head()
# Out:
#   aliases date_of_birth nationality      gender   lastrevid ethnic_group  \
# 0    None          None        None  [Q6581097]   985453603         None
# 1    None          None     [Q9903]  [Q6581097]  1008699604         None
# 2    None          None     [Q9903]  [Q6581097]  1008699709         None
# 3    None          None     [Q9903]  [Q6581097]  1008699728         None
# 4    None          None     [Q9683]  [Q6581097]   985261661         None
#
#   US_congress_bio_ID occupation party academic_degree         id      label  \
# 0               None       None  None            None  Q45441526    Cui Yan
# 1               None       None  None            None  Q45441555   Guo Ziyi
# 2               None       None  None            None  Q45441562  Wan Zikui
# 3               None       None  None            None  Q45441563    Lin Pei
# 4               None       None  None            None  Q45441565  Guan Zhen
#
#   candidacy  type religion
# 0      None  item     None
# 1      None  item     None
# 2      None  item     None
# 3      None  item     None
# 4      None  item     None

# %%
#Import the dataset sample
path = '../ADA_project_data/'
df_sample = pd.read_json(path+'Sample.json.bz2',compression = 'bz2',lines = True)
df_sample.head()
# Out:
#              quoteID                                          quotation  \
# 0  2015-11-11-109291  They'll call me lots of different things. Libe...
# 1  2015-11-04-105046                     The choices are not that easy,
# 2  2015-09-11-070666  It's kind of the same way it's been with the R...
# 3  2015-01-12-082489  We're now going back to the frozen tundra, and...
# 4  2015-11-09-033345  I had a chuckle: They were showing a video of ...
#
#              speaker                  qids                date  \
# 0     Chris Christie              [Q63879] 2015-11-11 00:55:12
# 1           Dr. John  [Q511074, Q54593093] 2015-11-04 18:13:06
# 2    Niklas Kronwall             [Q722939] 2015-09-11 19:54:00
# 3  Frances McDormand             [Q204299] 2015-01-12 01:40:00
# 4        Kris Draper             [Q948695] 2015-11-09 00:57:45
#
#    numOccurrences                                             probas  \
# 0               1  [[Chris Christie, 0.7395], [Bobby Jindal, 0.15...
# 1               2               [[Dr. John, 0.5531], [None, 0.4469]]
# 2               1  [[Niklas Kronwall, 0.7119], [None, 0.2067], [H...
# 3               3  [[Frances McDormand, 0.484], [None, 0.4495], [...
# 4               3  [[Kris Draper, 0.8782], [None, 0.1043], [Serge...
#
#                                                 urls phase
# 0  [http://thehill.com/blogs/ballot-box/259760-ch...     E
# 1  [http://delawareonline.com/story/news/health/2...     E
# 2  [http://redwings.nhl.com/club/news.htm?id=7787...     E
# 3  [http://feeds.people.com/~r/people/headlines/~...     E
# 4  [http://ca.rd.yahoo.com/sports/rss/nfl/SIG=13u...     E

# %% [markdown]
# ### How to tranlate items into meanings name ?

# %% [markdown]
# Understanding items
# Items and their data are interconnected
#
# In Wikidata, items are used to represent all the things in human knowledge, including topics, concepts, and objects. For example, the "1988 Summer Olympics", "love", "Elvis Presley", and "gorilla" are all items in Wikidata.

# %% [markdown]
# #### Importing the sample to join metadata with quotations :

# %% [markdown]
# Join quotations data with metadata :

# %%
#Create sub-sample to group the same authors togethers
df_sub = df_sample.sample(int(5*10e3))
s1 = len(df_sub)

#For the moment, choose rows which at minimum 1 qid associated
#Remove this row when using the data that have been wrangled
df_sub = df_sub[[len(a)>0 for a in df_sub['qids']]]

s2 = len(df_sub)

print('There is {} % of rows that have no qid associated with'.format((1-s2/s1)*100))
df_sub['qid_unique'] = df_sub['qids'].apply(lambda x: x[0]) 
df_sub['qid_unique']
# Out:
# There is 34.424 % of rows that have no qid associated with
# 913958       Q728063
# 145250      Q1194856
# 1245292    Q30015089
# 709231     Q12150206
# 445402     Q52435478
#              ...
# 513342      Q7324127
# 810869      Q4716898
# 1186579     Q2349264
# 228595           Q76
# 467213     Q11894442
# Name: qid_unique, Length: 32788, dtype: object

# %%
#Group quotation by speaker

df_grouped=df_sub.groupby('qid_unique') \
['quoteID'] \
.count() \
.reset_index(name='count') \
.sort_values(['count'], ascending=False) 

df_grouped.head(20)

#Interesting to note that there is the same speaker called the by different ways (e.g : Donald Trump and President Trump)

#for speaker, quotation in df_group:
#    print('Speaker : ', speaker)
#    print('Quotations', quotation)
# Out:
#       qid_unique  count
# 8581      Q22686    377
# 22011        Q76     77
# 13169    Q359442     59
# 262        Q1058     57
# 14654    Q450675     53
# 19800      Q6294     48
# 19763      Q6279     43
# 685       Q11673     40
# 14382    Q434706     36
# 22637     Q83106     35
# 14792    Q457786     33
# 14424     Q43723     32
# 13777     Q39259     31
# 22535     Q79983     30
# 15215    Q473239     28
# 15811   Q4911497     28
# 5516     Q180589     27
# 13566    Q380900     27
# 12377    Q324546     26
# 1278    Q1286476     25

# %%
#Merging with metadata

#df_merged = df_group.merge(df,how='inner',on='speaker',right_on='label')
df_merged = df_grouped.merge(df_metadata,how='inner',left_on='qid_unique', right_on='id')\.sort_values(['count'], ascending=False)
df_merged.head(10)
# Out:
#   qid_unique  count                                            aliases  \
# 0        Q76     77  [Barack Hussein Obama II, Barack Obama II, Bar...
# 1    Q359442     59                                  [Bernard Sanders]
# 2    Q450675     53  [Jorge Mario Bergoglio, Francisco, Pope Franci...
# 3      Q6294     48  [Hillary Rodham Clinton, Hillary Rodham, Hilla...
# 4     Q11673     40                                [Andrew Mark Cuomo]
# 5    Q434706     36  [Elizabeth Ann Warren, Senator Warren, Elisabe...
# 6    Q457786     33  [Rodrigo Roa Duterte, Rodrigo "Rody" Roa Duter...
# 7     Q43723     32  [Binyamin Netanyahu, Bibi, Bibi Netanyahu, Ben...
# 8    Q473239     28  [Michael Richard "Mike" Pompeo, Michael Richar...
# 9    Q180589     27  [Boris, Alexander Boris de Pfeffel Johnson, Bo...
#
#              date_of_birth   nationality      gender   lastrevid  \
# 0  [+1961-08-04T00:00:00Z]         [Q30]  [Q6581097]  1395141963
# 1  [+1941-09-08T00:00:00Z]         [Q30]  [Q6581097]  1392561607
# 2  [+1936-12-17T00:00:00Z]  [Q237, Q414]  [Q6581097]  1396054797
# 3  [+1947-10-26T00:00:00Z]         [Q30]  [Q6581072]  1393846565
# 4  [+1957-12-06T00:00:00Z]         [Q30]  [Q6581097]  1393197828
# 5  [+1949-06-22T00:00:00Z]         [Q30]  [Q6581072]  1394365746
# 6  [+1945-03-28T00:00:00Z]        [Q928]  [Q6581097]  1348817804
# 7  [+1949-10-21T00:00:00Z]        [Q801]  [Q6581097]  1391756559
# 8  [+1963-12-30T00:00:00Z]         [Q30]  [Q6581097]  1393216542
# 9  [+1964-06-19T00:00:00Z]   [Q30, Q145]  [Q6581097]  1395092363
#
#                               ethnic_group US_congress_bio_ID  \
# 0  [Q49085, Q6935055, Q12826303, Q6392846]            O000167
# 1                                  [Q7325]            S000033
# 2                               [Q1056744]               None
# 3                                     None            C001041
# 4                                [Q974693]               None
# 5                                 [Q49078]            W000817
# 6                               [Q1290600]               None
# 7                                  [Q7325]               None
# 8                                     None            P000602
# 9                               [Q7994501]               None
#
#                                           occupation  \
# 0    [Q82955, Q40348, Q15958642, Q28532974, Q372436]
# 1  [Q82955, Q1930187, Q154549, Q1622272, Q36180, ...
# 2  [Q63173086, Q593644, Q104050302, Q36180, Q1234...
# 3  [Q82955, Q40348, Q193391, Q36180, Q18814623, Q...
# 4                                   [Q40348, Q82955]
# 5  [Q185351, Q82955, Q37226, Q1622272, Q40348, Q1...
# 6                                           [Q82955]
# 7  [Q82955, Q193391, Q372436, Q47064, Q15958642, ...
# 8        [Q40348, Q43845, Q2961975, Q189290, Q82955]
# 9  [Q1930187, Q82955, Q1607826, Q36180, Q11774202...
#
#                                           party       academic_degree  \
# 0                                      [Q29552]  [Q1765120, Q1540185]
# 1  [Q6542163, Q29552, Q327591, Q327591, Q29552]            [Q1765120]
# 2                                          None            [Q1233889]
# 3                              [Q29552, Q29468]   [Q163727, Q1540185]
# 4                                      [Q29552]            [Q1540185]
# 5                                      [Q29552]   [Q163727, Q1540185]
# 6                                    [Q7140531]                  None
# 7                                     [Q187009]    [Q787674, Q950900]
# 8                                      [Q29468]                  None
# 9                                       [Q9626]                  None
#
#         id               label  \
# 0      Q76        Barack Obama
# 1  Q359442      Bernie Sanders
# 2  Q450675             Francis
# 3    Q6294     Hillary Clinton
# 4   Q11673        Andrew Cuomo
# 5  Q434706    Elizabeth Warren
# 6  Q457786     Rodrigo Duterte
# 7   Q43723  Benjamin Netanyahu
# 8  Q473239         Mike Pompeo
# 9  Q180589       Boris Johnson
#
#                                            candidacy  type  \
# 0  [Q3586671, Q45578, Q4226, Q4791768, Q17067714,...  item
# 1                                               None  item
# 2                                               None  item
# 3                                [Q699872, Q4791768]  item
# 4                             [Q22023432, Q65047185]  item
# 5                                        [Q28220813]  item
# 6                                               None  item
# 7                     [Q2917048, Q2480394, Q2689039]  item
# 8                                               None  item
# 9  [Q30173038, Q30325756, Q428598, Q590740, Q3586...  item
#
#                                religion
# 0  [Q23540, Q1062789, Q960252, Q426316]
# 1                               [Q9268]
# 2                               [Q9592]
# 3                              [Q33203]
# 4                               [Q1841]
# 5                              [Q33203]
# 6                                  None
# 7                               [Q9268]
# 8                             [Q178169]
# 9                            [Q6423963]

# %%
#Replace label column at the first place

# shift column 'Name' to first position
first_column = df_merged.pop('label')
  
# insert column using insert(position,column_name,
# first_column) function
df_merged.insert(0, 'label', first_column)

# %%
df_merged.head(50)
# Out:
#                   label qid_unique  count  \
# 0          Barack Obama        Q76     77
# 1        Bernie Sanders    Q359442     59
# 2               Francis    Q450675     53
# 3       Hillary Clinton      Q6294     48
# 4          Andrew Cuomo     Q11673     40
# 5      Elizabeth Warren    Q434706     36
# 6       Rodrigo Duterte    Q457786     33
# 7    Benjamin Netanyahu     Q43723     32
# 8           Mike Pompeo    Q473239     28
# 9         Boris Johnson    Q180589     27
# 10          Marco Rubio    Q324546     26
# 11           Mike Pence     Q24313     25
# 12        Pep Guardiola    Q164038     24
# 15         Rahul Gandhi     Q10218     23
# 14       Lindsey Graham     Q22212     23
# 13       Vladimir Putin      Q7747     23
# 16         Nancy Pelosi    Q170581     21
# 17          Theresa May    Q264766     21
# 18         LeBron James     Q36159     19
# 19    Michael Bloomberg       Q607     19
# 20         Gavin Newsom    Q461391     17
# 21     Malcolm Turnbull    Q927550     17
# 22         Arun Jaitley   Q3629480     16
# 23       Lewis Hamilton   Q6536656     16
# 24            Elon Musk    Q317521     16
# 25             Tim Cook   Q1404825     16
# 28  Mauricio Pochettino    Q313000     15
# 26        Anthony Fauci    Q573246     15
# 27        Jeff Banister   Q6173283     15
# 30        Rajnath Singh   Q3506475     14
# 31      Mitch McConnell    Q355522     14
# 32           Joe Maddon   Q1093629     14
# 29          Virat Kohli    Q213854     14
# 33        Stephen Curry    Q352159     13
# 34        Jeremy Corbyn    Q291169     13
# 35      Nicola Sturgeon    Q467112     13
# 36       Kim Kardashian    Q186304     13
# 37     Muhammadu Buhari    Q361567     13
# 38             Jeb Bush    Q221997     13
# 44          Mike DeWine   Q1363468     12
# 47         Dave Roberts   Q5229686     12
# 46          Joe Girardi   Q1186457     12
# 45        Rudy Giuliani    Q212648     12
# 40           Jay Inslee   Q1100710     12
# 43         Pete Carroll   Q1758777     12
# 42      Brendan Rodgers  Q19973684     12
# 41          John McCain     Q10390     12
# 39          Harry Roque  Q23303083     12
# 53        Angela Merkel       Q567     11
# 57        Melania Trump    Q432473     11
#
#                                               aliases  \
# 0   [Barack Hussein Obama II, Barack Obama II, Bar...
# 1                                   [Bernard Sanders]
# 2   [Jorge Mario Bergoglio, Francisco, Pope Franci...
# 3   [Hillary Rodham Clinton, Hillary Rodham, Hilla...
# 4                                 [Andrew Mark Cuomo]
# 5   [Elizabeth Ann Warren, Senator Warren, Elisabe...
# 6   [Rodrigo Roa Duterte, Rodrigo "Rody" Roa Duter...
# 7   [Binyamin Netanyahu, Bibi, Bibi Netanyahu, Ben...
# 8   [Michael Richard "Mike" Pompeo, Michael Richar...
# 9   [Boris, Alexander Boris de Pfeffel Johnson, Bo...
# 10                              [Marco Antonio Rubio]
# 11  [Michael R. Pence, Rep. Mike Pence, Michael Pe...
# 12  [Josep Guardiola, Josep Guardiola i Sala, Jose...
# 15                                               None
# 14                              [Lindsey Olin Graham]
# 13  [Vladimir Vladimirovich Putin, Putin, Presiden...
# 16  [Nancy Patricia D'Alesandro Pelosi, Nancy Patr...
# 17  [Theresa Mary Brasier, Prime Minister Theresa ...
# 18  [LeBron Raymone James Sr., King James, LBJ, Le...
# 19  [Michael Rubens Bloomberg, Michael R. Bloomber...
# 20                         [Gavin Christopher Newsom]
# 21                           [Malcolm Bligh Turnbull]
# 22                                               None
# 23                                               None
# 24       [Elon Reeve Musk, Elon R. Musk, Elon R Musk]
# 25                                               None
# 28  [Mauricio Roberto Pochettino Trassero, Maricar...
# 26  [Anthony S. Fauci, Anthony S Fauci, Anthony St...
# 27                            [Jeffery Todd Banister]
# 30                       [Rajnath, Rajnath Dev Singh]
# 31  [Addison Mitchell McConnell, Jr., Addison Mitc...
# 32       [Joseph John Maddon, Joseph John Maddon Jr.]
# 29                                           [Cheeku]
# 33  [Wardell Stephen Curry II, Steph Curry, Wardel...
# 34                            [Jeremy Bernard Corbyn]
# 35                         [Nicola Ferguson Sturgeon]
# 36  [Kim Kardashian West, KiKi, Keeks, Kim K, Kimb...
# 37        [GMB, PMB, Baba buhari, Bubu, Baba Go Slow]
# 38  [John Ellis Bush, Bush, Jeb, John Ellis "Jeb" ...
# 44  [Richard Michael DeWine, Richard DeWine, Micha...
# 47                                               None
# 46                            [Joseph Elliot Girardi]
# 45  [Rudolph Giuliani, Rudolph William Louis Giuli...
# 40                                [Jay Robert Inslee]
# 43                                               None
# 42                           [Brendan Austin Rodgers]
# 41      [John Sidney McCain III, John S. McCain, III]
# 39                                               None
# 53  [Angela Dorothea Merkel, Angela Kasner, Angela...
# 57  [Melanija Knavs, Melania Knauss, Melania Knaus...
#
#                                      date_of_birth          nationality  \
# 0                          [+1961-08-04T00:00:00Z]                [Q30]
# 1                          [+1941-09-08T00:00:00Z]                [Q30]
# 2                          [+1936-12-17T00:00:00Z]         [Q237, Q414]
# 3                          [+1947-10-26T00:00:00Z]                [Q30]
# 4                          [+1957-12-06T00:00:00Z]                [Q30]
# 5                          [+1949-06-22T00:00:00Z]                [Q30]
# 6                          [+1945-03-28T00:00:00Z]               [Q928]
# 7                          [+1949-10-21T00:00:00Z]               [Q801]
# 8                          [+1963-12-30T00:00:00Z]                [Q30]
# 9                          [+1964-06-19T00:00:00Z]          [Q30, Q145]
# 10                         [+1971-05-28T00:00:00Z]                [Q30]
# 11                         [+1959-06-07T00:00:00Z]                [Q30]
# 12                         [+1971-01-18T00:00:00Z]                [Q29]
# 15                         [+1970-06-19T00:00:00Z]               [Q668]
# 14                         [+1955-07-09T00:00:00Z]                [Q30]
# 13                         [+1952-10-07T00:00:00Z]       [Q15180, Q159]
# 16                         [+1940-03-26T00:00:00Z]                [Q30]
# 17                         [+1956-10-01T00:00:00Z]               [Q145]
# 18                         [+1984-12-30T00:00:00Z]                [Q30]
# 19                         [+1942-02-14T00:00:00Z]                [Q30]
# 20                         [+1967-10-10T00:00:00Z]                [Q30]
# 21                         [+1954-10-24T00:00:00Z]               [Q408]
# 22                         [+1952-12-28T00:00:00Z]               [Q668]
# 23                         [+1984-11-21T00:00:00Z]               [Q145]
# 24                         [+1971-06-28T00:00:00Z]     [Q258, Q16, Q30]
# 25                         [+1984-03-13T00:00:00Z]                [Q30]
# 28                         [+1972-03-02T00:00:00Z]          [Q414, Q29]
# 26                         [+1940-12-24T00:00:00Z]                [Q30]
# 27                         [+1965-01-15T00:00:00Z]                [Q30]
# 30                         [+1951-07-10T00:00:00Z]               [Q668]
# 31                         [+1942-02-20T00:00:00Z]                [Q30]
# 32                         [+1954-02-08T00:00:00Z]                [Q30]
# 29                         [+1988-11-05T00:00:00Z]               [Q668]
# 33                         [+1988-03-14T00:00:00Z]                [Q30]
# 34  [+1949-05-26T00:00:00Z, +1949-01-01T00:00:00Z]               [Q145]
# 35                         [+1970-07-19T00:00:00Z]          [Q22, Q145]
# 36                         [+1980-10-21T00:00:00Z]                [Q30]
# 37                         [+1942-12-17T00:00:00Z]              [Q1033]
# 38                         [+1953-02-11T00:00:00Z]           [Q30, Q29]
# 44                         [+1947-01-05T00:00:00Z]                [Q30]
# 47                                            None                [Q30]
# 46                         [+1964-10-14T00:00:00Z]                [Q30]
# 45                         [+1944-05-28T00:00:00Z]                [Q30]
# 40                         [+1951-02-09T00:00:00Z]                [Q30]
# 43                         [+1951-09-15T00:00:00Z]                [Q30]
# 42                         [+1996-08-09T00:00:00Z]                [Q30]
# 41                         [+1936-08-29T00:00:00Z]                [Q30]
# 39                         [+1966-10-21T00:00:00Z]               [Q928]
# 53                         [+1954-07-17T00:00:00Z]       [Q183, Q16957]
# 57                         [+1970-04-26T00:00:00Z]  [Q215, Q83286, Q30]
#
#         gender   lastrevid                                       ethnic_group  \
# 0   [Q6581097]  1395141963            [Q49085, Q6935055, Q12826303, Q6392846]
# 1   [Q6581097]  1392561607                                            [Q7325]
# 2   [Q6581097]  1396054797                                         [Q1056744]
# 3   [Q6581072]  1393846565                                               None
# 4   [Q6581097]  1393197828                                          [Q974693]
# 5   [Q6581072]  1394365746                                           [Q49078]
# 6   [Q6581097]  1348817804                                         [Q1290600]
# 7   [Q6581097]  1391756559                                            [Q7325]
# 8   [Q6581097]  1393216542                                               None
# 9   [Q6581097]  1395092363                                         [Q7994501]
# 10  [Q6581097]  1393345921                                               None
# 11  [Q6581097]  1395854609                                               None
# 12  [Q6581097]  1388621526                                               None
# 15  [Q6581097]  1348295449                                               None
# 14  [Q6581097]  1392182121                                               None
# 13  [Q6581097]  1395274624                                           [Q49542]
# 16  [Q6581072]  1392905094                                          [Q974693]
# 17  [Q6581072]  1392235818                                         [Q7994501]
# 18  [Q6581097]  1395492157                                           [Q49085]
# 19  [Q6581097]  1391164280                                            [Q7325]
# 20  [Q6581097]  1396128461                                               None
# 21  [Q6581097]  1388042865                                               None
# 22  [Q6581097]  1382428033                                               None
# 23  [Q6581097]  1392677497                                               None
# 24  [Q6581097]  1395054202                                               None
# 25  [Q6581097]  1323626384                                               None
# 28  [Q6581097]  1365925966                                               None
# 26  [Q6581097]  1387979010                                               None
# 27  [Q6581097]  1378257491                                               None
# 30  [Q6581097]  1382582279                                               None
# 31  [Q6581097]  1392727294                                               None
# 32  [Q6581097]  1315755360                                               None
# 29  [Q6581097]  1390478408                                               None
# 33  [Q6581097]  1389300978                                           [Q49085]
# 34  [Q6581097]  1396097133                                               None
# 35  [Q6581072]  1395095252                                               None
# 36  [Q6581072]  1395690668  [Q2325516, Q1058496, Q1344183, Q1075293, Q3476...
# 37  [Q6581097]  1391282556                                           [Q33938]
# 38  [Q6581097]  1393415091                                               None
# 44  [Q6581097]  1392437484                                               None
# 47  [Q6581097]  1392070268                                               None
# 46  [Q6581097]  1377618193                                               None
# 45  [Q6581097]  1394825933                                               None
# 40  [Q6581097]  1393018467                                               None
# 43  [Q6581097]  1378242166                                               None
# 42  [Q6581097]  1374372202                                               None
# 41  [Q6581097]  1388502237                      [Q3476361, Q7435494, Q846570]
# 39  [Q6581097]  1391140852                                               None
# 53  [Q6581072]  1394947627                                           [Q42884]
# 57  [Q6581072]  1386259124                                           [Q15863]
#
#    US_congress_bio_ID                                         occupation  \
# 0             O000167    [Q82955, Q40348, Q15958642, Q28532974, Q372436]
# 1             S000033  [Q82955, Q1930187, Q154549, Q1622272, Q36180, ...
# 2                None  [Q63173086, Q593644, Q104050302, Q36180, Q1234...
# 3             C001041  [Q82955, Q40348, Q193391, Q36180, Q18814623, Q...
# 4                None                                   [Q40348, Q82955]
# 5             W000817  [Q185351, Q82955, Q37226, Q1622272, Q40348, Q1...
# 6                None                                           [Q82955]
# 7                None  [Q82955, Q193391, Q372436, Q47064, Q15958642, ...
# 8             P000602        [Q40348, Q43845, Q2961975, Q189290, Q82955]
# 9                None  [Q1930187, Q82955, Q1607826, Q36180, Q11774202...
# 10            R000595                                   [Q82955, Q40348]
# 11            P000587                         [Q82955, Q40348, Q2722764]
# 12               None                                 [Q937857, Q628099]
# 15               None                                           [Q82955]
# 14            G000359    [Q82955, Q19934710, Q40348, Q5177784, Q5123536]
# 13               None  [Q82955, Q185351, Q6665249, Q18814623, Q239273...
# 16            P000197                                           [Q82955]
# 17               None                                           [Q82955]
# 18               None                      [Q3665646, Q28389, Q10798782]
# 19               None  [Q43845, Q82955, Q2095549, Q36180, Q1424605, Q...
# 20               None                         [Q82955, Q3427922, Q43845]
# 21               None      [Q1930187, Q82955, Q131524, Q40348, Q2883465]
# 22               None                 [Q82955, Q40348, Q17221, Q7621877]
# 23               None                                          [Q937857]
# 24               None  [Q15895020, Q205375, Q5482740, Q81096, Q131524...
# 25               None                                        [Q11774891]
# 28               None                                 [Q937857, Q628099]
# 26               None                      [Q15634285, Q39631, Q1650915]
# 27               None                                        [Q10871364]
# 30               None                                  [Q82955, Q169470]
# 31            M000355        [Q82955, Q40348, Q16533, Q1450482, Q211236]
# 32               None                     [Q10871364, Q865935, Q1186921]
# 29               None                                        [Q12299841]
# 33               None                                         [Q3665646]
# 34               None                                [Q15627169, Q82955]
# 35               None                                   [Q82955, Q40348]
# 36               None  [Q3501317, Q512314, Q4610556, Q8246794, Q13152...
# 37               None                                   [Q47064, Q82955]
# 38               None     [Q806798, Q82955, Q17487600, Q1413170, Q36180]
# 44            D000294                                   [Q82955, Q40348]
# 47               None                                [Q33999, Q10798782]
# 46               None                              [Q10871364, Q1186921]
# 45               None                  [Q40348, Q82955, Q36180, Q131524]
# 40            I000026                          [Q82955, Q40348, Q600751]
# 43               None                                        [Q19204627]
# 42               None                                        [Q10871364]
# 41            M000303  [Q82955, Q10669499, Q18814623, Q618694, Q37243...
# 39               None                                           [Q82955]
# 53               None                [Q82955, Q169470, Q372436, Q593644]
# 57               None              [Q4610556, Q2519376, Q211236, Q43845]
#
#                                            party       academic_degree  \
# 0                                       [Q29552]  [Q1765120, Q1540185]
# 1   [Q6542163, Q29552, Q327591, Q327591, Q29552]            [Q1765120]
# 2                                           None            [Q1233889]
# 3                               [Q29552, Q29468]   [Q163727, Q1540185]
# 4                                       [Q29552]            [Q1540185]
# 5                                       [Q29552]   [Q163727, Q1540185]
# 6                                     [Q7140531]                  None
# 7                                      [Q187009]    [Q787674, Q950900]
# 8                                       [Q29468]                  None
# 9                                        [Q9626]                  None
# 10                                      [Q29468]  [Q1765120, Q1540185]
# 11                                      [Q29468]                  None
# 12                                          None                  None
# 15                                      [Q10225]                  None
# 14                                      [Q29468]  [Q1765120, Q1540185]
# 13                   [Q79854, Q4488786, Q151469]           [Q17744738]
# 16                                      [Q29552]                  None
# 17                                       [Q9626]                  None
# 18                                          None                  None
# 19                      [Q29552, Q29468, Q29552]                  None
# 20                                      [Q29552]                  None
# 21                                     [Q241149]                  None
# 22                                      [Q10230]                  None
# 23                                          None                  None
# 24                                          None                  None
# 25                                          None                  None
# 28                                          None                  None
# 26                                          None             [Q913404]
# 27                                          None                  None
# 30                  [Q10230, Q3245961, Q2352638]                  None
# 31                                      [Q29468]                  None
# 32                                          None                  None
# 29                                          None                  None
# 33                                          None                  None
# 34                                       [Q9630]                  None
# 35                                      [Q10658]                  None
# 36                                      [Q29552]                  None
# 37                          [Q5160852, Q4729266]                  None
# 38                                      [Q29468]            [Q1765120]
# 44                                      [Q29468]                  None
# 47                                          None                  None
# 46                                          None                  None
# 45                                      [Q29468]            [Q1765120]
# 40                                      [Q29552]                  None
# 43                                          None                  None
# 42                                          None                  None
# 41                                      [Q29468]                  None
# 39                         [Q7165740, Q25101390]                  None
# 53                             [Q49762, Q677182]             [Q849697]
# 57                                      [Q29468]                  None
#
#            id                                          candidacy  type  \
# 0         Q76  [Q3586671, Q45578, Q4226, Q4791768, Q17067714,...  item
# 1     Q359442                                               None  item
# 2     Q450675                                               None  item
# 3       Q6294                                [Q699872, Q4791768]  item
# 4      Q11673                             [Q22023432, Q65047185]  item
# 5     Q434706                                        [Q28220813]  item
# 6     Q457786                                               None  item
# 7      Q43723                     [Q2917048, Q2480394, Q2689039]  item
# 8     Q473239                                               None  item
# 9     Q180589  [Q30173038, Q30325756, Q428598, Q590740, Q3586...  item
# 10    Q324546                                               None  item
# 11     Q24313                                               None  item
# 12    Q164038                                               None  item
# 15     Q10218                                        [Q63988877]  item
# 14     Q22212                                               None  item
# 13      Q7747           [Q19760074, Q488814, Q1505420, Q1348890]  item
# 16    Q170581                  [Q28404971, Q28122293, Q52494157]  item
# 17    Q264766  [Q30173038, Q215622, Q590740, Q428598, Q918503...  item
# 18     Q36159                                               None  item
# 19       Q607                                               None  item
# 20    Q461391                                               None  item
# 21    Q927550                                               None  item
# 22   Q3629480                                        [Q63988621]  item
# 23   Q6536656                                               None  item
# 24    Q317521                                               None  item
# 25   Q1404825                                               None  item
# 28    Q313000                                               None  item
# 26    Q573246                                               None  item
# 27   Q6173283                                               None  item
# 30   Q3506475                                        [Q63988874]  item
# 31    Q355522                                               None  item
# 32   Q1093629                                               None  item
# 29    Q213854                                               None  item
# 33    Q352159                                               None  item
# 34    Q291169  [Q30173038, Q918466, Q918472, Q918503, Q428598...  item
# 35    Q467112                                               None  item
# 36    Q186304                                               None  item
# 37    Q361567                             [Q24961921, Q56684494]  item
# 38    Q221997                                               None  item
# 44   Q1363468                                               None  item
# 47   Q5229686                                               None  item
# 46   Q1186457                                               None  item
# 45    Q212648                                         [Q4791860]  item
# 40   Q1100710                                               None  item
# 43   Q1758777                                               None  item
# 42  Q19973684                                               None  item
# 41     Q10390                                 [Q45578, Q4791860]  item
# 39  Q23303083                                               None  item
# 53       Q567  [Q555931, Q15062956, Q704648, Q702017, Q704641...  item
# 57    Q432473                                               None  item
#
#                                 religion
# 0   [Q23540, Q1062789, Q960252, Q426316]
# 1                                [Q9268]
# 2                                [Q9592]
# 3                               [Q33203]
# 4                                [Q1841]
# 5                               [Q33203]
# 6                                   None
# 7                                [Q9268]
# 8                              [Q178169]
# 9                             [Q6423963]
# 10                     [Q1841, Q7361618]
# 11                           [Q13631353]
# 12                                  None
# 15                               [Q9089]
# 14                            [Q1351880]
# 13                    [Q60995, Q3333484]
# 16                               [Q1841]
# 17                            [Q6423963]
# 18                                  None
# 19                     [Q9268, Q1133485]
# 20                               [Q9592]
# 21                               [Q1841]
# 22                               [Q9089]
# 23                                  None
# 24                             [Q288928]
# 25                                  None
# 28                                  None
# 26                               [Q1841]
# 27                                  None
# 30                               [Q9089]
# 31                            [Q1351880]
# 32                                  None
# 29                               [Q9089]
# 33                                  None
# 34                                  None
# 35                             [Q922480]
# 36                               [Q5043]
# 37                                [Q432]
# 38                      [Q682443, Q1841]
# 44                                  None
# 47                                  None
# 46                                  None
# 45                                  None
# 40                              [Q23540]
# 43                                  None
# 42                                  None
# 41            [Q1351880, Q23540, Q93191]
# 39                                  None
# 53                     [Q170111, Q75809]
# 57                        [Q9592, Q5043]

# %% [markdown]
# #### Representativity of the data

# %%
#Check the repartition of the data according several criterias 

#Plot an histogram of ages of speakers by number of quotations
df_merged['nationality'].apply(lambda x:x[0])
country = df_merged.groupby('nationality')['count'] 
country.head(20)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20508/3408920889.py in <module>
#       2
#       3 #Plot an histogram of nationalty by number of quotation
# ----> 4 df_merged['nationality'].apply(lambda x:x[0])
#
# ~\anaconda3\envs\ada\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4355         dtype: float64
#    4356         """
# -> 4357         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4358
#    4359     def _reduce(
#
# ~\anaconda3\envs\ada\lib\site-packages\pandas\core\apply.py in apply(self)
#    1041             return self.apply_str()
#    1042
# -> 1043         return self.apply_standard()
#    1044
#    1045     def agg(self):
#
# ~\anaconda3\envs\ada\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#    1097                 # List[Union[Callable[..., Any], str]]]]]"; expected
#    1098                 # "Callable[[Any], Any]"
# -> 1099                 mapped = lib.map_infer(
#    1100                     values,
#    1101                     f,  # type: ignore[arg-type]
#
# ~\anaconda3\envs\ada\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# ~\AppData\Local\Temp/ipykernel_20508/3408920889.py in <lambda>(x)
#       2
#       3 #Plot an histogram of nationalty by number of quotation
# ----> 4 df_merged['nationality'].apply(lambda x:x[0])
#
# TypeError: 'NoneType' object is not subscriptable

# %% [raw]
# #Count how many speakers has no metadata
#
#
# print('There are {} speakers'.format(len(df_merged)))
# print('{} speakers that have not metadata'.format(len(df_no_metadata)))
#
# print('There is {} % of speakers that has no metadata'.format(100*len(df_no_metadata)/len(df_merged)))
# print(df_no_metadata.sample(50))

# %% [markdown]
# ## Aditionnal metadata from Wikidata

# %% [markdown]
# Script to retrieve metedata from Quotebank entries :

# %% [raw]
# '''
# Execute this script as:
# python query_wikidata_dump.py --input <path-to-wikidata-json-dump> --output <path-to-output-json-file>
# '''
#
# import json
# import sys
# from tqdm import tqdm
# from argparse import ArgumentParser
# import gzip
#
# parser = ArgumentParser()
# parser.add_argument("--input", required=True)
# parser.add_argument("--output", required=True)
# args = parser.parse_args()
#
# # Usage:
#
#
# def main():
#     # Do not enforce encoding here since the input encoding is correct
#     with open(args.output, "w") as output_file:
#         with gzip.open(args.input, 'rb') as s_file:
#             for instance in s_file:
#                 instance = instance.decode('utf-8')
#                 instance = instance[:-2]
#                 if len(instance)==0:
#                     continue
#                 s = json.loads(instance.strip("\n"))
#
#                 if s.get("labels", {}).get("en") is not None:
#                     s["label"] = s["labels"]["en"]["value"]
#                 if s.get("labels") is not None:
#                     del s["labels"]
#                 else:
#                     continue
#
#                 # Occupation
#                 if len(s.get("claims", {}).get("P106", [])) > 0:
#                     tmp = []
#                     for v in s["claims"]["P106"]:
#                         # id: "Q123", "numeric-id": 123
#                         if (
#                             v["mainsnak"].get("datavalue", {}).get("value", {}).get("id")
#                             is not None
#                         ):
#                             tmp.append(v["mainsnak"]["datavalue"]["value"]["id"])
#                     if len(tmp) > 0:
#                         s["occupation"] = tmp
#
#                 # Gender
#                 if len(s.get("claims", {}).get("P21", [])) > 0:
#                     tmp = []
#                     for v in s["claims"]["P21"]:
#                         # id: "Q123", "numeric-id": 123
#                         if (
#                             v["mainsnak"].get("datavalue", {}).get("value", {}).get("id")
#                             is not None
#                         ):
#                             tmp.append(v["mainsnak"]["datavalue"]["value"]["id"])
#                     if len(tmp) > 0:
#                         s["gender"] = tmp
#
#                 # Country of citizenship
#                 if len(s.get("claims", {}).get("P27", [])) > 0:
#                     tmp = []
#                     for v in s["claims"]["P27"]:
#                         # id: "Q123", "numeric-id": 123
#                         if (
#                             v["mainsnak"].get("datavalue", {}).get("value", {}).get("id")
#                             is not None
#                         ):
#                             tmp.append(v["mainsnak"]["datavalue"]["value"]["id"])
#                     if len(tmp) > 0:
#                         s["nationality"] = tmp
#
#                 # Position Held
#                 if len(s.get("claims", {}).get("P39", [])) > 0:
#                     tmp = []
#                     for v in s["claims"]["P39"]:
#                         # id: "Q123", "numeric-id": 123
#                         if (
#                             v["mainsnak"].get("datavalue", {}).get("value", {}).get("id")
#                             is not None
#                         ):
#                             tmp.append(v["mainsnak"]["datavalue"]["value"]["id"])
#                     if len(tmp) > 0:
#                         s["positions_held"] = tmp
#
#                 # Date of Birth
#                 if len(s.get("claims", {}).get("P569", [])) > 0:
#                     tmp = []
#                     for v in s["claims"]["P569"]:
#                         if (
#                             v["mainsnak"].get("datavalue", {}).get("value", {}).get("time")
#                             is not None
#                         ):
#                             tmp.append(v["mainsnak"]["datavalue"]["value"]["time"])
#                     if len(tmp) > 0:
#                         s["date_of_birth"] = tmp
#
#                 # Academic Degree
#                 if len(s.get("claims", {}).get("P512", [])) > 0:
#                     tmp = []
#                     for v in s["claims"]["P512"]:
#                         if (
#                             v["mainsnak"].get("datavalue", {}).get("value", {}).get("id")
#                             is not None
#                         ):
#                             tmp.append(v["mainsnak"]["datavalue"]["value"]["id"])
#                     if len(tmp) > 0:
#                         s["academic_degree"] = tmp
#
#                 # Member of Political Party
#                 if len(s.get("claims", {}).get("P102", [])) > 0:
#                     tmp = []
#                     for v in s["claims"]["P102"]:
#                         if (
#                             v["mainsnak"].get("datavalue", {}).get("value", {}).get("id")
#                             is not None
#                         ):
#                             tmp.append(v["mainsnak"]["datavalue"]["value"]["id"])
#                     if len(tmp) > 0:
#                         s["party"] = tmp
#
#                 # Candidacy in election
#                 if len(s.get("claims", {}).get("P3602", [])) > 0:
#                     tmp = []
#                     for v in s["claims"]["P3602"]:
#                         if (
#                             v["mainsnak"].get("datavalue", {}).get("value", {}).get("id")
#                             is not None
#                         ):
#                             tmp.append(v["mainsnak"]["datavalue"]["value"]["id"])
#                     if len(tmp) > 0:
#                         s["candidacy"] = tmp
#
#                 # US Congress Bio ID
#                 # Get more information on the politicians based on the ID here: https://bioguide.congress.gov
#                 if len(s.get("claims", {}).get("P1157", [])) > 0:
#                     tmp = None
#                     for v in s["claims"]["P1157"]:
#                         if (
#                             v["mainsnak"].get("datavalue", {}).get("value")
#                             is not None
#                         ):
#                             tmp = v["mainsnak"]["datavalue"]["value"]
#                             break
#                     if tmp is not None:
#                         s["US_congress_bio_ID"] = tmp
#
#                 # Ethnic Group
#                 if len(s.get("claims", {}).get("P172", [])) > 0:
#                     tmp = []
#                     for v in s["claims"]["P172"]:
#                         if (
#                             v["mainsnak"].get("datavalue", {}).get("value", {}).get("id")
#                             is not None
#                         ):
#                             tmp.append(v["mainsnak"]["datavalue"]["value"]["id"])
#                     if len(tmp) > 0:
#                         s["ethnic_group"] = tmp
#
#                 # Religion
#                 if len(s.get("claims", {}).get("P140", [])) > 0:
#                     tmp = []
#                     for v in s["claims"]["P140"]:
#                         if (
#                             v["mainsnak"].get("datavalue", {}).get("value", {}).get("id")
#                             is not None
#                         ):
#                             tmp.append(v["mainsnak"]["datavalue"]["value"]["id"])
#                     if len(tmp) > 0:
#                         s["religion"] = tmp
#
#                 # Aliases. Removing leftovers and unnecessary attributes
#                 if len(s.get("aliases", {}).get("en", [])) > 0:
#                     s["aliases"] = [v["value"] for v in s["aliases"]["en"]]
#                 elif s.get("aliases") is not None:
#                     del s["aliases"]
#                 if s.get("descriptions") is not None:
#                     del s["descriptions"]
#                 if s.get("sitelinks") is not None:
#                     del s["sitelinks"]
#                 if s.get("claims") is not None:
#                     del s["claims"]
#
#                 output_file.write(json.dumps(s, ensure_ascii=False) + "\n")
#
# if __name__ == "__main__":
#     main()
