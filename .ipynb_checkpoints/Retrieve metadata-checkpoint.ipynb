# %% [markdown]
# # Retrieve metadata about speakers

# %% [markdown]
# This notebook is dedicated to the retrieve of the speakers metadata. First, it uses the parquet file that was provided to retrieve extra-information (occupation, date of birth, gender, religion) on speakers.

# %% [markdown]
# ## Using provided parquet file

# %% [markdown]
# Pandas requires pyarrow to read parquet files, which can be installed using conda install pyarrow -c conda-forge.
# You can load this file as a pandas dataframe using df = pd.read_parquet(<path_to_file>).

# %% [raw]
# Schema of parquet file :
#
#     Schema:
#  |-- aliases: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- date_of_birth: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- nationality: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- gender: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- lastrevid: long (nullable = true)
#  |-- ethnic_group: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- US_congress_bio_ID: string (nullable = true)
#  |-- occupation: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- party: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- academic_degree: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- id: string (nullable = true)
#  |-- label: string (nullable = true)
#  |-- candidacy: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- type: string (nullable = true)
#  |-- religion: array (nullable = true)
#  |    |-- element: string (containsNull = true)

# %%
#importing the required modules
import seaborn as sns
from IPython.display import display, HTML
import matplotlib.pyplot as plt
import scipy.stats as stats
import pandas as pd
import numpy as np
import seaborn as sns

# %%
# Small adjustments to default style of plots, making sure it's readable and colorblind-friendly everywhere
plt.style.use('seaborn-colorblind')
plt.rcParams.update({'font.size' : 12.5,
                     'figure.figsize':(10,7)})

# %% [markdown]
# ### Import data

# %%
#Define the path for folder containing data
#TO BE MODIFIED ACCORDING HIS OWN FOLER containing data in local
path = '../ADA_project_data/'
df = pd.read_parquet(path+'speaker_attributes.parquet')
df.head()
# Out:
# ---------------------------------------------------------------------------
# ArrowMemoryError                          Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9616/2327828956.py in <module>
#       1 path = '../ADA_project_data/'
#       2
# ----> 3 df = pd.read_parquet(path+'speaker_attributes.parquet')
#       4
#       5 df.head()
#
# ~\anaconda3\envs\ada\lib\site-packages\pandas\io\parquet.py in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, **kwargs)
#     493     impl = get_engine(engine)
#     494
# --> 495     return impl.read(
#     496         path,
#     497         columns=columns,
#
# ~\anaconda3\envs\ada\lib\site-packages\pandas\io\parquet.py in read(self, path, columns, use_nullable_dtypes, storage_options, **kwargs)
#     237         )
#     238         try:
# --> 239             result = self.api.parquet.read_table(
#     240                 path_or_handle, columns=columns, **kwargs
#     241             ).to_pandas(**to_pandas_kwargs)
#
# ~\anaconda3\envs\ada\lib\site-packages\pyarrow\array.pxi in pyarrow.lib._PandasConvertible.to_pandas()
#
# ~\anaconda3\envs\ada\lib\site-packages\pyarrow\table.pxi in pyarrow.lib.Table._to_pandas()
#
# ~\anaconda3\envs\ada\lib\site-packages\pyarrow\pandas_compat.py in table_to_blockmanager(options, table, categories, ignore_metadata, types_mapper)
#     787     _check_data_column_metadata_consistency(all_columns)
#     788     columns = _deserialize_column_index(table, all_columns, column_indexes)
# --> 789     blocks = _table_to_blocks(options, table, categories, ext_columns_dtypes)
#     790
#     791     axes = [columns, index]
#
# ~\anaconda3\envs\ada\lib\site-packages\pyarrow\pandas_compat.py in _table_to_blocks(options, block_table, categories, extension_columns)
#    1126     # Convert an arrow table to Block from the internal pandas API
#    1127     columns = block_table.column_names
# -> 1128     result = pa.lib.table_to_blocks(options, block_table, categories,
#    1129                                     list(extension_columns.keys()))
#    1130     return [_reconstruct_block(item, columns, extension_columns)
#
# ~\anaconda3\envs\ada\lib\site-packages\pyarrow\table.pxi in pyarrow.lib.table_to_blocks()
#
# ~\anaconda3\envs\ada\lib\site-packages\pyarrow\error.pxi in pyarrow.lib.check_status()
#
# ArrowMemoryError: malloc of size 1073741824 failed

# %%
#Does the metadata is unique ? 
df[df['label']=='Donald Trump']
df.index.is_unique #True
# Out:
# True

# %%
#import the dataset sample
path = '../ADA_project_data/'
raw_data = pd.read_json(path+'Sample.json.bz2',compression = 'bz2',lines = True)

raw_data.head()
# Out:
#              quoteID                                          quotation  \
# 0  2015-11-11-109291  They'll call me lots of different things. Libe...
# 1  2015-11-04-105046                     The choices are not that easy,
# 2  2015-09-11-070666  It's kind of the same way it's been with the R...
# 3  2015-01-12-082489  We're now going back to the frozen tundra, and...
# 4  2015-11-09-033345  I had a chuckle: They were showing a video of ...
#
#              speaker                  qids                date  \
# 0     Chris Christie              [Q63879] 2015-11-11 00:55:12
# 1           Dr. John  [Q511074, Q54593093] 2015-11-04 18:13:06
# 2    Niklas Kronwall             [Q722939] 2015-09-11 19:54:00
# 3  Frances McDormand             [Q204299] 2015-01-12 01:40:00
# 4        Kris Draper             [Q948695] 2015-11-09 00:57:45
#
#    numOccurrences                                             probas  \
# 0               1  [[Chris Christie, 0.7395], [Bobby Jindal, 0.15...
# 1               2               [[Dr. John, 0.5531], [None, 0.4469]]
# 2               1  [[Niklas Kronwall, 0.7119], [None, 0.2067], [H...
# 3               3  [[Frances McDormand, 0.484], [None, 0.4495], [...
# 4               3  [[Kris Draper, 0.8782], [None, 0.1043], [Serge...
#
#                                                 urls phase
# 0  [http://thehill.com/blogs/ballot-box/259760-ch...     E
# 1  [http://delawareonline.com/story/news/health/2...     E
# 2  [http://redwings.nhl.com/club/news.htm?id=7787...     E
# 3  [http://feeds.people.com/~r/people/headlines/~...     E
# 4  [http://ca.rd.yahoo.com/sports/rss/nfl/SIG=13u...     E

# %% [markdown]
# ### How to tranlate items into meanings name ?

# %% [markdown]
# Understanding items
# Items and their data are interconnected
#
# In Wikidata, items are used to represent all the things in human knowledge, including topics, concepts, and objects. For example, the "1988 Summer Olympics", "love", "Elvis Presley", and "gorilla" are all items in Wikidata.

# %% [markdown]
# #### Importing the sample to join metadata with quotations :

# %% [markdown]
# Join quotations data with metadata :

# %%
df_trump = raw_data[raw_data['speaker']=='Emmanuel Macron']
df_trump.sample(50)


#df[df['label']==df_trump['speaker'].iloc[0]]
# Out:
#                    quoteID                                          quotation  \
# 713655   2018-03-02-086314  our determination to fight unforgivingly again...
# 920419   2019-01-16-043188                   I will be very vigilant on that,
# 1089670  2020-03-06-082805                will last weeks and perhaps months.
# 460420   2017-12-12-092630  ready to welcome [ Trump ] if he decides to co...
# 1227953  2020-01-22-005140                    and French security takes over.
# 1038444  2020-01-09-013728  clearly showed us that even though the agreeme...
# 695478   2018-06-11-092069  This decision is not only unlawful but it is a...
# 937246   2019-11-04-105086  We regret this and it makes the Franco-Chinese...
# 723744   2018-11-11-036353  Long live peace between people and between sta...
# 699518   2018-11-15-057891  is playing American politics, and I let him pl...
# 1124206  2020-01-23-022447                                 Go out -- outside!
# 725549   2018-04-25-036497  Here, I would like to pay special tribute to t...
# 744829   2018-04-25-157754  We signed it... we cannot say we should get ri...
# 440113   2017-12-19-100705                             the war against Daesh,
# 580959   2017-09-19-013250  Because it is a good deal, essential to peace ...
# 1116302  2020-01-22-028648  I am not going to come saying `this is a peace...
# 920419   [[Emmanuel Macron, 0.7263], [None, 0.2215], [J...
# 1089670        [[Emmanuel Macron, 0.9322], [None, 0.0678]]
# 460420         [[Emmanuel Macron, 0.9094], [None, 0.0906]]
# 1227953  [[Emmanuel Macron, 0.6347], [None, 0.3308], [J...
# 1038444  [[Emmanuel Macron, 0.9259], [None, 0.0532], [A...
# 695478   [[Emmanuel Macron, 0.9037], [None, 0.0636], [H...
# 937246   [[Emmanuel Macron, 0.7483], [None, 0.2019], [M...
# 723744           [[Emmanuel Macron, 0.875], [None, 0.125]]
# 699518   [[Emmanuel Macron, 0.7381], [President Donald ...
# 1124206  [[Emmanuel Macron, 0.8014], [None, 0.1887], [J...
# 725549   [[Emmanuel Macron, 0.6559], [None, 0.2465], [M...
# 744829   [[Emmanuel Macron, 0.5273], [None, 0.4234], [D...
# 440113   [[Emmanuel Macron, 0.5086], [Jens Stoltenberg,...
# 580959         [[Emmanuel Macron, 0.7474], [None, 0.2526]]
# 1116302  [[Emmanuel Macron, 0.8055], [None, 0.1827], [J...
# 204114         [[Emmanuel Macron, 0.9321], [None, 0.0679]]
# 199338           [[Emmanuel Macron, 0.665], [None, 0.335]]
# 726476   [[Emmanuel Macron, 0.4391], [None, 0.4137], [D...
# 1136285        [[Emmanuel Macron, 0.8983], [None, 0.1017]]
# 645295   [[Emmanuel Macron, 0.7498], [None, 0.228], [Pr...
# 772320         [[Emmanuel Macron, 0.7299], [None, 0.2701]]
# 797368   [[Emmanuel Macron, 0.7616], [None, 0.1788], [A...
# 974945           [[Emmanuel Macron, 0.906], [None, 0.094]]
# 889430         [[Emmanuel Macron, 0.8139], [None, 0.1861]]
# 816640   [[Emmanuel Macron, 0.8593], [None, 0.1109], [T...
# 1245280  [[Emmanuel Macron, 0.7345], [None, 0.2016], [H...
# 1114024  [[Emmanuel Macron, 0.7106], [Charles Michel, 0...
# 1098447        [[Emmanuel Macron, 0.9257], [None, 0.0743]]
# 536660   [[Emmanuel Macron, 0.4993], [None, 0.3228], [A...
# 1080840  [[Emmanuel Macron, 0.5428], [None, 0.2779], [U...
# 839487         [[Emmanuel Macron, 0.6485], [None, 0.3515]]
# 987498         [[Emmanuel Macron, 0.9506], [None, 0.0494]]
# 779923   [[Emmanuel Macron, 0.8769], [None, 0.0825], [P...
# 470637   [[Emmanuel Macron, 0.6682], [None, 0.21], [FRA...
# 991446   [[Emmanuel Macron, 0.7509], [None, 0.2421], [E...
# 290632         [[Emmanuel Macron, 0.6733], [None, 0.3267]]
# 939903   [[Emmanuel Macron, 0.8749], [None, 0.1052], [A...
# 738551   [[Emmanuel Macron, 0.6812], [None, 0.2361], [V...
# 886308   [[Emmanuel Macron, 0.6475], [None, 0.3517], [G...
# 1180184  [[Emmanuel Macron, 0.7998], [None, 0.126], [Vl...
# 728080   [[Emmanuel Macron, 0.8024], [None, 0.1608], [X...
# 441271   [[Emmanuel Macron, 0.6806], [None, 0.2651], [T...
# 1180184  [https://www.justsecurity.org/69687/the-early-...     E
# 728080   [https://thediplomat.com/2018/01/why-did-franc...     E
# 441271   [http://www.irishtimes.com/opinion/theresa-may...     E
# 970720   [http://rss.cnn.com/~r/rss/cnn_world/~3/weR8bJ...     E
# 667615   [https://www.breitbart.com/europe/2018/12/10/m...     E
# 509695   [http://www.wsws.org/en/articles/2017/09/18/ma...     E
# 491553   [http://feeds.foxnews.com/~r/foxnews/world/~3/...     E
# 980762   [http://rt.com/news/469507-macron-thunberg-ant...     E
# 1115325  [http://www.breitbart.com/news/france-agrees-t...     E
# 663135   [https://www.express.co.uk/news/world/904274/G...     E

# %%
raw_data
# Out:
#                    quoteID                                          quotation  \
# 0        2015-11-11-109291  They'll call me lots of different things. Libe...
# 1        2015-11-04-105046                     The choices are not that easy,
# 2        2015-09-11-070666  It's kind of the same way it's been with the R...
# 3        2015-01-12-082489  We're now going back to the frozen tundra, and...
# 4        2015-11-09-033345  I had a chuckle: They were showing a video of ...
# ...                    ...                                                ...
# 1263785  2020-01-09-100998  We can't thank our dear family friend, WWE Sup...
# 1263786  2020-01-14-073101  The Fake News Media and their Democrat Partner...
# 1263787  2020-04-03-015274  get some new programming out to the community ...
# 1263788  2020-03-27-054612  The unforeseen and significant increase in the...
# 1263789  2020-02-24-012630  Everybody is spending an enormous amount of ti...
#
#                         speaker                  qids                date  \
# 0                Chris Christie              [Q63879] 2015-11-11 00:55:12
# 1                      Dr. John  [Q511074, Q54593093] 2015-11-04 18:13:06
# 2               Niklas Kronwall             [Q722939] 2015-09-11 19:54:00
# 3             Frances McDormand             [Q204299] 2015-01-12 01:40:00
# 4                   Kris Draper             [Q948695] 2015-11-09 00:57:45
# ...                         ...                   ...                 ...
# 1263785             Terri Irwin            [Q2368306] 2020-01-09 20:15:06
# 1263786  President Donald Trump              [Q22686] 2020-01-14 16:00:37
# 1263787           Karen Simpson  [Q5434129, Q6370032] 2020-04-03 14:24:17
# 1263788                    None                    [] 2020-03-27 00:00:00
# 1263789                    None                    [] 2020-02-24 13:41:13
#
#          numOccurrences                                             probas  \
# 0                     1  [[Chris Christie, 0.7395], [Bobby Jindal, 0.15...
# 1                     2               [[Dr. John, 0.5531], [None, 0.4469]]
# 2                     1  [[Niklas Kronwall, 0.7119], [None, 0.2067], [H...
# 3                     3  [[Frances McDormand, 0.484], [None, 0.4495], [...
# 4                     3  [[Kris Draper, 0.8782], [None, 0.1043], [Serge...
# ...                 ...                                                ...
# 1263785               1            [[Terri Irwin, 0.7848], [None, 0.2152]]
# 1263786               3  [[President Donald Trump, 0.9371], [None, 0.05...
# 1263787               1          [[Karen Simpson, 0.5827], [None, 0.4173]]
# 1263788              28         [[None, 0.6457], [Andrew Meadows, 0.3543]]
# 1263789               2            [[None, 0.5237], [Kate Taylor, 0.4763]]
#
#                                                       urls phase
# 0        [http://thehill.com/blogs/ballot-box/259760-ch...     E
# 1        [http://delawareonline.com/story/news/health/2...     E
# 2        [http://redwings.nhl.com/club/news.htm?id=7787...     E
# 3        [http://feeds.people.com/~r/people/headlines/~...     E
# 4        [http://ca.rd.yahoo.com/sports/rss/nfl/SIG=13u...     E
# ...                                                    ...   ...
# 1263785  [http://cltampa.com/arts-entertainment/a-e-eve...     E
# 1263786  [https://www.thetrumpet.com/radio/trumpet-dail...     E
# 1263787  [https://www.eastbaytimes.com/2020/04/03/nonpr...     E
# 1263788  [http://iowapublicradio.org/post/stocks-are-si...     E
# 1263789  [http://feeds.businessinsider.com.au/~/6189683...     E
#
# [1263790 rows x 9 columns]

# %%
#Create sub-sample to group the same authors togethers

df_sub = raw_data.sample(int(5*10e3))
# Out:
# 70477      [Q50366986]
# 487264              []
# 1107551             []
# 816492       [Q173789]
# 936360      [Q7489944]
#               ...
# 93348               []
# 549159              []
# 870804              []
# 1090807       [Q36215]
# 775052              []
# Name: qids, Length: 50000, dtype: object

# %%
#For the moment, choose only the qid with only one entry
df_qids = df_sub[[len(a)>0 for a in df_sub['qids']]]
df_qids['qids'] = df_qids['qids'].apply(lambda x: x[0])

df_qids.sample(10)
# Out:
# C:\Users\jules\AppData\Local\Temp/ipykernel_9616/1053909806.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_qids['qids'] = df_qids['qids'].apply(lambda x: x[0])
#                    quoteID                                          quotation  \
# 547779   2017-12-08-097139  set the stage for huge cuts to education, law ...
# 365255   2016-09-04-048802  That's not too much to ask for someone who is ...
# 347979   2016-04-29-113424  This fundraise will facilitate the development...
# 507169   2017-10-02-089993  Since I don't prefer either of them, what can ...
# 313021   2016-09-23-064156  It supports the hard work that the actors and ...
# 1225704  2020-03-22-005563    Coronavirus has now arrived here in the Senate,
# 41725    2015-01-08-024202  I had a taste last season [ at Oldham Atheltic...
# 872866   2019-01-10-001357  A good way to understand it is that, really, t...
# 791046   2018-04-11-002686  A particularly crucial battleground in today's...
# 660711   2018-08-13-022511  He's a special, special commodity, isn't he. H...
#
#                    speaker       qids                date  numOccurrences  \
# 547779     Robert Menendez    Q888132 2017-12-08 15:19:25               6
# 365255       Charles Wells  Q21751032 2016-09-04 00:00:00               8
# 347979      George Maxwell  Q43912739 2016-04-29 00:00:00               1
# 507169       Tina Campbell  Q22338518 2017-10-02 10:50:58               6
# 313021   Jessica Greenberg  Q16251715 2016-09-23 05:00:00               1
# 1225704    Mitch McConnell    Q355522 2020-03-22 00:00:00               1
# 41725           Mark Oxley  Q10499992 2015-01-08 09:53:45               1
# 872866      Tommy Thompson  Q15439473 2019-01-10 22:22:40               6
# 791046     Georges Pontier    Q594668 2018-04-11 09:03:00               2
# 660711            Joe Root   Q3180174 2018-08-13 03:48:34               1
#
#                                                     probas  \
# 547779   [[Robert Menendez, 0.6154], [None, 0.2819], [J...
# 365255   [[Charles Wells, 0.459], [None, 0.2795], [Kerr...
# 347979          [[George Maxwell, 0.9292], [None, 0.0708]]
# 507169   [[Tina Campbell, 0.4054], [None, 0.3651], [Eri...
# 313021       [[Jessica Greenberg, 0.6833], [None, 0.3167]]
# 1225704  [[Mitch McConnell, 0.7992], [None, 0.17], [Ste...
# 41725               [[Mark Oxley, 0.7424], [None, 0.2576]]
# 872866            [[Tommy Thompson, 0.843], [None, 0.157]]
# 791046   [[Georges Pontier, 0.4889], [None, 0.2706], [P...
# 660711   [[Joe Root, 0.857], [James Anderson, 0.0743], ...
#
#                                                       urls phase
# 547779   [http://www.timescall.com/news/ci_31512044/how...     E
# 365255   [http://www.dailygazette.com/news/2016/sep/04/...     E
# 347979   [http://www.rigzone.com/news/oil_gas/a/144272/...     E
# 507169   [https://www.vibe.com/2017/10/tina-campbell-vo...     E
# 313021   [http://standard.net/Entertainment/2016/09/23/...     E
# 1225704  [http://feeds.foxnews.com/~r/foxnews/politics/...     E
# 41725    [http://edinburghnews.scotsman.com/sport/footb...     E
# 872866   [http://m.nzherald.co.nz/world/news/article.cf...     E
# 791046   [http://catholicnewsagency.com/news/president-...     E
# 660711   [https://www.thehindu.com/sport/cricket/we-did...     E

# %%
#Group quotation by speaker

df_group=df_qids.groupby('qids') \
['quoteID'] \
.count() \
.reset_index(name='count') \
.sort_values(['count'], ascending=False) 


df_group.head(20)



#Interesting to note that there is the same speaker called the by different ways (e.g : Donald Trump and President Trump)

#for speaker, quotation in df_group:
#    print('Speaker : ', speaker)
#    print('Quotations', quotation)
# Out:
#            qids  count
# 8463     Q22686    362
# 21747       Q76     79
# 288       Q1058     65
# 19605     Q6294     61
# 13043   Q359442     57
# 14581   Q450675     51
# 19571     Q6279     48
# 22350    Q79983     31
# 14304   Q434706     31
# 5443    Q180589     28
# 9875    Q264766     28
# 8304     Q22212     28
# 11816  Q3099714     27
# 22455    Q83106     27
# 14349    Q43723     24
# 1323   Q1286476     24
# 12265   Q324546     24
# 9301     Q24313     24
# 4876    Q170581     23
# 15139   Q473239     22

# %%
#Merging with metadata

#df_merged = df_group.merge(df,how='inner',on='speaker',right_on='label')
df_merged = df_group.merge(df,how='inner',left_on='qids', right_on='id').sort_values
df_merged = df_merged[1:]

# %%
df_merged.head(10)
# Out:
#        qids  count                                            aliases  \
# 1     Q6294     61  [Hillary Rodham Clinton, Hillary Rodham, Hilla...
# 2   Q359442     57                                  [Bernard Sanders]
# 3   Q450675     51  [Jorge Mario Bergoglio, Francisco, Pope Franci...
# 4   Q434706     31  [Elizabeth Ann Warren, Senator Warren, Elisabe...
# 5   Q180589     28  [Boris, Alexander Boris de Pfeffel Johnson, Bo...
# 6   Q264766     28  [Theresa Mary Brasier, Prime Minister Theresa ...
# 7    Q22212     28                              [Lindsey Olin Graham]
# 8    Q43723     24  [Binyamin Netanyahu, Bibi, Bibi Netanyahu, Ben...
# 9   Q324546     24                              [Marco Antonio Rubio]
# 10   Q24313     24  [Michael R. Pence, Rep. Mike Pence, Michael Pe...
#
#               date_of_birth   nationality      gender   lastrevid  \
# 1   [+1947-10-26T00:00:00Z]         [Q30]  [Q6581072]  1393846565
# 2   [+1941-09-08T00:00:00Z]         [Q30]  [Q6581097]  1392561607
# 3   [+1936-12-17T00:00:00Z]  [Q237, Q414]  [Q6581097]  1396054797
# 4   [+1949-06-22T00:00:00Z]         [Q30]  [Q6581072]  1394365746
# 5   [+1964-06-19T00:00:00Z]   [Q30, Q145]  [Q6581097]  1395092363
# 6   [+1956-10-01T00:00:00Z]        [Q145]  [Q6581072]  1392235818
# 7   [+1955-07-09T00:00:00Z]         [Q30]  [Q6581097]  1392182121
# 8   [+1949-10-21T00:00:00Z]        [Q801]  [Q6581097]  1391756559
# 9   [+1971-05-28T00:00:00Z]         [Q30]  [Q6581097]  1393345921
# 10  [+1959-06-07T00:00:00Z]         [Q30]  [Q6581097]  1395854609
#
#    ethnic_group US_congress_bio_ID  \
# 1          None            C001041
# 2       [Q7325]            S000033
# 3    [Q1056744]               None
# 4      [Q49078]            W000817
# 5    [Q7994501]               None
# 6    [Q7994501]               None
# 7          None            G000359
# 8       [Q7325]               None
# 9          None            R000595
# 10         None            P000587
#
#                                            occupation  \
# 1   [Q82955, Q40348, Q193391, Q36180, Q18814623, Q...
# 2   [Q82955, Q1930187, Q154549, Q1622272, Q36180, ...
# 3   [Q63173086, Q593644, Q104050302, Q36180, Q1234...
# 4   [Q185351, Q82955, Q37226, Q1622272, Q40348, Q1...
# 5   [Q1930187, Q82955, Q1607826, Q36180, Q11774202...
# 6                                            [Q82955]
# 7     [Q82955, Q19934710, Q40348, Q5177784, Q5123536]
# 8   [Q82955, Q193391, Q372436, Q47064, Q15958642, ...
# 9                                    [Q82955, Q40348]
# 10                         [Q82955, Q40348, Q2722764]
#
#                                            party       academic_degree  \
# 1                               [Q29552, Q29468]   [Q163727, Q1540185]
# 2   [Q6542163, Q29552, Q327591, Q327591, Q29552]            [Q1765120]
# 3                                           None            [Q1233889]
# 4                                       [Q29552]   [Q163727, Q1540185]
# 5                                        [Q9626]                  None
# 6                                        [Q9626]                  None
# 7                                       [Q29468]  [Q1765120, Q1540185]
# 8                                      [Q187009]    [Q787674, Q950900]
# 9                                       [Q29468]  [Q1765120, Q1540185]
# 10                                      [Q29468]                  None
#
#          id               label  \
# 1     Q6294     Hillary Clinton
# 2   Q359442      Bernie Sanders
# 3   Q450675             Francis
# 4   Q434706    Elizabeth Warren
# 5   Q180589       Boris Johnson
# 6   Q264766         Theresa May
# 7    Q22212      Lindsey Graham
# 8    Q43723  Benjamin Netanyahu
# 9   Q324546         Marco Rubio
# 10   Q24313          Mike Pence
#
#                                             candidacy  type           religion
# 1                                 [Q699872, Q4791768]  item           [Q33203]
# 2                                                None  item            [Q9268]
# 3                                                None  item            [Q9592]
# 4                                         [Q28220813]  item           [Q33203]
# 5   [Q30173038, Q30325756, Q428598, Q590740, Q3586...  item         [Q6423963]
# 6   [Q30173038, Q215622, Q590740, Q428598, Q918503...  item         [Q6423963]
# 7                                                None  item         [Q1351880]
# 8                      [Q2917048, Q2480394, Q2689039]  item            [Q9268]
# 9                                                None  item  [Q1841, Q7361618]
# 10                                               None  item        [Q13631353]

# %% [raw]
# #Count how many speakers has no metadata
#
#
# print('There are {} speakers'.format(len(df_merged)))
# print('{} speakers that have not metadata'.format(len(df_no_metadata)))
#
# print('There is {} % of speakers that has no metadata'.format(100*len(df_no_metadata)/len(df_merged)))
# print(df_no_metadata.sample(50))

# %% [markdown]
# ## Aditionnal metadata from Wikidata

# %% [markdown]
# Script to retrieve metedata from Quotebank entries :

# %% [raw]
# '''
# Execute this script as:
# python query_wikidata_dump.py --input <path-to-wikidata-json-dump> --output <path-to-output-json-file>
# '''
#
# import json
# import sys
# from tqdm import tqdm
# from argparse import ArgumentParser
# import gzip
#
# parser = ArgumentParser()
# parser.add_argument("--input", required=True)
# parser.add_argument("--output", required=True)
# args = parser.parse_args()
#
# # Usage:
#
#
# def main():
#     # Do not enforce encoding here since the input encoding is correct
#     with open(args.output, "w") as output_file:
#         with gzip.open(args.input, 'rb') as s_file:
#             for instance in s_file:
#                 instance = instance.decode('utf-8')
#                 instance = instance[:-2]
#                 if len(instance)==0:
#                     continue
#                 s = json.loads(instance.strip("\n"))
#
#                 if s.get("labels", {}).get("en") is not None:
#                     s["label"] = s["labels"]["en"]["value"]
#                 if s.get("labels") is not None:
#                     del s["labels"]
#                 else:
#                     continue
#
#                 # Occupation
#                 if len(s.get("claims", {}).get("P106", [])) > 0:
#                     tmp = []
#                     for v in s["claims"]["P106"]:
#                         # id: "Q123", "numeric-id": 123
#                         if (
#                             v["mainsnak"].get("datavalue", {}).get("value", {}).get("id")
#                             is not None
#                         ):
#                             tmp.append(v["mainsnak"]["datavalue"]["value"]["id"])
#                     if len(tmp) > 0:
#                         s["occupation"] = tmp
#
#                 # Gender
#                 if len(s.get("claims", {}).get("P21", [])) > 0:
#                     tmp = []
#                     for v in s["claims"]["P21"]:
#                         # id: "Q123", "numeric-id": 123
#                         if (
#                             v["mainsnak"].get("datavalue", {}).get("value", {}).get("id")
#                             is not None
#                         ):
#                             tmp.append(v["mainsnak"]["datavalue"]["value"]["id"])
#                     if len(tmp) > 0:
#                         s["gender"] = tmp
#
#                 # Country of citizenship
#                 if len(s.get("claims", {}).get("P27", [])) > 0:
#                     tmp = []
#                     for v in s["claims"]["P27"]:
#                         # id: "Q123", "numeric-id": 123
#                         if (
#                             v["mainsnak"].get("datavalue", {}).get("value", {}).get("id")
#                             is not None
#                         ):
#                             tmp.append(v["mainsnak"]["datavalue"]["value"]["id"])
#                     if len(tmp) > 0:
#                         s["nationality"] = tmp
#
#                 # Position Held
#                 if len(s.get("claims", {}).get("P39", [])) > 0:
#                     tmp = []
#                     for v in s["claims"]["P39"]:
#                         # id: "Q123", "numeric-id": 123
#                         if (
#                             v["mainsnak"].get("datavalue", {}).get("value", {}).get("id")
#                             is not None
#                         ):
#                             tmp.append(v["mainsnak"]["datavalue"]["value"]["id"])
#                     if len(tmp) > 0:
#                         s["positions_held"] = tmp
#
#                 # Date of Birth
#                 if len(s.get("claims", {}).get("P569", [])) > 0:
#                     tmp = []
#                     for v in s["claims"]["P569"]:
#                         if (
#                             v["mainsnak"].get("datavalue", {}).get("value", {}).get("time")
#                             is not None
#                         ):
#                             tmp.append(v["mainsnak"]["datavalue"]["value"]["time"])
#                     if len(tmp) > 0:
#                         s["date_of_birth"] = tmp
#
#                 # Academic Degree
#                 if len(s.get("claims", {}).get("P512", [])) > 0:
#                     tmp = []
#                     for v in s["claims"]["P512"]:
#                         if (
#                             v["mainsnak"].get("datavalue", {}).get("value", {}).get("id")
#                             is not None
#                         ):
#                             tmp.append(v["mainsnak"]["datavalue"]["value"]["id"])
#                     if len(tmp) > 0:
#                         s["academic_degree"] = tmp
#
#                 # Member of Political Party
#                 if len(s.get("claims", {}).get("P102", [])) > 0:
#                     tmp = []
#                     for v in s["claims"]["P102"]:
#                         if (
#                             v["mainsnak"].get("datavalue", {}).get("value", {}).get("id")
#                             is not None
#                         ):
#                             tmp.append(v["mainsnak"]["datavalue"]["value"]["id"])
#                     if len(tmp) > 0:
#                         s["party"] = tmp
#
#                 # Candidacy in election
#                 if len(s.get("claims", {}).get("P3602", [])) > 0:
#                     tmp = []
#                     for v in s["claims"]["P3602"]:
#                         if (
#                             v["mainsnak"].get("datavalue", {}).get("value", {}).get("id")
#                             is not None
#                         ):
#                             tmp.append(v["mainsnak"]["datavalue"]["value"]["id"])
#                     if len(tmp) > 0:
#                         s["candidacy"] = tmp
#
#                 # US Congress Bio ID
#                 # Get more information on the politicians based on the ID here: https://bioguide.congress.gov
#                 if len(s.get("claims", {}).get("P1157", [])) > 0:
#                     tmp = None
#                     for v in s["claims"]["P1157"]:
#                         if (
#                             v["mainsnak"].get("datavalue", {}).get("value")
#                             is not None
#                         ):
#                             tmp = v["mainsnak"]["datavalue"]["value"]
#                             break
#                     if tmp is not None:
#                         s["US_congress_bio_ID"] = tmp
#
#                 # Ethnic Group
#                 if len(s.get("claims", {}).get("P172", [])) > 0:
#                     tmp = []
#                     for v in s["claims"]["P172"]:
#                         if (
#                             v["mainsnak"].get("datavalue", {}).get("value", {}).get("id")
#                             is not None
#                         ):
#                             tmp.append(v["mainsnak"]["datavalue"]["value"]["id"])
#                     if len(tmp) > 0:
#                         s["ethnic_group"] = tmp
#
#                 # Religion
#                 if len(s.get("claims", {}).get("P140", [])) > 0:
#                     tmp = []
#                     for v in s["claims"]["P140"]:
#                         if (
#                             v["mainsnak"].get("datavalue", {}).get("value", {}).get("id")
#                             is not None
#                         ):
#                             tmp.append(v["mainsnak"]["datavalue"]["value"]["id"])
#                     if len(tmp) > 0:
#                         s["religion"] = tmp
#
#                 # Aliases. Removing leftovers and unnecessary attributes
#                 if len(s.get("aliases", {}).get("en", [])) > 0:
#                     s["aliases"] = [v["value"] for v in s["aliases"]["en"]]
#                 elif s.get("aliases") is not None:
#                     del s["aliases"]
#                 if s.get("descriptions") is not None:
#                     del s["descriptions"]
#                 if s.get("sitelinks") is not None:
#                     del s["sitelinks"]
#                 if s.get("claims") is not None:
#                     del s["claims"]
#
#                 output_file.write(json.dumps(s, ensure_ascii=False) + "\n")
#
# if __name__ == "__main__":
#     main()
