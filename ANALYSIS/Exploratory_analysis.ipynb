# %% [markdown]
# # Exploratory analysis speakers aggregations

# %%
#importing the required modules
import seaborn as sns
from IPython.display import display, HTML
import matplotlib.pyplot as plt
import scipy.stats as stats
import pandas as pd
import numpy as np
import seaborn as sns

# %%
# Small adjustments to default style of plots, making sure it's readable and colorblind-friendly everywhere
plt.style.use('seaborn-colorblind')
plt.rcParams.update({'font.size' : 12.5,
                     'figure.figsize':(20,7)})

# %% [markdown]
# ## 1. Import data

# %% [markdown]
# ### Metadata

# %% [markdown]
# Pandas requires pyarrow to read parquet files, which can be installed using conda install pyarrow -c conda-forge.
# You can load this file as a pandas dataframe using df = pd.read_parquet(<path_to_file>).

# %%
#Define the path for folder containing data
#TO BE MODIFIED ACCORDING HIS OWN FOLER containing data in local
#Jules
path = r'/Users/jules/kDrive/onedrive/Documents_Onedrive/EPFL/MA3/ADA/Project/Dataset/'
df_metadata = pd.read_parquet(path+'speaker_attributes.parquet')
#df_metadata.head()

# %% [markdown]
# ### Quotations dataset

# %%
#Import the dataset sample

#Jules: 
path = r'/Users/jules/kDrive/onedrive/Documents_Onedrive/EPFL/MA3/ADA/Project/Dataset/'

df_sample = pd.read_json(path+'Sample_classified_1Mio_v1.json.bz2',compression = 'bz2',lines = True)
df_metadata.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10496/2648693592.py in <module>
#       4 path = r'/Users/jules/kDrive/onedrive/Documents_Onedrive/EPFL/MA3/ADA/Project/Dataset/'
#       5
# ----> 6 df_sample = pd.read_json(path+'Sample_classified_1Mio_v1.json.bz2',compression = 'bz2',lines = True)
#       7 df_metadata.head()
#
# ~\anaconda3\envs\ada\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     205                 else:
#     206                     kwargs[new_arg_name] = new_arg_value
# --> 207             return func(*args, **kwargs)
#     208
#     209         return cast(F, wrapper)
#
# ~\anaconda3\envs\ada\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\envs\ada\lib\site-packages\pandas\io\json\_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options)
#     612
#     613     with json_reader:
# --> 614         return json_reader.read()
#     615
#     616
#
# ~\anaconda3\envs\ada\lib\site-packages\pandas\io\json\_json.py in read(self)
#     744                 data = ensure_str(self.data)
#     745                 data_lines = data.split("\n")
# --> 746                 obj = self._get_object_parser(self._combine_lines(data_lines))
#     747         else:
#     748             obj = self._get_object_parser(self.data)
#
# ~\anaconda3\envs\ada\lib\site-packages\pandas\io\json\_json.py in _get_object_parser(self, json)
#     768         obj = None
#     769         if typ == "frame":
# --> 770             obj = FrameParser(json, **kwargs).parse()
#     771
#     772         if typ == "series" or obj is None:
#
# ~\anaconda3\envs\ada\lib\site-packages\pandas\io\json\_json.py in parse(self)
#     883
#     884         else:
# --> 885             self._parse_no_numpy()
#     886
#     887         if self.obj is None:
#
# ~\anaconda3\envs\ada\lib\site-packages\pandas\io\json\_json.py in _parse_no_numpy(self)
#    1138         if orient == "columns":
#    1139             self.obj = DataFrame(
# -> 1140                 loads(json, precise_float=self.precise_float), dtype=None
#    1141             )
#    1142         elif orient == "split":
#
# ValueError: Could not reserve memory block

# %% [markdown]
# ### Lookup table for QIDs

# %% [markdown]
# #### Using the provided csv file to link qids with meaningful names

# %%
#read the file 

df_lookup = pd.read_csv('wikidata_labels_descriptions_quotebank.csv.bz2',compression = 'bz2',index_col='QID')
#df_lookup.sample(20)

# %% [markdown]
# ### 2. Merge speakers metadata with quotations

# %% [markdown]
# Join quotations data with metadata :

# %%
#Create sub-sample
#df_sub = df_sample.sample(int(1*10e3))
df_sub = df_sample.copy()
s1 = len(df_sub)

#For the moment, choose rows which at minimum 1 qid associated
#Remove this row when using the data that have been wrangled
df_sub = df_sub[[len(a)>0 for a in df_sub['qids']]]

s2 = len(df_sub)

print('There is {} % of rows that have no qid associated with (on {} rows)'.format((1-s2/s1)*100,s1))

#Choose the first QID that is associated with (to be improved)
df_sub['qid_unique'] = df_sub['qids'].apply(lambda x: x[0])
# Out:
# There is 0.0 % of rows that have no qid associated with (on 213357 rows)

# %%
#Group quotation by speaker

df_grouped=df_sub.groupby('qid_unique') \
['quoteID'] \
.count() \
.reset_index(name='count') \
.sort_values(['count'], ascending=False)

# %%
#Merging with metadata

df_merged = df_grouped.merge(df_metadata,how='inner',left_on='qid_unique', right_on='id').sort_values(['count'], ascending=False)

# %%
#Replace label column at the first place

# shift column 'Name' to first position
first_column = df_merged.pop('label')
  
# insert column using insert(position,column_name,
# first_column) function
df_merged.insert(0, 'label', first_column)

# %%
df_merged.head(20)
# Out:
#                  label qid_unique  count  \
# 0         Barack Obama        Q76   1042
# 1      Hillary Clinton      Q6294    617
# 2              Francis    Q450675    352
# 3       Bernie Sanders    Q359442    309
# 4           John Kerry     Q22316    232
# 5        David Cameron   Q1173911    215
# 6          Marco Rubio    Q324546    195
# 7   Benjamin Netanyahu     Q43723    172
# 8      Rodrigo Duterte    Q457786    156
# 9             Jeb Bush    Q221997    148
# 10      Louis van Gaal    Q207431    140
# 11        Arun Jaitley   Q3629480    137
# 12          Joe Maddon   Q1093629    135
# 13      Vladimir Putin      Q7747    134
# 14      Will Schuester    Q348577    122
# 15         Joe Girardi   Q1186457    116
# 16    Malcolm Turnbull    Q927550    113
# 17            Tim Cook   Q1404825    110
# 18          Mike Pence     Q24313    103
# 21        LeBron James     Q36159     96
#
#                                               aliases  \
# 0   [Barack Hussein Obama II, Barack Obama II, Bar...
# 1   [Hillary Rodham Clinton, Hillary Rodham, Hilla...
# 2   [Jorge Mario Bergoglio, Francisco, Pope Franci...
# 3                                   [Bernard Sanders]
# 4           [John Forbes Kerry, Kerry, John F. Kerry]
# 5                                                None
# 6                               [Marco Antonio Rubio]
# 7   [Binyamin Netanyahu, Bibi, Bibi Netanyahu, Ben...
# 8   [Rodrigo Roa Duterte, Rodrigo "Rody" Roa Duter...
# 9   [John Ellis Bush, Bush, Jeb, John Ellis "Jeb" ...
# 10                   [Aloysius Paulus Maria van Gaal]
# 11                                               None
# 12       [Joseph John Maddon, Joseph John Maddon Jr.]
# 13  [Vladimir Vladimirovich Putin, Putin, Presiden...
# 14  [Anthony John Abbott, Anthony John "Tony" Abbo...
# 15                            [Joseph Elliot Girardi]
# 16                           [Malcolm Bligh Turnbull]
# 17                                               None
# 18  [Michael R. Pence, Rep. Mike Pence, Michael Pe...
# 21  [LeBron Raymone James Sr., King James, LBJ, Le...
#
#               date_of_birth     nationality      gender   lastrevid  \
# 0   [+1961-08-04T00:00:00Z]           [Q30]  [Q6581097]  1395141963
# 1   [+1947-10-26T00:00:00Z]           [Q30]  [Q6581072]  1393846565
# 2   [+1936-12-17T00:00:00Z]    [Q237, Q414]  [Q6581097]  1396054797
# 3   [+1941-09-08T00:00:00Z]           [Q30]  [Q6581097]  1392561607
# 4   [+1943-12-11T00:00:00Z]           [Q30]  [Q6581097]  1393166711
# 5   [+1933-01-21T00:00:00Z]          [Q145]  [Q6581097]  1392347409
# 6   [+1971-05-28T00:00:00Z]           [Q30]  [Q6581097]  1393345921
# 7   [+1949-10-21T00:00:00Z]          [Q801]  [Q6581097]  1391756559
# 8   [+1945-03-28T00:00:00Z]          [Q928]  [Q6581097]  1348817804
# 9   [+1953-02-11T00:00:00Z]      [Q30, Q29]  [Q6581097]  1393415091
# 10  [+1951-08-08T00:00:00Z]        [Q29999]  [Q6581097]  1390309283
# 11  [+1952-12-28T00:00:00Z]          [Q668]  [Q6581097]  1382428033
# 12  [+1954-02-08T00:00:00Z]           [Q30]  [Q6581097]  1315755360
# 13  [+1952-10-07T00:00:00Z]  [Q15180, Q159]  [Q6581097]  1395274624
# 14  [+1957-11-04T00:00:00Z]    [Q408, Q145]  [Q6581097]  1394062431
# 15  [+1964-10-14T00:00:00Z]           [Q30]  [Q6581097]  1377618193
# 16  [+1954-10-24T00:00:00Z]          [Q408]  [Q6581097]  1388042865
# 17  [+1984-03-13T00:00:00Z]           [Q30]  [Q6581097]  1323626384
# 18  [+1959-06-07T00:00:00Z]           [Q30]  [Q6581097]  1395854609
# 21  [+1984-12-30T00:00:00Z]           [Q30]  [Q6581097]  1395492157
#
#                                ethnic_group US_congress_bio_ID  \
# 0   [Q49085, Q6935055, Q12826303, Q6392846]            O000167
# 1                                      None            C001041
# 2                                [Q1056744]               None
# 3                                   [Q7325]            S000033
# 4                                      None            K000148
# 5                                      None               None
# 6                                      None            R000595
# 7                                   [Q7325]               None
# 8                                [Q1290600]               None
# 9                                      None               None
# 10                                     None               None
# 11                                     None               None
# 12                                     None               None
# 13                                 [Q49542]               None
# 14                                     None               None
# 15                                     None               None
# 16                                     None               None
# 17                                     None               None
# 18                                     None            P000587
# 21                                 [Q49085]               None
#
#                                            occupation  \
# 0     [Q82955, Q40348, Q15958642, Q28532974, Q372436]
# 1   [Q82955, Q40348, Q193391, Q36180, Q18814623, Q...
# 2   [Q63173086, Q593644, Q104050302, Q36180, Q1234...
# 3   [Q82955, Q1930187, Q154549, Q1622272, Q36180, ...
# 4   [Q82955, Q10669499, Q40348, Q193391, Q2095549,...
# 5                                            [Q33999]
# 6                                    [Q82955, Q40348]
# 7   [Q82955, Q193391, Q372436, Q47064, Q15958642, ...
# 8                                            [Q82955]
# 9      [Q806798, Q82955, Q17487600, Q1413170, Q36180]
# 10                                 [Q937857, Q628099]
# 11                 [Q82955, Q40348, Q17221, Q7621877]
# 12                     [Q10871364, Q865935, Q1186921]
# 13  [Q82955, Q185351, Q6665249, Q18814623, Q239273...
# 14                                           [Q82955]
# 15                              [Q10871364, Q1186921]
# 16      [Q1930187, Q82955, Q131524, Q40348, Q2883465]
# 17                                        [Q11774891]
# 18                         [Q82955, Q40348, Q2722764]
# 21                      [Q3665646, Q28389, Q10798782]
#
#                                            party       academic_degree  \
# 0                                       [Q29552]  [Q1765120, Q1540185]
# 1                               [Q29552, Q29468]   [Q163727, Q1540185]
# 2                                           None            [Q1233889]
# 3   [Q6542163, Q29552, Q327591, Q327591, Q29552]            [Q1765120]
# 4                                       [Q29552]                  None
# 5                                           None                  None
# 6                                       [Q29468]  [Q1765120, Q1540185]
# 7                                      [Q187009]    [Q787674, Q950900]
# 8                                     [Q7140531]                  None
# 9                                       [Q29468]            [Q1765120]
# 10                                          None                  None
# 11                                      [Q10230]                  None
# 12                                          None                  None
# 13                   [Q79854, Q4488786, Q151469]           [Q17744738]
# 14                                     [Q241149]                  None
# 15                                          None                  None
# 16                                     [Q241149]                  None
# 17                                          None                  None
# 18                                      [Q29468]                  None
# 21                                          None                  None
#
#           id                                          candidacy  type  \
# 0        Q76  [Q3586671, Q45578, Q4226, Q4791768, Q17067714,...  item
# 1      Q6294                                [Q699872, Q4791768]  item
# 2    Q450675                                               None  item
# 3    Q359442                                               None  item
# 4     Q22316                                          [Q464075]  item
# 5   Q1173911                                               None  item
# 6    Q324546                                               None  item
# 7     Q43723                     [Q2917048, Q2480394, Q2689039]  item
# 8    Q457786                                               None  item
# 9    Q221997                                               None  item
# 10   Q207431                                               None  item
# 11  Q3629480                                        [Q63988621]  item
# 12  Q1093629                                               None  item
# 13     Q7747           [Q19760074, Q488814, Q1505420, Q1348890]  item
# 14   Q348577                                               None  item
# 15  Q1186457                                               None  item
# 16   Q927550                                               None  item
# 17  Q1404825                                               None  item
# 18    Q24313                                               None  item
# 21    Q36159                                               None  item
#
#                                 religion
# 0   [Q23540, Q1062789, Q960252, Q426316]
# 1                               [Q33203]
# 2                                [Q9592]
# 3                                [Q9268]
# 4                                [Q9592]
# 5                                   None
# 6                      [Q1841, Q7361618]
# 7                                [Q9268]
# 8                                   None
# 9                       [Q682443, Q1841]
# 10                                  None
# 11                               [Q9089]
# 12                                  None
# 13                    [Q60995, Q3333484]
# 14                               [Q1841]
# 15                                  None
# 16                               [Q1841]
# 17                                  None
# 18                           [Q13631353]
# 21                                  None

# %%
len(df_merged)
# Out:
# 55070

# %% [markdown]
# ## 3. Regression analysis
