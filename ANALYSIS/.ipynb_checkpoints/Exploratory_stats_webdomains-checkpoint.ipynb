# %% [markdown]
# # Exploratory analysis webdomains aggregations

# %% [markdown]
# This notebook uses newspaper metatdata retrieved using WHOIS requests and classified quotes to show some information about colloquial language use accross quotes sources indicators

# %% [markdown]
# ## 0 Dependencies

# %%
import numpy as np
import pandas as pd
import bz2
import json
import seaborn as sns
import matplotlib.pyplot as plt
from whois import whois
from tqdm import tqdm
tqdm.pandas()

# %%
# Small adjustments to default style of plots, making sure it's readable and colorblind-friendly everywhere
plt.style.use('seaborn-colorblind')
plt.rcParams.update({'font.size' : 14,
                     'figure.figsize':(20,7)})

# %% [markdown]
# ## 1 Data loading

# %% [markdown]
# sample dataset with linguisitc type classification

# %%
df= pd.read_json("/Users/nicolasantacroce/Desktop/Desktop/EPFL/EPFL MA1/Applied Data Analysis/Sample_classified_1Mio_v1.json.bz2",compression="bz2",lines=True)

# %% [markdown]
# extract web domains from urls

# %%
df["domain"]= df['urls'].apply(lambda x: "/".join(x[0].split('/',3)[:3]))

# %% [markdown]
# read domain metadata dataframe

# %%
df_domain= pd.read_pickle("./whois_result.pkl")
df_domain.head(10)
# Out:
#                          domain  count                     org country  \
# 0      http://www.breitbart.com   5220   Domains By Proxy, LLC      US
# 1            http://www.msn.com   4505   Microsoft Corporation      US
# 2      http://home.nzcity.co.nz   4372                    None    None
# 3        http://www.stuff.co.nz   3766                    None    None
# 4      https://www.thesun.co.uk   3726                    None    None
# 5                http://msn.com   3649   Microsoft Corporation      US
# 6          http://express.co.uk   3487                    None    None
# 7            http://mlb.mlb.com   3189  MLB Advanced Media, LP      US
# 8            http://thehill.com   3142                    None      US
# 9  https://www.seattletimes.com   3012   SEATTLE TIMES COMPANY      US
#
#      state          city
# 0  Arizona         Tempe
# 1       WA       Redmond
# 2     None          None
# 3     None          None
# 4     None          None
# 5       WA       Redmond
# 6     None          None
# 7       NY      New York
# 8       FL  Jacksonville
# 9       WA       SEATTLE

# %% [markdown]
# join dataframes

# %%
df= df.join(df_domain.set_index('domain'), on='domain')
del df["count"]
df.head()
# Out:
#              quoteID                                          quotation  \
# 0  2015-11-11-109291  They'll call me lots of different things. Libe...
# 1  2015-09-11-070666  It's kind of the same way it's been with the R...
# 2  2015-11-09-033345  I had a chuckle: They were showing a video of ...
# 3  2015-09-05-038628  New Zealand will go in with a lot of confidenc...
# 4  2015-02-11-042325  In his suicide note he even made a joke thanki...
#
#            speaker                                        qids  \
# 0   Chris Christie                                    [Q63879]
# 1  Niklas Kronwall                                   [Q722939]
# 2      Kris Draper                                   [Q948695]
# 3       John Eales                                   [Q926351]
# 4      Pat Buckley  [Q19956564, Q23006312, Q7143252, Q7143253]
#
#                  date  numOccurrences  \
# 0 2015-11-11 00:55:12               1
# 1 2015-09-11 19:54:00               1
# 2 2015-11-09 00:57:45               3
# 3 2015-09-05 02:40:10               3
# 4 2015-02-11 09:59:09               1
#
#                                               probas  \
# 0  [[Chris Christie, 0.7395], [Bobby Jindal, 0.15...
# 1  [[Niklas Kronwall, 0.7119], [None, 0.2067], [H...
# 2  [[Kris Draper, 0.8782], [None, 0.1043], [Serge...
# 3  [[John Eales, 0.7896], [None, 0.2006], [Toutai...
# 4            [[Pat Buckley, 0.8816], [None, 0.1184]]
#
#                                                 urls phase      p1      p2  \
# 0  [http://thehill.com/blogs/ballot-box/259760-ch...     E  0.7395  0.1505
# 1  [http://redwings.nhl.com/club/news.htm?id=7787...     E  0.7119  0.2067
# 2  [http://ca.rd.yahoo.com/sports/rss/nfl/SIG=13u...     E  0.8782  0.1043
# 3  [http://www.stuff.co.nz/sport/rugby/all-blacks...     E  0.7896  0.2006
# 4  [http://independent.ie/life/health-wellbeing/m...     E  0.8816  0.1184
#
#    delta_p  year  colloquial                   domain                   org  \
# 0   0.5890  2015           0       http://thehill.com                  None
# 1   0.5052  2015           0  http://redwings.nhl.com  REDACTED FOR PRIVACY
# 2   0.7739  2015           1   http://ca.rd.yahoo.com                  None
# 3   0.5890  2015           0   http://www.stuff.co.nz                  None
# 4   0.7632  2015           1    http://independent.ie                  None
#
#   country state                  city
# 0      US    FL          Jacksonville
# 1      US    NY  REDACTED FOR PRIVACY
# 2    None  None                  None
# 3    None  None                  None
# 4    None  None                  None

# %% [markdown]
# ## 2 Getting percent of colloquial quotes by organisation

# %% [markdown]
# create dataframe

# %%
#create a small dataframe with number of colloquial quotes per organisation
df_org_sum= (df[["org","colloquial"]][df["org"].apply(lambda x: isinstance(x, str))]).groupby(["org"])\
.apply(lambda x : x.sum()).sort_values(["colloquial"], ascending=False)
del df_org_sum["org"]
#create a small dataframe with number of quotes per organisation
df_org_count= (df[["org","colloquial"]][df["org"].apply(lambda x: isinstance(x, str))]).groupby(["org"])\
.apply(lambda x : x.count()).sort_values(["colloquial"], ascending=False)
del df_org_count["org"]
#merge dataframes and rename columns
df_grouped_org= pd.merge(df_org_count, df_org_sum, left_index=True, right_index=True).reset_index()
df_grouped_org["colloquial_share"]= df_grouped_org["colloquial_y"]/df_grouped_org["colloquial_x"]
df_grouped_org.rename(columns = {"colloquial_x":'count', 'colloquial_y':'sum'}, inplace = True)
df_grouped_org.head()
# Out:
#                                                  org  count   sum  \
# 0                               REDACTED FOR PRIVACY  29093  8934
# 1                              Domains By Proxy, LLC  17518  5966
# 2                              Whois Privacy Service  10431  3403
# 3  Privacy service provided by Withheld for Priva...   9651  3496
# 4                               MediaNews Group, Inc   7616  2016
#
#    colloquial_share
# 0          0.307084
# 1          0.340564
# 2          0.326239
# 3          0.362242
# 4          0.264706

# %% [markdown]
# plot results

# %%
ax = sns.barplot(x="org", y="colloquial_share",data=df_grouped_org[1:20])
plt.xticks(rotation=60, ha='right')
ax.set(ylabel='Number of quotations',xlabel="Registered Organisation")
# Out:
# [Text(0, 0.5, 'Number of quotations'), Text(0.5, 0, 'Registered Organisation')]

# %% [markdown]
# We can observe that domains organisations often remain anonymous. It seems that anonymous organisations use more colloquial language than other.

# %% [markdown]
# ## 3 Getting percent of colloquial quotes by country

# %% [markdown]
# create dataframe

# %%
#create a small dataframe with number of colloquial quotes per country
df_country_sum= (df[["country","colloquial"]][df["country"].apply(lambda x: isinstance(x, str))]).groupby(["country"])\
.apply(lambda x : x.sum()).sort_values(["colloquial"], ascending=False)
del df_country_sum["country"]
#create a small dataframe with number of quotes per country
df_country_count= (df[["country","colloquial"]][df["country"].apply(lambda x: isinstance(x, str))]).groupby(["country"])\
.apply(lambda x : x.count()).sort_values(["colloquial"], ascending=False)
del df_country_count["country"]
#merge dataframes and rename columns
df_grouped_country= pd.merge(df_country_count, df_country_sum, left_index=True, right_index=True).reset_index()
df_grouped_country["colloquial_share"]= df_grouped_country["colloquial_y"]/df_grouped_country["colloquial_x"]
df_grouped_country.rename(columns = {"colloquial_x":'count', 'colloquial_y':'sum'}, inplace = True)
df_grouped_country.head()
# Out:
#   country   count    sum  colloquial_share
# 0      US  246539  74769          0.303275
# 1      CA   19783   6836          0.345549
# 2      IN   17276   7500          0.434128
# 3      GB   15602   5308          0.340213
# 4      IS    9672   3503          0.362179

# %% [markdown]
# plot results

# %%
ax = sns.barplot(x="country", y="colloquial_share",data=df_grouped_country[:20])
plt.xticks(rotation=60, ha='right')
ax.set(ylabel='Number of quotations',xlabel="Registered Country")
# Out:
# [Text(0, 0.5, 'Number of quotations'), Text(0.5, 0, 'Registered Country')]

# %% [markdown]
# We can observe similar rates in countries where English is the main language. It seems that Indian and Filipino newspaper use more colloquial language than others. European countries where English is not the main language also seem to have similar rates.

# %% [markdown]
# ## 4 Getting percent of colloquial quotes by state

# %% [markdown]
# create dataframe

# %%
#create a small dataframe with number of colloquial quotes per state
df_state_sum= (df[["state","colloquial"]][df["state"].apply(lambda x: isinstance(x, str))]).groupby(["state"])\
.apply(lambda x : x.sum()).sort_values(["colloquial"], ascending=False)
del df_state_sum["state"]
#create a small dataframe with number of quotes per state
df_state_count= (df[["state","colloquial"]][df["state"].apply(lambda x: isinstance(x, str))]).groupby(["state"])\
.apply(lambda x : x.count()).sort_values(["colloquial"], ascending=False)
del df_state_count["state"]
#merge dataframes and rename columns
df_grouped_state= pd.merge(df_state_count, df_state_sum, left_index=True, right_index=True).reset_index()
df_grouped_state["colloquial_share"]= df_grouped_state["colloquial_y"]/df_grouped_state["colloquial_x"]
df_grouped_state.rename(columns = {"colloquial_x":'count', 'colloquial_y':'sum'}, inplace = True)
df_grouped_state.head()
# Out:
#      state  count    sum  colloquial_share
# 0       NY  49658  14429          0.290567
# 1       WA  20646   6491          0.314395
# 2       CA  20395   6742          0.330571
# 3  Arizona  18572   6297          0.339059
# 4       ON  14315   5025          0.351030

# %% [markdown]
# plot results

# %%
ax = sns.barplot(x="state", y="colloquial_share",data=df_grouped_state[1:20])
plt.xticks(rotation=60, ha='right')
ax.set(ylabel='Number of quotations',xlabel="Registered State")
# Out:
# [Text(0, 0.5, 'Number of quotations'), Text(0.5, 0, 'Registered State')]

# %% [markdown]
# Could be interesting to compare accross US states as it is the most represented country

# %% [markdown]
# ## 5 Getting percent of colloquial quotes by city

# %% [markdown]
# create dataframe

# %%
#create a small dataframe with number of colloquial quotes per city
df_city_sum= (df[["city","colloquial"]][df["city"].apply(lambda x: isinstance(x, str))]).groupby(["city"])\
.apply(lambda x : x.sum()).sort_values(["colloquial"], ascending=False)
del df_city_sum["city"]
#create a small dataframe with number of quotes per city
df_city_count= (df[["city","colloquial"]][df["city"].apply(lambda x: isinstance(x, str))]).groupby(["city"])\
.apply(lambda x : x.count()).sort_values(["colloquial"], ascending=False)
del df_city_count["city"]
#merge dataframes and rename columns
df_grouped_city= pd.merge(df_city_count, df_city_sum, left_index=True, right_index=True).reset_index()
df_grouped_city["colloquial_share"]= df_grouped_city["colloquial_y"]/df_grouped_city["colloquial_x"]
df_grouped_city.rename(columns = {"colloquial_x":'count', 'colloquial_y':'sum'}, inplace = True)
df_grouped_city.head()
# Out:
#                    city  count    sum  colloquial_share
# 0  REDACTED FOR PRIVACY  41029  12935          0.315265
# 1              New York  29608   8538          0.288368
# 2                 Tempe  16510   5565          0.337068
# 3                Denver  13152   3612          0.274635
# 4               Toronto  11234   4125          0.367189

# %% [markdown]
# plot results

# %%
ax = sns.barplot(x="city", y="colloquial_share",data=df_grouped_city[1:20])
plt.xticks(rotation=60, ha='right')
ax.set(ylabel='Number of quotations',xlabel="Registered City")
# Out:
# [Text(0, 0.5, 'Number of quotations'), Text(0.5, 0, 'Registered City')]

# %% [markdown]
# Could be used to generate some kind of world map of colloquial language use
