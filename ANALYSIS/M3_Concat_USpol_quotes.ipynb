# %% [markdown]
# This notebook is use to concatenate the files per year

# %%
#importing the required modules
import seaborn as sns
from IPython.display import display, HTML
import matplotlib.pyplot as plt
import scipy.stats as stats
import pandas as pd
import numpy as np
import seaborn as sns

# %%
#Concatenate files 

path = r'/Users/jules/kDrive/onedrive/Documents_Onedrive/EPFL/MA3/ADA/Project/Dataset/BIG_SAMPLE/Results_LR/'

df = pd.DataFrame()
for year in range(2015,2021,1):
    file_path = path +'df_LR_'+ str(year)+'.json.bz2'
    try:
        df_temp = pd.read_json(file_path,compression = 'bz2',lines = True)
        df = pd.concat([df, df_temp])
    except:
        print(file_path)

# %%
df
# Out:
#                   quoteID                                          quotation  \
# 0       2015-04-16-012993                  Come, Son, Let Me Tell You A Lie,
# 1       2015-05-09-008197  Everybody grieves in their own way. I just wan...
# 2       2015-07-31-011595  But a vast minority of sex assault victims are...
# 3       2015-11-05-133940  We are running major law offices with major re...
# 4       2015-12-23-026592  I did footings, I did walls. Right now, I'm up...
# ...                   ...                                                ...
# 112073  2020-03-12-051570  People in this area are very in tune with what...
# 112074  2020-03-01-037715                    to help spread facts, not fear.
# 112075  2020-03-21-041323  We knew that we needed to do more to protect o...
# 112076  2020-01-28-083318                   the Sheriff has enriched himself
# 112077  2020-01-28-018941  Fantastic sound quality, pairs easily. Works w...
#
#                   speaker qid_unique                date  \
# 0          Robert Johnson  Q16215328 2015-04-16 12:17:09
# 1          Robert Johnson  Q16215328 2015-05-09 09:25:48
# 2          Robert Johnson  Q16215328 2015-07-31 15:21:13
# 3          Robert Johnson  Q16215328 2015-11-05 07:30:00
# 4          Robert Johnson  Q16215328 2015-12-23 14:38:25
# ...                   ...        ...                 ...
# 112073     Marge Anderson   Q6760269 2020-03-12 04:29:22
# 112074  Sabrina Cervantes  Q27890015 2020-03-01 01:42:05
# 112075         Luis Alejo   Q6700297 2020-03-21 19:42:48
# 112076     Joel Robideaux   Q6213896 2020-01-28 00:28:26
# 112077     Justin Everett  Q16210933 2020-01-28 01:00:31
#
#                                                      urls      p1      p2  \
# 0       [http://mysanantonio.com/entertainment/article...  0.6719  0.2895
# 1       [http://www.foxbaltimore.com/news/features/top...  0.6130  0.2622
# 2       [http://pix11.com/2015/07/31/men-convicted-of-...  0.9152  0.0848
# 3       [http://www.nydailynews.com/new-york/exclusive...  0.7218  0.2288
# 4       [http://www.mprnews.org/story/2015/10/23/vikes...  0.7711  0.1818
# ...                                                   ...     ...     ...
# 112073  [https://www.recorder.com/b1-Northfield-trash-...  0.8344  0.1656
# 112074  [https://mynewsla.com/business/2020/02/29/offi...  0.8328  0.1561
# 112075  [https://www.montereyherald.com/2020/03/21/cov...  0.8260  0.1582
# 112076  [https://www.katc.com/news/lafayette-parish/lp...  0.7743  0.2182
# 112077  [https://www.buzzfeed.com/yiyang/valentines-da...  0.9249  0.0752
#
#         delta_p  year  ...  US_congress_bio_ID        occupation       party  \
# 0        0.3824  2015  ...                None  [Q40348, Q82955]    [Q29552]
# 1        0.3508  2015  ...                None  [Q40348, Q82955]    [Q29552]
# 2        0.8304  2015  ...                None  [Q40348, Q82955]    [Q29552]
# 3        0.4930  2015  ...                None  [Q40348, Q82955]    [Q29552]
# 4        0.5893  2015  ...                None  [Q40348, Q82955]    [Q29552]
# ...         ...   ...  ...                 ...               ...         ...
# 112073   0.6688  2020  ...                None          [Q82955]        None
# 112074   0.6767  2020  ...                None          [Q82955]  [Q5020399]
# 112075   0.6678  2020  ...                None  [Q40348, Q82955]    [Q29552]
# 112076   0.5561  2020  ...                None  [Q82955, Q43845]    [Q29468]
# 112077   0.8497  2020  ...                None          [Q82955]    [Q29468]
#
#         academic_degree         id candidacy  type religion   age    bi_party
# 0                  None  Q16215328      None  item     None  46.0    Democrat
# 1                  None  Q16215328      None  item     None  46.0    Democrat
# 2                  None  Q16215328      None  item     None  46.0    Democrat
# 3                  None  Q16215328      None  item     None  46.0    Democrat
# 4                  None  Q16215328      None  item     None  46.0    Democrat
# ...                 ...        ...       ...   ...      ...   ...         ...
# 112073             None   Q6760269      None  item     None  89.0        None
# 112074             None  Q27890015      None  item     None  34.0        None
# 112075             None   Q6700297      None  item     None  47.0    Democrat
# 112076             None   Q6213896      None  item     None  59.0  Republican
# 112077             None  Q16210933      None  item     None  50.0  Republican
#
# [564658 rows x 28 columns]

# %%
df.to_json(path+'df_all.json.bz2',compression='bz2',lines=True,orient="records")
