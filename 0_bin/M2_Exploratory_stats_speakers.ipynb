# %% [markdown]
# # Exploratory analysis speakers aggregations

# %% [markdown]
# This notebook has a similar structure that Retrieve_metadata `(SPEAKERS_METADATA/Retrieve_metadata.ipynb)`.
#
# However, it uses the results of classification step (extract quotations with colloquial langage) to perform an aggregation on speakers and apply an exploratory analysis. This notebook is the first iterative step in exploring the data on speakers aggregations. It does not consitutes any relevant statistical results and have to be considered only in a "exploratory way".

# %% [markdown]
# ***Important remark:*** due to their large size, the samples of data have been retrieve in local. Therefore, if you do not have the sample, do not run the cells but only inspect the results of each cell that have been runned.

# %%
#importing the required modules
import seaborn as sns
from IPython.display import display, HTML
import matplotlib.pyplot as plt
import scipy.stats as stats
import pandas as pd
import numpy as np
import seaborn as sns

# %%
# Small adjustments to default style of plots, making sure it's readable and colorblind-friendly everywhere
plt.style.use('seaborn-colorblind')
plt.rcParams.update({'font.size' : 12.5,
                     'figure.figsize':(25,7)})

# %% [markdown]
# ## 1. Import data

# %% [markdown]
# ### Metadata

# %% [markdown]
# Pandas requires pyarrow to read parquet files, which can be installed using conda install pyarrow -c conda-forge.
# You can load this file as a pandas dataframe using df = pd.read_parquet(<path_to_file>).

# %%
#Define the path for folder containing data
#TO BE MODIFIED ACCORDING HIS OWN FOLER containing data in local 
#Jules:
path = r'/Users/jules/kDrive/onedrive/Documents_Onedrive/EPFL/MA3/ADA/Project/Dataset/'
df_metadata = pd.read_parquet(path+'speaker_attributes.parquet')
#df_metadata.head()

# %% [markdown]
# ### Quotations dataset

# %%
#Import the dataset sample

#Jules: 
path = r'/Users/jules/kDrive/onedrive/Documents_Onedrive/EPFL/MA3/ADA/Project/Dataset/'

df_sample = pd.read_json(path+'Sample_classified_1Mio_v1.json.bz2',compression = 'bz2',lines = True)

# %%
df_sample.sample(20)
# Out:
#                   quoteID                                          quotation  \
# 229467  2016-04-20-073091          I've always identified with Libertarians,
# 10219   2015-04-17-038621  I'm enjoying watching him play. I'm really pro...
# 611030  2020-02-11-029916  I did that last year and I sort of found I slo...
# 466618  2019-06-13-023680  Getting some rest and some treatment is the be...
# 442017  2019-06-24-056377  Might be a mad house but it's home and I love ...
# 28039   2015-10-15-046630  I never thought I'd be walking through the doo...
# 100407  2015-04-01-053621  I've never been comfortable with it. From the ...
# 472494  2019-08-25-024238          It's a new kind of audio-visual language,
# 2257    2015-11-08-053872  The only consolation with a move of this small...
# 621682  2020-02-06-096691  The world has started to understand our narrat...
# 267691  2017-10-04-164665  We should not be selling guns of mass destruct...
# 133075  2016-05-25-113909  This entire Sie Complex is going to allow us t...
# 495506  2019-03-26-060274  I've just got to put forth the effort and keep...
# 369114  2018-03-10-058331  Over the years I've stared in the eyes of the ...
# 147732  2016-09-30-139372        We're feeling very positive about our entry
# 558029  2020-04-16-052868  They're just so far back, so I'm having troubl...
# 211325  2016-09-16-097299  That's why someone like Trump has had success,...
# 462029  2019-03-03-029729                  Just check their Instagram pages!
# 540550  2020-02-20-036610  In his mind, to rank the teams right now, it w...
# 626624  2020-03-24-062709  The homeowner can apply for one mortgage assis...
#
#                   speaker                                               qids  \
# 229467          Rand Paul                                          [Q463557]
# 10219       Daniel Briere                                [Q3013801, Q960831]
# 611030        Dillon Hunt                                        [Q45342407]
# 466618          Ken Giles                                        [Q16929691]
# 442017       Tina O'Brien                                         [Q4340888]
# 28039           Bob Saget                                          [Q333544]
# 100407      Chris Trapper                                         [Q5108302]
# 472494  Christian Marclay                                          [Q923306]
# 2257          Bill Cahill                                        [Q28016763]
# 621682         Imran Khan  [Q155164, Q15987686, Q1660487, Q17306146, Q183...
# 267691     Alan Lowenthal                                         [Q3740782]
# 133075   Christopher Hill                   [Q1086743, Q26263308, Q52891045]
# 495506    Dennis Robinson                                        [Q18747793]
# 369114         Wayne Swan                                         [Q1236571]
# 147732     Edward Garnier                                          [Q334339]
# 558029       Ian Rapoport                                        [Q20685256]
# 211325           Bob Dole                                          [Q319079]
# 462029         Rob Wilson  [Q16152044, Q23092173, Q262108, Q52855846, Q55...
# 540550      Adam Schefter                                         [Q4679729]
# 626624        David Scott  [Q132071, Q16235821, Q16302033, Q21229786, Q27...
#
#                       date  numOccurrences  \
# 229467 2016-04-20 00:19:05               1
# 10219  2015-04-17 16:45:32               3
# 611030 2020-02-11 15:30:00               2
# 466618 2019-06-13 03:38:18               3
# 442017 2019-06-24 14:31:04               1
# 28039  2015-10-15 19:14:23               1
# 100407 2015-04-01 21:46:08               1
# 472494 2019-08-25 12:00:00               1
# 2257   2015-11-08 03:03:53               3
# 621682 2020-02-06 00:10:35               1
# 267691 2017-10-04 21:52:35               1
# 133075 2016-05-25 13:30:55               1
# 495506 2019-03-26 03:47:23               2
# 369114 2018-03-10 05:01:35               1
# 147732 2016-09-30 11:30:09               1
# 558029 2020-04-16 15:03:10               1
# 211325 2016-09-16 19:00:53               2
# 462029 2019-03-03 13:00:26               1
# 540550 2020-02-20 14:25:19               2
# 626624 2020-03-24 00:00:00               1
#
#                                                    probas  \
# 229467  [[Rand Paul, 0.7422], [None, 0.2477], [Bernie ...
# 10219   [[Daniel Briere, 0.747], [None, 0.1953], [Jean...
# 611030            [[Dillon Hunt, 0.9195], [None, 0.0805]]
# 466618  [[Ken Giles, 0.7707], [None, 0.182], [Charlie ...
# 442017  [[Tina O'Brien, 0.9359], [None, 0.0587], [Lace...
# 28039   [[Bob Saget, 0.9462], [None, 0.0425], [Jeff Fr...
# 100407          [[Chris Trapper, 0.7253], [None, 0.2747]]
# 472494      [[Christian Marclay, 0.9436], [None, 0.0564]]
# 2257              [[Bill Cahill, 0.9372], [None, 0.0628]]
# 621682             [[Imran Khan, 0.8612], [None, 0.1388]]
# 267691  [[Alan Lowenthal, 0.7252], [None, 0.2387], [Bi...
# 133075  [[Christopher Hill, 0.7099], [None, 0.2596], [...
# 495506  [[Dennis Robinson, 0.7413], [None, 0.2544], [D...
# 369114  [[Wayne Swan, 0.794], [None, 0.1791], [Mark Bu...
# 147732         [[Edward Garnier, 0.7202], [None, 0.2798]]
# 558029  [[Ian Rapoport, 0.6448], [None, 0.3074], [Chri...
# 211325  [[Bob Dole, 0.6437], [None, 0.3295], [Donald T...
# 462029             [[Rob Wilson, 0.8834], [None, 0.1166]]
# 540550  [[Adam Schefter, 0.7644], [None, 0.2106], [Ric...
# 626624            [[David Scott, 0.9121], [None, 0.0879]]
#
#                                                      urls phase      p1  \
# 229467  [http://www.centredaily.com/news/politics-gove...     E  0.7422
# 10219   [http://scores.espn.go.com/blog/nhl/post/_/id/...     E  0.7470
# 611030  [http://www.odt.co.nz/sport/rugby/highlanders/...     E  0.9195
# 466618  [http://o.canada.com/sports/baseball/toronto-b...     E  0.7707
# 442017  [http://www.heart.co.uk/showbiz/tv-movies/coro...     E  0.9359
# 28039   [http://boulderweekly.com/article-15106-you-go...     E  0.9462
# 100407  [http://www.vueweekly.com/chris-trapper-search...     E  0.7253
# 472494  [http://feeds.mashable.com/~r/Mashable/~3/6G1h...     E  0.9436
# 2257    [http://www.reporterherald.com/business/ci_290...     E  0.9372
# 621682  [https://arynews.tv/en/pm-imran-to-address-kas...     E  0.8612
# 267691  [https://pjmedia.com/news-and-politics/2017/10...     E  0.7252
# 133075  [https://magazine.du.edu/campus-community/korb...     E  0.7099
# 495506  [http://daily-chronicle.com/2019/03/26/niu-foo...     E  0.7413
# 369114  [https://www.theguardian.com/australia-news/20...     E  0.7940
# 147732  [http://www.harboroughmail.co.uk/news/have-we-...     E  0.7202
# 558029  [https://www.masslive.com/patriots/2020/04/pat...     E  0.6448
# 211325  [http://cjonline.com/news/2016-09-16/bob-dole-...     E  0.6437
# 462029  [https://azbigmedia.com/do-entitled-millennial...     E  0.8834
# 540550  [https://thespun.com/more/top-stories/tom-brad...     E  0.7644
# 626624  [http://www.fox5atlanta.com/news/georgia-lawma...     E  0.9121
#
#             p2  delta_p  year  colloquial
# 229467  0.2477   0.4945  2016           0
# 10219   0.1953   0.5517  2015           0
# 611030  0.0805   0.8390  2020           0
# 466618  0.1820   0.5887  2019           0
# 442017  0.0587   0.8772  2019           1
# 28039   0.0425   0.9037  2015           0
# 100407  0.2747   0.4506  2015           0
# 472494  0.0564   0.8872  2019           0
# 2257    0.0628   0.8744  2015           0
# 621682  0.1388   0.7224  2020           1
# 267691  0.2387   0.4865  2017           1
# 133075  0.2596   0.4503  2016           0
# 495506  0.2544   0.4869  2019           0
# 369114  0.1791   0.6149  2018           1
# 147732  0.2798   0.4404  2016           0
# 558029  0.3074   0.3374  2020           0
# 211325  0.3295   0.3142  2016           0
# 462029  0.1166   0.7668  2019           0
# 540550  0.2106   0.5538  2020           1
# 626624  0.0879   0.8242  2020           1

# %% [markdown]
# ### Lookup table for QIDs

# %% [markdown]
# #### Using the provided csv file to link qids with meaningful names

# %%
#read the file 
df_lookup = pd.read_csv('wikidata_labels_descriptions_quotebank.csv.bz2',compression = 'bz2',index_col='QID')
#df_lookup.sample(20)

# %% [markdown]
# ### 2. Merge speakers metadata with quotations

# %% [markdown]
# Join quotations data with metadata :

# %%
#Create sub-sample
#df_sub = df_sample.sample(int(1*10e3))
df_sub = df_sample.copy()
s1 = len(df_sub)

#For the moment, choose rows which at minimum 1 qid associated
#Remove this row when using the data that have been wrangled
df_sub = df_sub[[len(a)>0 for a in df_sub['qids']]]

s2 = len(df_sub)

print('There is {} % of rows that have no qid associated with (on {} rows)'.format((1-s2/s1)*100,s1))

#Choose the first QID that is associated with (to be improved)
df_sub['qid_unique'] = df_sub['qids'].apply(lambda x: x[0])
# Out:
# There is 0.0 % of rows that have no qid associated with (on 668534 rows)

# %%
#Perform a group_by on quotations by speaker 
df_grouped = df_sub.groupby(['qid_unique', 'colloquial']).size().unstack(fill_value=0).reset_index()
df_grouped['quotes_number'] = df_grouped[1]+df_grouped[0]
df_grouped.sort_values(['quotes_number'], ascending=False) 

# Create also a column (called "fraction") that computes the fraction of colloquial quotes over total quotations. (by speaker)
df_grouped['fraction']=df_grouped[1]/(df_grouped['quotes_number'])
df_grouped.reset_index().sort_values(['fraction'], ascending=False)
# Out:
# colloquial   index qid_unique  0  1  quotes_number  fraction
# 173959      173959    Q999889  0  1              1       1.0
# 104293      104293   Q4696730  0  1              1       1.0
# 31944        31944   Q1740079  0  1              1       1.0
# 104288      104288   Q4696700  0  1              1       1.0
# 31948        31948   Q1740086  0  1              1       1.0
# ...            ...        ... .. ..            ...       ...
# 102323      102323  Q45561071  1  0              1       0.0
# 102319      102319  Q45558354  1  0              1       0.0
# 32878        32878  Q17564389  1  0              1       0.0
# 32879        32879  Q17564409  1  0              1       0.0
# 114295      114295  Q50365960  1  0              1       0.0
#
# [173960 rows x 6 columns]

# %%
#Merging with metadata

df_merged = df_grouped.merge(df_metadata,how='inner',left_on='qid_unique', right_on='id').sort_values(['quotes_number'], ascending=False)

# %%
#Replace label column at the first place to see speakers names

# shift column 'Name' to first position
first_column = df_merged.pop('label')
# insert column using insert(position,column_name,first_column) function
df_merged.insert(0, 'label', first_column)
df_merged.head(20)
print('There are {} speakers'.format(len(df_merged)))
# Out:
# There are 107413 speakers

# %% [markdown]
# ## 3. Exploratory analysis

# %%
col_subset = ['gender','nationality','occupation']
# data wrangling : remove NaNs, speakers that does not contains the specified metadata feature
df_plot = df_merged.copy()
df_plot.dropna(axis = 0, subset=col_subset,inplace=True)

for col in col_subset: 
    #For the moment, only taking the first item that is on the list
    df_plot[col]= df_plot[col].apply(lambda x:x[0])

# %% [markdown]
# - Distribution of colloquial quotes fraction:

# %%
array_100 = plt.hist(df_plot['fraction'],bins=100,log=True)
plt.title('Histogram of colloquial quotes fraction per speaker')
plt.xlabel('Colloquial quotes fraction [0-1]')
plt.ylabel('Number of speakers')
# Out:
# Text(0, 0.5, 'Number of speakers')

# %% [markdown]
# It appears that a large number of speakers has a colloquial fraction equals to 0 or 1. These speakers correspond to the ones which have only 1 quote associated with. Therefore, their colloquial fraction could be only equals to 0 and 1. After a quick look, it appears that the same phenomena is osberved for fraction of integers.(1/2, 2/5)
#
# For the next of the analysis, we will probably remove speakers that have only few quotes attributed.

# %% [markdown]
# - Fraction of colloquial language of 10 most represented speakers

# %%
ax = sns.barplot(x="label", y="fraction",data=df_plot[:9])
ax.set_title('Fraction of colloquial language of 10 most represented speakers')
ax.set(xlabel='Speaker name',ylabel='Fraction of colloquial quotes')
# Out:
# [Text(0.5, 0, 'Speaker name'), Text(0, 0.5, 'Fraction of colloquial quotes')]

# %% [markdown]
# Observing this plot, it underlines the fact that the more speaker is represented, the more his colloquial fraction tends to the average of the whole dataset. This statement underlines the weakness of the classification procedure.

# %% [markdown]
# - Fraction of colloquial langage by gender :

# %%
df_gender = df_plot.groupby('gender')['fraction'].mean() \
            .reset_index(name='mean_fraction')

df_gender['gender'] = df_gender['gender'].apply(lambda x: df_lookup.loc[x]['Label'])
df_gender = df_gender.set_index('gender')
df_mf = df_gender.loc[['male','female']].reset_index()

ax = sns.barplot(x='gender', y="mean_fraction", data=df_mf)
ax.set(ylabel='Average fraction of colloquial quotations')
# Out:
# [Text(0, 0.5, 'Average fraction of colloquial quotations')]

# %%
# fraction per occupation

df_occupation = df_plot.groupby('occupation')['fraction'].mean() \
                .reset_index(name='mean_fraction')\
                .sort_values(['mean_fraction'], ascending=False)

df_occupation['occupation'] = df_occupation['occupation'].apply(lambda x: df_lookup.loc[x]['Label'])

#Not taking in account the occupation with fraction equals to 1 (correspond to speakers with not sufficient amount of quotations)

df_test = df_occupation[df_occupation['mean_fraction']!=1]

ax = sns.barplot(x="occupation", y="mean_fraction", data=df_test[:5])
ax.set(xlabel='speaker_occupation',ylabel='Colloquial quotes fraction')
# Out:
# [Text(0.5, 0, 'speaker_occupation'),
#  Text(0, 0.5, 'Colloquial quotes fraction')]

# %% [markdown]
# We can't derive anything from this plot above as we do not have the number of quotations in each occupation category. Then, the retrieval of the relative size of each category hasto be computed. However, it shows the possibilities from this speaker's aggregation and the different conclusions could be drawn thank to these metadata.

# %% [markdown]
# **Conclusion** :
# These results could not give meaningful interpretations for now. Indeed, the classification method has to be improved. The main problem that seems to arise is the too large size (20 000 entries) of the informal dictionary used for classification. In next step, the dictionnary has to be filtered to keep only the terms that clearly distinguish informal/colloquial langage. It has to be avoid the terms that lies in the two categories. Additionnaly, the speakers with a too low number of quotations has to be filtered as their aggregation could biased the result.

# %% [markdown]
# ### Export the dataframe in a file

# %%
df_merged.head()
# Out:
#                   label qid_unique     0    1  quotes_number  fraction  \
# 102255     Barack Obama        Q76  1008  359           1367  0.262619
# 55163    Bernie Sanders    Q359442   723  268            991  0.270434
# 62477           Francis    Q450675   641  271            912  0.297149
# 90835   Hillary Clinton      Q6294   645  245            890  0.275281
# 2501       Andrew Cuomo     Q11673   476  182            658  0.276596
#
#                                                   aliases  \
# 102255  [Barack Hussein Obama II, Barack Obama II, Bar...
# 55163                                   [Bernard Sanders]
# 62477   [Jorge Mario Bergoglio, Francisco, Pope Franci...
# 90835   [Hillary Rodham Clinton, Hillary Rodham, Hilla...
# 2501                                  [Andrew Mark Cuomo]
#
#                   date_of_birth   nationality      gender   lastrevid  \
# 102255  [+1961-08-04T00:00:00Z]         [Q30]  [Q6581097]  1395141963
# 55163   [+1941-09-08T00:00:00Z]         [Q30]  [Q6581097]  1392561607
# 62477   [+1936-12-17T00:00:00Z]  [Q237, Q414]  [Q6581097]  1396054797
# 90835   [+1947-10-26T00:00:00Z]         [Q30]  [Q6581072]  1393846565
# 2501    [+1957-12-06T00:00:00Z]         [Q30]  [Q6581097]  1393197828
#
#                                    ethnic_group US_congress_bio_ID  \
# 102255  [Q49085, Q6935055, Q12826303, Q6392846]            O000167
# 55163                                   [Q7325]            S000033
# 62477                                [Q1056744]               None
# 90835                                      None            C001041
# 2501                                  [Q974693]               None
#
#                                                occupation  \
# 102255    [Q82955, Q40348, Q15958642, Q28532974, Q372436]
# 55163   [Q82955, Q1930187, Q154549, Q1622272, Q36180, ...
# 62477   [Q63173086, Q593644, Q104050302, Q36180, Q1234...
# 90835   [Q82955, Q40348, Q193391, Q36180, Q18814623, Q...
# 2501                                     [Q40348, Q82955]
#
#                                                party       academic_degree  \
# 102255                                      [Q29552]  [Q1765120, Q1540185]
# 55163   [Q6542163, Q29552, Q327591, Q327591, Q29552]            [Q1765120]
# 62477                                           None            [Q1233889]
# 90835                               [Q29552, Q29468]   [Q163727, Q1540185]
# 2501                                        [Q29552]            [Q1540185]
#
#              id                                          candidacy  type  \
# 102255      Q76  [Q3586671, Q45578, Q4226, Q4791768, Q17067714,...  item
# 55163   Q359442                                               None  item
# 62477   Q450675                                               None  item
# 90835     Q6294                                [Q699872, Q4791768]  item
# 2501     Q11673                             [Q22023432, Q65047185]  item
#
#                                     religion
# 102255  [Q23540, Q1062789, Q960252, Q426316]
# 55163                                [Q9268]
# 62477                                [Q9592]
# 90835                               [Q33203]
# 2501                                 [Q1841]

# %%
df_merged.to_json(path+'Speakers_aggregation.json.bz2',compression='bz2',lines=True,orient="records")

# %%
#Test to see if the dataframe has been correctly converted in json

df_result = pd.read_json(path+'Speakers_aggregation.json.bz2',compression = 'bz2',lines = True)

# %%
df_result.head()
# Out:
#              label qid_unique     0    1  quotes_number  fraction  \
# 0     Barack Obama        Q76  1008  359           1367  0.262619
# 1   Bernie Sanders    Q359442   723  268            991  0.270434
# 2          Francis    Q450675   641  271            912  0.297149
# 3  Hillary Clinton      Q6294   645  245            890  0.275281
# 4     Andrew Cuomo     Q11673   476  182            658  0.276596
#
#                                              aliases            date_of_birth  \
# 0  [Barack Hussein Obama II, Barack Obama II, Bar...  [+1961-08-04T00:00:00Z]
# 1                                  [Bernard Sanders]  [+1941-09-08T00:00:00Z]
# 2  [Jorge Mario Bergoglio, Francisco, Pope Franci...  [+1936-12-17T00:00:00Z]
# 3  [Hillary Rodham Clinton, Hillary Rodham, Hilla...  [+1947-10-26T00:00:00Z]
# 4                                [Andrew Mark Cuomo]  [+1957-12-06T00:00:00Z]
#
#     nationality      gender   lastrevid  \
# 0         [Q30]  [Q6581097]  1395141963
# 1         [Q30]  [Q6581097]  1392561607
# 2  [Q237, Q414]  [Q6581097]  1396054797
# 3         [Q30]  [Q6581072]  1393846565
# 4         [Q30]  [Q6581097]  1393197828
#
#                               ethnic_group US_congress_bio_ID  \
# 0  [Q49085, Q6935055, Q12826303, Q6392846]            O000167
# 1                                  [Q7325]            S000033
# 2                               [Q1056744]               None
# 3                                     None            C001041
# 4                                [Q974693]               None
#
#                                           occupation  \
# 0    [Q82955, Q40348, Q15958642, Q28532974, Q372436]
# 1  [Q82955, Q1930187, Q154549, Q1622272, Q36180, ...
# 2  [Q63173086, Q593644, Q104050302, Q36180, Q1234...
# 3  [Q82955, Q40348, Q193391, Q36180, Q18814623, Q...
# 4                                   [Q40348, Q82955]
#
#                                           party       academic_degree  \
# 0                                      [Q29552]  [Q1765120, Q1540185]
# 1  [Q6542163, Q29552, Q327591, Q327591, Q29552]            [Q1765120]
# 2                                          None            [Q1233889]
# 3                              [Q29552, Q29468]   [Q163727, Q1540185]
# 4                                      [Q29552]            [Q1540185]
#
#         id                                          candidacy  type  \
# 0      Q76  [Q3586671, Q45578, Q4226, Q4791768, Q17067714,...  item
# 1  Q359442                                               None  item
# 2  Q450675                                               None  item
# 3    Q6294                                [Q699872, Q4791768]  item
# 4   Q11673                             [Q22023432, Q65047185]  item
#
#                                religion
# 0  [Q23540, Q1062789, Q960252, Q426316]
# 1                               [Q9268]
# 2                               [Q9592]
# 3                              [Q33203]
# 4                               [Q1841]

# %%
nan_number = df_result['party'].isnull().sum()

print("There is {} NANs (over {} rows) in the party column ".format(nan_number, len(df_result)))
# Out:
# There is 94468 NANs (over 107413 rows) in the party column

# %%
df_result['party']
# Out:
# 0                                             [Q29552]
# 1         [Q6542163, Q29552, Q327591, Q327591, Q29552]
# 2                                                 None
# 3                                     [Q29552, Q29468]
# 4                                             [Q29552]
#                               ...
# 107408                                            None
# 107409                                       [Q205150]
# 107410                                            None
# 107411                                            None
# 107412                                            None
# Name: party, Length: 107413, dtype: object
