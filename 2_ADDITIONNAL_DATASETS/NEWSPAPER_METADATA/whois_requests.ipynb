# %% [markdown]
# # WHOIS requests on the first URL of each quote

# %% [markdown]
# ## 0 Needed packages and functions

# %% [markdown]
# ### 0.1 Importing needed packages

# %%
import numpy as np
import pandas as pd
import bz2
import json
import seaborn as sns
import matplotlib.pyplot as plt
from whois import whois
from tqdm import tqdm
tqdm.pandas()

# %% [markdown]
# ### 0.2 Function to perform WHOIS request

# %%
def tryandget(url):
    try:
        who= whois(url)
        return [who.org, who.country, who.state, who.city]
    except:
        pass
    return [None, None, None, None]

# %% [markdown]
# ### 0.3 Plots format

# %%
# Small adjustments to default style of plots, making sure it's readable and colorblind-friendly everywhere
plt.style.use('seaborn-colorblind')
plt.rcParams.update({'font.size' : 14,
                     'figure.figsize':(20,7)})

# %% [markdown]
# ## 1 Data preparation for request

# %% [markdown]
# ### 1.1 Reading sample data

# %%
df= pd.read_json("/Users/nicolasantacroce/Desktop/Desktop/EPFL/EPFL MA1/Applied Data Analysis/Sample.json.bz2",compression="bz2",lines=True)

# %% [markdown]
# ### 1.2 Extracting domains from urls

# %%
df["domain"]= df['urls'].apply(lambda x: "/".join(x[0].split('/',3)[:3]))

# %% [markdown]
# ### 1.3 Creating a dataframe of unique domains

# %%
df_domain= pd.DataFrame(df.value_counts("domain")).reset_index()
df_domain= df_domain.rename(columns={0: "count"})
df_domain.describe()

# %% [markdown]
# ## 2 Getting WHOIS informations

# %% [markdown]
# ### 2.1 Performing WHOIS requests on domains (takes a lot of time)

# %%
df_domain[["org","country","state","city"]]= df_domain["domain"].apply(lambda x: pd.Series(tryandget(x)))

# %% [markdown]
# ### 2.2 Saving domain dataframe to pickle format

# %%
df_domain.to_pickle("./whois_result.pkl")
df_domain.head(10)

# %% [markdown]
# ## 3 Joining WHOIS info to sample data

# %% [markdown]
# ### 3.1 Loading domain dataframe from pickle

# %%
df_domain= pd.read_pickle("./whois_result.pkl")
df_domain.head(10)
# Out:
#                          domain  count                     org country  \
# 0      http://www.breitbart.com   5220   Domains By Proxy, LLC      US
# 1            http://www.msn.com   4505   Microsoft Corporation      US
# 2      http://home.nzcity.co.nz   4372                    None    None
# 3        http://www.stuff.co.nz   3766                    None    None
# 4      https://www.thesun.co.uk   3726                    None    None
# 5                http://msn.com   3649   Microsoft Corporation      US
# 6          http://express.co.uk   3487                    None    None
# 7            http://mlb.mlb.com   3189  MLB Advanced Media, LP      US
# 8            http://thehill.com   3142                    None      US
# 9  https://www.seattletimes.com   3012   SEATTLE TIMES COMPANY      US
#
#      state          city
# 0  Arizona         Tempe
# 1       WA       Redmond
# 2     None          None
# 3     None          None
# 4     None          None
# 5       WA       Redmond
# 6     None          None
# 7       NY      New York
# 8       FL  Jacksonville
# 9       WA       SEATTLE

# %% [markdown]
# ### 3.2 Joining sample data and domain data frame

# %%
df= df.join(df_domain.set_index('domain'), on='domain')
del df["count"]
df.head()
# Out:
#              quoteID                                          quotation  \
# 0  2015-11-11-109291  They'll call me lots of different things. Libe...
# 1  2015-11-04-105046                     The choices are not that easy,
# 2  2015-09-11-070666  It's kind of the same way it's been with the R...
# 3  2015-01-12-082489  We're now going back to the frozen tundra, and...
# 4  2015-11-09-033345  I had a chuckle: They were showing a video of ...
#
#              speaker                  qids                date  \
# 0     Chris Christie              [Q63879] 2015-11-11 00:55:12
# 1           Dr. John  [Q511074, Q54593093] 2015-11-04 18:13:06
# 2    Niklas Kronwall             [Q722939] 2015-09-11 19:54:00
# 3  Frances McDormand             [Q204299] 2015-01-12 01:40:00
# 4        Kris Draper             [Q948695] 2015-11-09 00:57:45
#
#    numOccurrences                                             probas  \
# 0               1  [[Chris Christie, 0.7395], [Bobby Jindal, 0.15...
# 1               2               [[Dr. John, 0.5531], [None, 0.4469]]
# 2               1  [[Niklas Kronwall, 0.7119], [None, 0.2067], [H...
# 3               3  [[Frances McDormand, 0.484], [None, 0.4495], [...
# 4               3  [[Kris Draper, 0.8782], [None, 0.1043], [Serge...
#
#                                                 urls phase  \
# 0  [http://thehill.com/blogs/ballot-box/259760-ch...     E
# 1  [http://delawareonline.com/story/news/health/2...     E
# 2  [http://redwings.nhl.com/club/news.htm?id=7787...     E
# 3  [http://feeds.people.com/~r/people/headlines/~...     E
# 4  [http://ca.rd.yahoo.com/sports/rss/nfl/SIG=13u...     E
#
#                       domain                   org country state  \
# 0         http://thehill.com                  None      US    FL
# 1  http://delawareonline.com     Gannett Co., Inc.      US    VA
# 2    http://redwings.nhl.com  REDACTED FOR PRIVACY      US    NY
# 3    http://feeds.people.com  Meredith Corporation      US    IA
# 4     http://ca.rd.yahoo.com                  None    None  None
#
#                    city
# 0          Jacksonville
# 1                  None
# 2  REDACTED FOR PRIVACY
# 3            Des Moines
# 4                  None

# %% [markdown]
# ## 4 Exploring retrieved metadata representativity

# %% [markdown]
# path to save visualisation plots

# %%
images_path= "/Users/nicolasantacroce/Desktop/Desktop/EPFL/EPFL MA1/Applied Data Analysis/whois_plots/"

# %% [markdown]
# ### 4.1 Registered organisations

# %% [markdown]
# *Number of retrieved organisations names*

# %%
df_org= df_domain[["org","count"]][df_domain["org"].apply(lambda x: isinstance(x, str))].groupby(["org"]).sum().sort_values(["count"], ascending=False).reset_index()
num_unique_org= len(df_org)
print("Number of unique organisations : {}".format(num_unique_org))
# Out:
# Number of unique organisations : 1794

# %% [markdown]
# *20 Most cited organisations in the sample data*

# %%
ax = sns.barplot(x="org", y="count",data=df_org[:20])
plt.xticks(rotation=60, ha='right')
ax.set(ylabel='Number of quotations',xlabel="Registered Organisation")
# Out:
# [Text(0, 0.5, 'Number of quotations'), Text(0.5, 0, 'Registered Organisation')]

# %%
df_pie_org = df_org.copy()[:0]
top_ten= {'org': 'Top Ten', 'count': df_org[:10]['count'].sum()}
new_row = {'org': 'Others', 'count': df_org[10:]['count'].sum()}
df_pie_org = df_pie_org.append(top_ten, ignore_index = True)
df_pie_org = df_pie_org.append(new_row, ignore_index = True)
fig, ax = plt.subplots(1,1)
colors = sns.color_palette("colorblind")
ax.pie(x=df_pie_org['count'],labels=df_pie_org['org'],colors=colors,autopct='%1.f%%',pctdistance=0.6,labeldistance=1.1);
ax.set_title('Distribution of registered organisations')
fig.savefig(images_path+'metadataPlot_org_pie.svg',format = 'svg',bbox_inches='tight')
fig.set_size_inches(8,8)
fig.savefig(images_path+'metadataPlot_org_pie.png',format = 'png',dpi=2000/8,bbox_inches='tight')

# %%
df_pie_org = df_org.copy()
df_pie_org.drop(labels= df_pie_org[10:].index, axis=0,inplace=True)
#new_row = {'org': 'Others', 'count': df_org[10:]['count'].sum()}
#df_pie_org = df_pie_org.append(new_row, ignore_index = True)
fig, ax = plt.subplots(1,1)
colors = sns.color_palette("colorblind")
ax.pie(x=df_pie_org['count'],labels=df_pie_org['org'],colors=colors,autopct='%1.f%%',pctdistance=0.6,labeldistance=1.1);
ax.set_title('Distribution of top ten registered organisations')
fig.savefig(images_path+'metadataPlot_org_top_ten_pie.svg',format = 'svg',bbox_inches='tight')
fig.set_size_inches(8,8)
fig.savefig(images_path+'metadataPlot_org_top_ten_pie.png',format = 'png',dpi=2000/8,bbox_inches='tight')

# %% [markdown]
# ### 4.2 Countries

# %% [markdown]
# *Number of retrieved countries*

# %%
df_country= df_domain[["country","count"]][df_domain["country"].apply(lambda x: isinstance(x, str))].groupby(["country"]).sum().sort_values(["count"], ascending=False).reset_index()
num_unique_country= len(df_country)
print("Number of unique countries : {}".format(num_unique_country))
# Out:
# Number of unique countries : 96

# %% [markdown]
# *20 Most cited countries in the sample data*

# %%
ax = sns.barplot(x="country", y="count",data=df_country[:20])
plt.xticks(rotation=60, ha='right')
ax.set(ylabel='Number of quotations',xlabel="Registered Country")
# Out:
# [Text(0, 0.5, 'Number of quotations'), Text(0.5, 0, 'Registered Country')]

# %% [markdown]
# *As US is by far the most common origin, we remove it and plot countries again to have a better visualisation of the following countries*

# %%
df_pie_country = df_country.copy()
df_pie_country.drop(labels= df_pie_country[6:].index, axis=0,inplace=True)
new_row = {'country': 'Others', 'count': df_country[6:]['count'].sum()}
df_pie_country = df_pie_country.append(new_row, ignore_index = True)
fig, ax = plt.subplots(1,1)
colors = sns.color_palette("colorblind")
ax.pie(x=df_pie_country['count'],labels=df_pie_country['country'],colors=colors,autopct='%1.f%%',pctdistance=0.6,labeldistance=1.1);
ax.set_title('Distribution of registered country of origin')
fig.savefig(images_path+'metadataPlot_country_pie.svg',format = 'svg',bbox_inches='tight')
fig.set_size_inches(8,8)
fig.savefig(images_path+'metadataPlot_country_pie.png',format = 'png',dpi=2000/8,bbox_inches='tight')

# %%
ax = sns.barplot(x="country", y="count",data=df_country[1:20])
plt.xticks(rotation=60, ha='right')
ax.set(ylabel='Number of quotations',xlabel="Registered Country")
# Out:
# [Text(0, 0.5, 'Number of quotations'), Text(0.5, 0, 'Registered Country')]

# %% [markdown]
# ### 4.3 States

# %% [markdown]
# *Number of retrieved states*

# %%
df_state= df_domain[["state","count"]][df_domain["state"].apply(lambda x: isinstance(x, str))].groupby(["state"]).sum().sort_values(["count"], ascending=False).reset_index()
num_unique_state= len(df_state)
print("Number of unique states : {}".format(num_unique_state))
# Out:
# Number of unique states : 420

# %% [markdown]
# *20 Most cited states in the sample data*

# %%
ax = sns.barplot(x="state", y="count",data=df_state[:20])
plt.xticks(rotation=60, ha='right')
ax.set(ylabel='Number of quotations',xlabel="Registered State")
# Out:
# [Text(0, 0.5, 'Number of quotations'), Text(0.5, 0, 'Registered State')]

# %%
df_pie_state = df_state.copy()
df_pie_state.drop(labels= df_pie_state[9:].index, axis=0,inplace=True)
new_row = {'state': 'Others', 'count': df_state[9:]['count'].sum()}
df_pie_state = df_pie_state.append(new_row, ignore_index = True)
fig, ax = plt.subplots(1,1)
colors = sns.color_palette("colorblind")
ax.pie(x=df_pie_state['count'],labels=df_pie_state['state'],colors=colors,autopct='%1.f%%',pctdistance=0.6,labeldistance=1.1);
ax.set_title('Distribution of registered state of origin')
fig.savefig(images_path+'metadataPlot_state_pie.svg',format = 'svg',bbox_inches='tight')
fig.set_size_inches(8,8)
fig.savefig(images_path+'metadataPlot_state_pie.png',format = 'png',dpi=2000/8,bbox_inches='tight')

# %% [markdown]
# ### 4.4 Cities

# %% [markdown]
# *Number of retrieved citites*

# %%
df_city= df_domain[["city","count"]][df_domain["city"].apply(lambda x: isinstance(x, str))].groupby(["city"]).sum().sort_values(["count"], ascending=False).reset_index()
num_unique_city= len(df_city)
print("Number of unique cities : {}".format(num_unique_city))
# Out:
# Number of unique cities : 309

# %% [markdown]
# *20 Most cited cities in the sample data*

# %%
ax = sns.barplot(x="city", y="count",data=df_city[:20])
plt.xticks(rotation=60, ha='right')
ax.set(ylabel='Number of quotations',xlabel="Registered City")
# Out:
# [Text(0, 0.5, 'Number of quotations'), Text(0.5, 0, 'Registered City')]

# %%
df_pie_city = df_city.copy()
df_pie_city.drop(labels= df_pie_city[9:].index, axis=0,inplace=True)
new_row = {'city': 'Others', 'count': df_city[9:]['count'].sum()}
df_pie_city = df_pie_city.append(new_row, ignore_index = True)
fig, ax = plt.subplots(1,1)
colors = sns.color_palette("colorblind")
ax.pie(x=df_pie_city['count'],labels=df_pie_city['city'],colors=colors,autopct='%1.f%%',pctdistance=0.6,labeldistance=1.1);
ax.set_title('Distribution of registered city of origin')
fig.savefig(images_path+'metadataPlot_city_pie.svg',format = 'svg',bbox_inches='tight')
fig.set_size_inches(8,8)
fig.savefig(images_path+'metadataPlot_city_pie.png',format = 'png',dpi=2000/8,bbox_inches='tight')
