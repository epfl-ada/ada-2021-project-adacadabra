# %% [markdown]
# # Retrieve metadata about speakers

# %% [markdown]
# This notebook is dedicated to the retrieve of the speakers metadata. First, it uses the parquet file that was provided to retrieve extra-information (occupation, date of birth, gender, religion) on speakers.

# %% [markdown]
# ## Using provided parquet file

# %% [markdown]
# Pandas requires pyarrow to read parquet files, which can be installed using conda install pyarrow -c conda-forge.
# You can load this file as a pandas dataframe using df = pd.read_parquet(<path_to_file>).

# %% [raw]
# Schema of parquet file :
#
#     Schema:
#  |-- aliases: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- date_of_birth: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- nationality: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- gender: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- lastrevid: long (nullable = true)
#  |-- ethnic_group: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- US_congress_bio_ID: string (nullable = true)
#  |-- occupation: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- party: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- academic_degree: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- id: string (nullable = true)
#  |-- label: string (nullable = true)
#  |-- candidacy: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- type: string (nullable = true)
#  |-- religion: array (nullable = true)
#  |    |-- element: string (containsNull = true)

# %%
#importing the required modules
import seaborn as sns
from IPython.display import display, HTML
import matplotlib.pyplot as plt
import scipy.stats as stats
import pandas as pd
import numpy as np
import seaborn as sns

# %%
# Small adjustments to default style of plots, making sure it's readable and colorblind-friendly everywhere
plt.style.use('seaborn-colorblind')
plt.rcParams.update({'font.size' : 12.5,
                     'figure.figsize':(10,7)})

# %% [markdown]
# ### Import data

# %%
#Define the path for folder containing data
#TO BE MODIFIED ACCORDING HIS OWN FOLER containing data in local
path = '../ADA_project_data/'
df_metadata = pd.read_parquet(path+'speaker_attributes.parquet')
df_metadata.head()
# Out:
#   aliases date_of_birth nationality      gender   lastrevid ethnic_group  \
# 0    None          None        None  [Q6581097]   985453603         None
# 1    None          None     [Q9903]  [Q6581097]  1008699604         None
# 2    None          None     [Q9903]  [Q6581097]  1008699709         None
# 3    None          None     [Q9903]  [Q6581097]  1008699728         None
# 4    None          None     [Q9683]  [Q6581097]   985261661         None
#
#   US_congress_bio_ID occupation party academic_degree         id      label  \
# 0               None       None  None            None  Q45441526    Cui Yan
# 1               None       None  None            None  Q45441555   Guo Ziyi
# 2               None       None  None            None  Q45441562  Wan Zikui
# 3               None       None  None            None  Q45441563    Lin Pei
# 4               None       None  None            None  Q45441565  Guan Zhen
#
#   candidacy  type religion
# 0      None  item     None
# 1      None  item     None
# 2      None  item     None
# 3      None  item     None
# 4      None  item     None

# %%
#Import the dataset sample
path = '../ADA_project_data/'
#df_sample = pd.read_json(path+'Sample.json.bz2',compression = 'bz2',lines = True)
#For cleaned data 
df_sample = pd.read_json(path+'Sample_cleaned_400000.json.bz2',compression = 'bz2',lines = True)
df_sample.head()
# Out:
#              quoteID                                          quotation  \
# 0  2015-11-11-109291  They'll call me lots of different things. Libe...
# 1  2015-09-11-070666  It's kind of the same way it's been with the R...
# 2  2015-11-09-033345  I had a chuckle: They were showing a video of ...
# 3  2015-09-05-038628  New Zealand will go in with a lot of confidenc...
# 4  2015-02-11-042325  In his suicide note he even made a joke thanki...
#
#            speaker                                        qids  \
# 0   Chris Christie                                    [Q63879]
# 1  Niklas Kronwall                                   [Q722939]
# 2      Kris Draper                                   [Q948695]
# 3       John Eales                                   [Q926351]
# 4      Pat Buckley  [Q19956564, Q23006312, Q7143252, Q7143253]
#
#                  date  numOccurrences  \
# 0 2015-11-11 00:55:12               1
# 1 2015-09-11 19:54:00               1
# 2 2015-11-09 00:57:45               3
# 3 2015-09-05 02:40:10               3
# 4 2015-02-11 09:59:09               1
#
#                                               probas  \
# 0  [[Chris Christie, 0.7395], [Bobby Jindal, 0.15...
# 1  [[Niklas Kronwall, 0.7119], [None, 0.2067], [H...
# 2  [[Kris Draper, 0.8782], [None, 0.1043], [Serge...
# 3  [[John Eales, 0.7896], [None, 0.2006], [Toutai...
# 4            [[Pat Buckley, 0.8816], [None, 0.1184]]
#
#                                                 urls phase      p1      p2  \
# 0  [http://thehill.com/blogs/ballot-box/259760-ch...     E  0.7395  0.1505
# 1  [http://redwings.nhl.com/club/news.htm?id=7787...     E  0.7119  0.2067
# 2  [http://ca.rd.yahoo.com/sports/rss/nfl/SIG=13u...     E  0.8782  0.1043
# 3  [http://www.stuff.co.nz/sport/rugby/all-blacks...     E  0.7896  0.2006
# 4  [http://independent.ie/life/health-wellbeing/m...     E  0.8816  0.1184
#
#    delta_p  year
# 0   0.5890  2015
# 1   0.5052  2015
# 2   0.7739  2015
# 3   0.5890  2015
# 4   0.7632  2015

# %% [markdown]
# ### How to tranlate items into meanings name ?

# %% [markdown]
# Understanding items
# Items and their data are interconnected
#
# In Wikidata, items are used to represent all the things in human knowledge, including topics, concepts, and objects. For example, the "1988 Summer Olympics", "love", "Elvis Presley", and "gorilla" are all items in Wikidata.

# %% [markdown]
# #### Importing the sample to join metadata with quotations :

# %% [markdown]
# Join quotations data with metadata :

# %%
#Create sub-sample to group the same authors togethers
#df_sub = df_sample.sample(int(5*10e3))
df_sub = df_sample.copy()
s1 = len(df_sub)

#For the moment, choose rows which at minimum 1 qid associated
#Remove this row when using the data that have been wrangled
df_sub = df_sub[[len(a)>0 for a in df_sub['qids']]]

s2 = len(df_sub)

print('There is {} % of rows that have no qid associated with'.format((1-s2/s1)*100))
df_sub['qid_unique'] = df_sub['qids'].apply(lambda x: x[0]) 
df_sub['qid_unique']
# Out:
# There is 0.0 % of rows that have no qid associated with
# 0            Q63879
# 1           Q722939
# 2           Q948695
# 3           Q926351
# 4         Q19956564
#             ...
# 213352    Q42212234
# 213353      Q464312
# 213354     Q6524549
# 213355     Q1444739
# 213356    Q18097882
# Name: qid_unique, Length: 213357, dtype: object

# %%
#Group quotation by speaker

df_grouped=df_sub.groupby('qid_unique') \
['quoteID'] \
.count() \
.reset_index(name='count') \
.sort_values(['count'], ascending=False) 

df_grouped.head(20)

#Interesting to note that there is the same speaker called the by different ways (e.g : Donald Trump and President Trump)

#for speaker, quotation in df_group:
#    print('Speaker : ', speaker)
#    print('Quotations', quotation)
# Out:
#       qid_unique  count
# 31053     Q22686   1312
# 84803        Q76   1042
# 75352      Q6294    617
# 53781    Q450675    352
# 814        Q1058    316
# 48147    Q359442    309
# 25215   Q2036942    250
# 30764     Q22316    232
# 2563    Q1173911    215
# 87233     Q79983    209
# 45242    Q324546    195
# 75275   Q6288836    192
# 52957     Q43723    172
# 54378    Q457786    156
# 87594    Q816459    152
# 30432    Q221997    148
# 57      Q1017017    142
# 26304    Q207431    140
# 48347   Q3629480    137
# 88922    Q973577    136

# %%
#Merging with metadata

#df_merged = df_group.merge(df,how='inner',on='speaker',right_on='label')
df_merged = df_grouped.merge(df_metadata,how='inner',left_on='qid_unique', right_on='id').sort_values(['count'], ascending=False)
df_merged.head(10)
# Out:
#   qid_unique  count                                            aliases  \
# 0        Q76   1042  [Barack Hussein Obama II, Barack Obama II, Bar...
# 1      Q6294    617  [Hillary Rodham Clinton, Hillary Rodham, Hilla...
# 2    Q450675    352  [Jorge Mario Bergoglio, Francisco, Pope Franci...
# 3    Q359442    309                                  [Bernard Sanders]
# 4     Q22316    232          [John Forbes Kerry, Kerry, John F. Kerry]
# 5   Q1173911    215                                               None
# 6    Q324546    195                              [Marco Antonio Rubio]
# 7     Q43723    172  [Binyamin Netanyahu, Bibi, Bibi Netanyahu, Ben...
# 8    Q457786    156  [Rodrigo Roa Duterte, Rodrigo "Rody" Roa Duter...
# 9    Q221997    148  [John Ellis Bush, Bush, Jeb, John Ellis "Jeb" ...
#
#              date_of_birth   nationality      gender   lastrevid  \
# 0  [+1961-08-04T00:00:00Z]         [Q30]  [Q6581097]  1395141963
# 1  [+1947-10-26T00:00:00Z]         [Q30]  [Q6581072]  1393846565
# 2  [+1936-12-17T00:00:00Z]  [Q237, Q414]  [Q6581097]  1396054797
# 3  [+1941-09-08T00:00:00Z]         [Q30]  [Q6581097]  1392561607
# 4  [+1943-12-11T00:00:00Z]         [Q30]  [Q6581097]  1393166711
# 5  [+1933-01-21T00:00:00Z]        [Q145]  [Q6581097]  1392347409
# 6  [+1971-05-28T00:00:00Z]         [Q30]  [Q6581097]  1393345921
# 7  [+1949-10-21T00:00:00Z]        [Q801]  [Q6581097]  1391756559
# 8  [+1945-03-28T00:00:00Z]        [Q928]  [Q6581097]  1348817804
# 9  [+1953-02-11T00:00:00Z]    [Q30, Q29]  [Q6581097]  1393415091
#
#                               ethnic_group US_congress_bio_ID  \
# 0  [Q49085, Q6935055, Q12826303, Q6392846]            O000167
# 1                                     None            C001041
# 2                               [Q1056744]               None
# 3                                  [Q7325]            S000033
# 4                                     None            K000148
# 5                                     None               None
# 6                                     None            R000595
# 7                                  [Q7325]               None
# 8                               [Q1290600]               None
# 9                                     None               None
#
#                                           occupation  \
# 0    [Q82955, Q40348, Q15958642, Q28532974, Q372436]
# 1  [Q82955, Q40348, Q193391, Q36180, Q18814623, Q...
# 2  [Q63173086, Q593644, Q104050302, Q36180, Q1234...
# 3  [Q82955, Q1930187, Q154549, Q1622272, Q36180, ...
# 4  [Q82955, Q10669499, Q40348, Q193391, Q2095549,...
# 5                                           [Q33999]
# 6                                   [Q82955, Q40348]
# 7  [Q82955, Q193391, Q372436, Q47064, Q15958642, ...
# 8                                           [Q82955]
# 9     [Q806798, Q82955, Q17487600, Q1413170, Q36180]
#
#                                           party       academic_degree  \
# 0                                      [Q29552]  [Q1765120, Q1540185]
# 1                              [Q29552, Q29468]   [Q163727, Q1540185]
# 2                                          None            [Q1233889]
# 3  [Q6542163, Q29552, Q327591, Q327591, Q29552]            [Q1765120]
# 4                                      [Q29552]                  None
# 5                                          None                  None
# 6                                      [Q29468]  [Q1765120, Q1540185]
# 7                                     [Q187009]    [Q787674, Q950900]
# 8                                    [Q7140531]                  None
# 9                                      [Q29468]            [Q1765120]
#
#          id               label  \
# 0       Q76        Barack Obama
# 1     Q6294     Hillary Clinton
# 2   Q450675             Francis
# 3   Q359442      Bernie Sanders
# 4    Q22316          John Kerry
# 5  Q1173911       David Cameron
# 6   Q324546         Marco Rubio
# 7    Q43723  Benjamin Netanyahu
# 8   Q457786     Rodrigo Duterte
# 9   Q221997            Jeb Bush
#
#                                            candidacy  type  \
# 0  [Q3586671, Q45578, Q4226, Q4791768, Q17067714,...  item
# 1                                [Q699872, Q4791768]  item
# 2                                               None  item
# 3                                               None  item
# 4                                          [Q464075]  item
# 5                                               None  item
# 6                                               None  item
# 7                     [Q2917048, Q2480394, Q2689039]  item
# 8                                               None  item
# 9                                               None  item
#
#                                religion
# 0  [Q23540, Q1062789, Q960252, Q426316]
# 1                              [Q33203]
# 2                               [Q9592]
# 3                               [Q9268]
# 4                               [Q9592]
# 5                                  None
# 6                     [Q1841, Q7361618]
# 7                               [Q9268]
# 8                                  None
# 9                      [Q682443, Q1841]

# %%
#Replace label column at the first place

# shift column 'Name' to first position
first_column = df_merged.pop('label')
  
# insert column using insert(position,column_name,
# first_column) function
df_merged.insert(0, 'label', first_column)

# %%
df_merged.head(50)
# Out:
#                   label qid_unique  count  \
# 0          Barack Obama        Q76   1042
# 1       Hillary Clinton      Q6294    617
# 2               Francis    Q450675    352
# 3        Bernie Sanders    Q359442    309
# 4            John Kerry     Q22316    232
# 5         David Cameron   Q1173911    215
# 6           Marco Rubio    Q324546    195
# 7    Benjamin Netanyahu     Q43723    172
# 8       Rodrigo Duterte    Q457786    156
# 9              Jeb Bush    Q221997    148
# 10       Louis van Gaal    Q207431    140
# 11         Arun Jaitley   Q3629480    137
# 12           Joe Maddon   Q1093629    135
# 13       Vladimir Putin      Q7747    134
# 14       Will Schuester    Q348577    122
# 15          Joe Girardi   Q1186457    116
# 16     Malcolm Turnbull    Q927550    113
# 17             Tim Cook   Q1404825    110
# 18           Mike Pence     Q24313    103
# 21         LeBron James     Q36159     96
# 22            Rand Paul    Q463557     96
# 19         Pete Carroll   Q1758777     96
# 20        Jeremy Corbyn    Q291169     96
# 23      Brendan Rodgers  Q19973684     93
# 24       Kim Kardashian    Q186304     92
# 25             John Key     Q57783     91
# 26       Buck Showalter    Q921030     91
# 27          John McCain     Q10390     90
# 28       Lewis Hamilton   Q6536656     89
# 29            Elon Musk    Q317521     88
# 30          Andy Murray     Q10125     88
# 31           John Kirby  Q16136520     87
# 32       Lindsey Graham     Q22212     87
# 33         Andrew Cuomo     Q11673     86
# 34       Bill Belichick    Q720027     86
# 35        Angela Merkel       Q567     85
# 37           Chip Kelly   Q3196830     84
# 36         Rahul Gandhi     Q10218     84
# 38      Mitch McConnell    Q355522     82
# 39        Pep Guardiola    Q164038     81
# 40           Nick Saban     Q70894     81
# 41        Rajnath Singh   Q3506475     80
# 42          James Comey    Q167607     79
# 43         Clint Hurdle   Q2979333     78
# 44    Manuel Pellegrini    Q296036     78
# 47          Gary Kubiak   Q3758515     74
# 45         Paul Molitor   Q1972377     74
# 46  Mauricio Pochettino    Q313000     74
# 48         John Gibbons  Q19953474     73
# 49           Harry Reid  Q19650494     73
#
#                                               aliases  \
# 0   [Barack Hussein Obama II, Barack Obama II, Bar...
# 1   [Hillary Rodham Clinton, Hillary Rodham, Hilla...
# 2   [Jorge Mario Bergoglio, Francisco, Pope Franci...
# 3                                   [Bernard Sanders]
# 4           [John Forbes Kerry, Kerry, John F. Kerry]
# 5                                                None
# 6                               [Marco Antonio Rubio]
# 7   [Binyamin Netanyahu, Bibi, Bibi Netanyahu, Ben...
# 8   [Rodrigo Roa Duterte, Rodrigo "Rody" Roa Duter...
# 9   [John Ellis Bush, Bush, Jeb, John Ellis "Jeb" ...
# 10                   [Aloysius Paulus Maria van Gaal]
# 11                                               None
# 12       [Joseph John Maddon, Joseph John Maddon Jr.]
# 13  [Vladimir Vladimirovich Putin, Putin, Presiden...
# 14  [Anthony John Abbott, Anthony John "Tony" Abbo...
# 15                            [Joseph Elliot Girardi]
# 16                           [Malcolm Bligh Turnbull]
# 17                                               None
# 18  [Michael R. Pence, Rep. Mike Pence, Michael Pe...
# 21  [LeBron Raymone James Sr., King James, LBJ, Le...
# 22    [Randal Howard Paul, Randal Howard "Rand" Paul]
# 19                                               None
# 20                            [Jeremy Bernard Corbyn]
# 23                           [Brendan Austin Rodgers]
# 24  [Kim Kardashian West, KiKi, Keeks, Kim K, Kimb...
# 25  [John Philip Key, Sir John Philip Key, John Ph...
# 26                                               None
# 27      [John Sidney McCain III, John S. McCain, III]
# 28                                               None
# 29       [Elon Reeve Musk, Elon R. Musk, Elon R Musk]
# 30  [Andrew Murray, Andrew Barron Murray, Andy Bar...
# 31                                [John Kirby (1949)]
# 32                              [Lindsey Olin Graham]
# 33                                [Andrew Mark Cuomo]
# 34                        [William Stephen Belichick]
# 35  [Angela Dorothea Merkel, Angela Kasner, Angela...
# 37                                               None
# 36                                               None
# 38  [Addison Mitchell McConnell, Jr., Addison Mitc...
# 39  [Josep Guardiola, Josep Guardiola i Sala, Jose...
# 40                  [Nicholas Lou Saban, Saban, Nick]
# 41                       [Rajnath, Rajnath Dev Singh]
# 42  [Jim Comey, James Brien Comey, Jim Brien Comey...
# 43  [Clinton Merrick Hurdle, Clinton Merrick "Clin...
# 44                 [Manuel Luis Pellegrini Ripamonti]
# 47                                [Gary Wayne Kubiak]
# 45                                 [Paul Leo Molitor]
# 46  [Mauricio Roberto Pochettino Trassero, Maricar...
# 48                                               None
# 49                                               None
#
#                                      date_of_birth       nationality  \
# 0                          [+1961-08-04T00:00:00Z]             [Q30]
# 1                          [+1947-10-26T00:00:00Z]             [Q30]
# 2                          [+1936-12-17T00:00:00Z]      [Q237, Q414]
# 3                          [+1941-09-08T00:00:00Z]             [Q30]
# 4                          [+1943-12-11T00:00:00Z]             [Q30]
# 5                          [+1933-01-21T00:00:00Z]            [Q145]
# 6                          [+1971-05-28T00:00:00Z]             [Q30]
# 7                          [+1949-10-21T00:00:00Z]            [Q801]
# 8                          [+1945-03-28T00:00:00Z]            [Q928]
# 9                          [+1953-02-11T00:00:00Z]        [Q30, Q29]
# 10                         [+1951-08-08T00:00:00Z]          [Q29999]
# 11                         [+1952-12-28T00:00:00Z]            [Q668]
# 12                         [+1954-02-08T00:00:00Z]             [Q30]
# 13                         [+1952-10-07T00:00:00Z]    [Q15180, Q159]
# 14                         [+1957-11-04T00:00:00Z]      [Q408, Q145]
# 15                         [+1964-10-14T00:00:00Z]             [Q30]
# 16                         [+1954-10-24T00:00:00Z]            [Q408]
# 17                         [+1984-03-13T00:00:00Z]             [Q30]
# 18                         [+1959-06-07T00:00:00Z]             [Q30]
# 21                         [+1984-12-30T00:00:00Z]             [Q30]
# 22                         [+1963-01-07T00:00:00Z]             [Q30]
# 19                         [+1951-09-15T00:00:00Z]             [Q30]
# 20  [+1949-05-26T00:00:00Z, +1949-01-01T00:00:00Z]            [Q145]
# 23                         [+1996-08-09T00:00:00Z]             [Q30]
# 24                         [+1980-10-21T00:00:00Z]             [Q30]
# 25                         [+1961-08-09T00:00:00Z]            [Q664]
# 26                         [+1956-05-23T00:00:00Z]             [Q30]
# 27                         [+1936-08-29T00:00:00Z]             [Q30]
# 28                         [+1984-11-21T00:00:00Z]            [Q145]
# 29                         [+1971-06-28T00:00:00Z]  [Q258, Q16, Q30]
# 30                         [+1987-05-15T00:00:00Z]            [Q145]
# 31  [+1949-01-01T00:00:00Z, +1949-03-09T00:00:00Z]            [Q145]
# 32                         [+1955-07-09T00:00:00Z]             [Q30]
# 33                         [+1957-12-06T00:00:00Z]             [Q30]
# 34                         [+1952-04-16T00:00:00Z]             [Q30]
# 35                         [+1954-07-17T00:00:00Z]    [Q183, Q16957]
# 37                         [+1963-11-25T00:00:00Z]             [Q30]
# 36                         [+1970-06-19T00:00:00Z]            [Q668]
# 38                         [+1942-02-20T00:00:00Z]             [Q30]
# 39                         [+1971-01-18T00:00:00Z]             [Q29]
# 40                         [+1951-10-31T00:00:00Z]             [Q30]
# 41                         [+1951-07-10T00:00:00Z]            [Q668]
# 42                         [+1960-12-14T00:00:00Z]             [Q30]
# 43                         [+1957-07-30T00:00:00Z]             [Q30]
# 44                         [+1953-09-16T00:00:00Z]            [Q298]
# 47                         [+1961-08-15T00:00:00Z]             [Q30]
# 45                         [+1956-08-22T00:00:00Z]             [Q30]
# 46                         [+1972-03-02T00:00:00Z]       [Q414, Q29]
# 48                         [+1949-00-00T00:00:00Z]            [Q145]
# 49                         [+1992-06-22T00:00:00Z]            [Q145]
#
#         gender   lastrevid                                       ethnic_group  \
# 0   [Q6581097]  1395141963            [Q49085, Q6935055, Q12826303, Q6392846]
# 1   [Q6581072]  1393846565                                               None
# 2   [Q6581097]  1396054797                                         [Q1056744]
# 3   [Q6581097]  1392561607                                            [Q7325]
# 4   [Q6581097]  1393166711                                               None
# 5   [Q6581097]  1392347409                                               None
# 6   [Q6581097]  1393345921                                               None
# 7   [Q6581097]  1391756559                                            [Q7325]
# 8   [Q6581097]  1348817804                                         [Q1290600]
# 9   [Q6581097]  1393415091                                               None
# 10  [Q6581097]  1390309283                                               None
# 11  [Q6581097]  1382428033                                               None
# 12  [Q6581097]  1315755360                                               None
# 13  [Q6581097]  1395274624                                           [Q49542]
# 14  [Q6581097]  1394062431                                               None
# 15  [Q6581097]  1377618193                                               None
# 16  [Q6581097]  1388042865                                               None
# 17  [Q6581097]  1323626384                                               None
# 18  [Q6581097]  1395854609                                               None
# 21  [Q6581097]  1395492157                                           [Q49085]
# 22  [Q6581097]  1392091442                                               None
# 19  [Q6581097]  1378242166                                               None
# 20  [Q6581097]  1396097133                                               None
# 23  [Q6581097]  1374372202                                               None
# 24  [Q6581072]  1395690668  [Q2325516, Q1058496, Q1344183, Q1075293, Q3476...
# 25  [Q6581097]  1377190794                                               None
# 26  [Q6581097]  1310779521                                               None
# 27  [Q6581097]  1388502237                      [Q3476361, Q7435494, Q846570]
# 28  [Q6581097]  1392677497                                               None
# 29  [Q6581097]  1395054202                                               None
# 30  [Q6581097]  1389280297                                          [Q181634]
# 31  [Q6581097]  1380907607                                               None
# 32  [Q6581097]  1392182121                                               None
# 33  [Q6581097]  1393197828                                          [Q974693]
# 34  [Q6581097]  1377377437                                               None
# 35  [Q6581072]  1394947627                                           [Q42884]
# 37  [Q6581097]  1377670582                                               None
# 36  [Q6581097]  1348295449                                               None
# 38  [Q6581097]  1392727294                                               None
# 39  [Q6581097]  1388621526                                               None
# 40  [Q6581097]  1370052814                                               None
# 41  [Q6581097]  1382582279                                               None
# 42  [Q6581097]  1393410268                                          [Q170826]
# 43  [Q6581097]  1378097300                                               None
# 44  [Q6581097]  1387936058                                               None
# 47  [Q6581097]  1377715198                                               None
# 45  [Q6581097]  1260182616                                               None
# 46  [Q6581097]  1365925966                                               None
# 48  [Q6581097]  1392952032                                               None
# 49  [Q6581097]  1392944054                                               None
#
#    US_congress_bio_ID                                         occupation  \
# 0             O000167    [Q82955, Q40348, Q15958642, Q28532974, Q372436]
# 1             C001041  [Q82955, Q40348, Q193391, Q36180, Q18814623, Q...
# 2                None  [Q63173086, Q593644, Q104050302, Q36180, Q1234...
# 3             S000033  [Q82955, Q1930187, Q154549, Q1622272, Q36180, ...
# 4             K000148  [Q82955, Q10669499, Q40348, Q193391, Q2095549,...
# 5                None                                           [Q33999]
# 6             R000595                                   [Q82955, Q40348]
# 7                None  [Q82955, Q193391, Q372436, Q47064, Q15958642, ...
# 8                None                                           [Q82955]
# 9                None     [Q806798, Q82955, Q17487600, Q1413170, Q36180]
# 10               None                                 [Q937857, Q628099]
# 11               None                 [Q82955, Q40348, Q17221, Q7621877]
# 12               None                     [Q10871364, Q865935, Q1186921]
# 13               None  [Q82955, Q185351, Q6665249, Q18814623, Q239273...
# 14               None                                           [Q82955]
# 15               None                              [Q10871364, Q1186921]
# 16               None      [Q1930187, Q82955, Q131524, Q40348, Q2883465]
# 17               None                                        [Q11774891]
# 18            P000587                         [Q82955, Q40348, Q2722764]
# 21               None                      [Q3665646, Q28389, Q10798782]
# 22            P000603                        [Q82955, Q39631, Q12013238]
# 19               None                                        [Q19204627]
# 20               None                                [Q15627169, Q82955]
# 23               None                                        [Q10871364]
# 24               None  [Q3501317, Q512314, Q4610556, Q8246794, Q13152...
# 25               None                                  [Q82955, Q188094]
# 26               None                                        [Q10871364]
# 27            M000303  [Q82955, Q10669499, Q18814623, Q618694, Q37243...
# 28               None                                          [Q937857]
# 29               None  [Q15895020, Q205375, Q5482740, Q81096, Q131524...
# 30               None                                        [Q10833314]
# 31               None                                         [Q1028181]
# 32            G000359    [Q82955, Q19934710, Q40348, Q5177784, Q5123536]
# 33               None                                   [Q40348, Q82955]
# 34               None                                [Q41583, Q42331263]
# 35               None                [Q82955, Q169470, Q372436, Q593644]
# 37               None                                         [Q3246315]
# 36               None                                           [Q82955]
# 38            M000355        [Q82955, Q40348, Q16533, Q1450482, Q211236]
# 39               None                                 [Q937857, Q628099]
# 40               None                                        [Q19204627]
# 41               None                                  [Q82955, Q169470]
# 42               None                         [Q40348, Q1622272, Q82955]
# 43               None                                        [Q10871364]
# 44               None                                 [Q937857, Q628099]
# 47               None                              [Q19204627, Q3246315]
# 45               None                              [Q10871364, Q1186921]
# 46               None                                 [Q937857, Q628099]
# 48               None                                         [Q1281618]
# 49               None                                [Q33999, Q10798782]
#
#                                            party       academic_degree  \
# 0                                       [Q29552]  [Q1765120, Q1540185]
# 1                               [Q29552, Q29468]   [Q163727, Q1540185]
# 2                                           None            [Q1233889]
# 3   [Q6542163, Q29552, Q327591, Q327591, Q29552]            [Q1765120]
# 4                                       [Q29552]                  None
# 5                                           None                  None
# 6                                       [Q29468]  [Q1765120, Q1540185]
# 7                                      [Q187009]    [Q787674, Q950900]
# 8                                     [Q7140531]                  None
# 9                                       [Q29468]            [Q1765120]
# 10                                          None                  None
# 11                                      [Q10230]                  None
# 12                                          None                  None
# 13                   [Q79854, Q4488786, Q151469]           [Q17744738]
# 14                                     [Q241149]                  None
# 15                                          None                  None
# 16                                     [Q241149]                  None
# 17                                          None                  None
# 18                                      [Q29468]                  None
# 21                                          None                  None
# 22                                      [Q29468]             [Q913404]
# 19                                          None                  None
# 20                                       [Q9630]                  None
# 23                                          None                  None
# 24                                      [Q29552]                  None
# 25                                     [Q204716]                  None
# 26                                          None                  None
# 27                                      [Q29468]                  None
# 28                                          None                  None
# 29                                          None                  None
# 30                                          None                  None
# 31                                          None                  None
# 32                                      [Q29468]  [Q1765120, Q1540185]
# 33                                      [Q29552]            [Q1540185]
# 34                                          None                  None
# 35                             [Q49762, Q677182]             [Q849697]
# 37                                          None                  None
# 36                                      [Q10225]                  None
# 38                                      [Q29468]                  None
# 39                                          None                  None
# 40                                          None                  None
# 41                  [Q10230, Q3245961, Q2352638]                  None
# 42                                      [Q29468]                  None
# 43                                          None                  None
# 44                                          None                  None
# 47                                          None                  None
# 45                                          None                  None
# 46                                          None                  None
# 48                                          None                  None
# 49                                          None                  None
#
#            id                                          candidacy  type  \
# 0         Q76  [Q3586671, Q45578, Q4226, Q4791768, Q17067714,...  item
# 1       Q6294                                [Q699872, Q4791768]  item
# 2     Q450675                                               None  item
# 3     Q359442                                               None  item
# 4      Q22316                                          [Q464075]  item
# 5    Q1173911                                               None  item
# 6     Q324546                                               None  item
# 7      Q43723                     [Q2917048, Q2480394, Q2689039]  item
# 8     Q457786                                               None  item
# 9     Q221997                                               None  item
# 10    Q207431                                               None  item
# 11   Q3629480                                        [Q63988621]  item
# 12   Q1093629                                               None  item
# 13      Q7747           [Q19760074, Q488814, Q1505420, Q1348890]  item
# 14    Q348577                                               None  item
# 15   Q1186457                                               None  item
# 16    Q927550                                               None  item
# 17   Q1404825                                               None  item
# 18     Q24313                                               None  item
# 21     Q36159                                               None  item
# 22    Q463557                                               None  item
# 19   Q1758777                                               None  item
# 20    Q291169  [Q30173038, Q918466, Q918472, Q918503, Q428598...  item
# 23  Q19973684                                               None  item
# 24    Q186304                                               None  item
# 25     Q57783                                               None  item
# 26    Q921030                                               None  item
# 27     Q10390                                 [Q45578, Q4791860]  item
# 28   Q6536656                                               None  item
# 29    Q317521                                               None  item
# 30     Q10125                                               None  item
# 31  Q16136520                                               None  item
# 32     Q22212                                               None  item
# 33     Q11673                             [Q22023432, Q65047185]  item
# 34    Q720027                                               None  item
# 35       Q567  [Q555931, Q15062956, Q704648, Q702017, Q704641...  item
# 37   Q3196830                                               None  item
# 36     Q10218                                        [Q63988877]  item
# 38    Q355522                                               None  item
# 39    Q164038                                               None  item
# 40     Q70894                                               None  item
# 41   Q3506475                                        [Q63988874]  item
# 42    Q167607                                               None  item
# 43   Q2979333                                               None  item
# 44    Q296036                                               None  item
# 47   Q3758515                                               None  item
# 45   Q1972377                                               None  item
# 46    Q313000                                               None  item
# 48  Q19953474                                               None  item
# 49  Q19650494                                               None  item
#
#                                 religion
# 0   [Q23540, Q1062789, Q960252, Q426316]
# 1                               [Q33203]
# 2                                [Q9592]
# 3                                [Q9268]
# 4                                [Q9592]
# 5                                   None
# 6                      [Q1841, Q7361618]
# 7                                [Q9268]
# 8                                   None
# 9                       [Q682443, Q1841]
# 10                                  None
# 11                               [Q9089]
# 12                                  None
# 13                    [Q60995, Q3333484]
# 14                               [Q1841]
# 15                                  None
# 16                               [Q1841]
# 17                                  None
# 18                           [Q13631353]
# 21                                  None
# 22                             [Q178169]
# 19                                  None
# 20                                  None
# 23                                  None
# 24                               [Q5043]
# 25                                  None
# 26                                  None
# 27            [Q1351880, Q23540, Q93191]
# 28                                  None
# 29                             [Q288928]
# 30                                  None
# 31                                  None
# 32                            [Q1351880]
# 33                               [Q1841]
# 34                                  None
# 35                     [Q170111, Q75809]
# 37                                  None
# 36                               [Q9089]
# 38                            [Q1351880]
# 39                                  None
# 40                                  None
# 41                               [Q9089]
# 42                                  None
# 43                                  None
# 44                                  None
# 47                                  None
# 45                                  None
# 46                                  None
# 48                                  None
# 49                                  None

# %% [markdown]
# #### Representativity of the data

# %%
#Check the repartition of the data according several criterias 

#Plot an histogram of ages of speakers by number of quotations
df_merged['nationality'].apply(lambda x:x[0])
country = df_merged.groupby('nationality')['count'] 
country.head(20)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20508/3408920889.py in <module>
#       2
#       3 #Plot an histogram of nationalty by number of quotation
# ----> 4 df_merged['nationality'].apply(lambda x:x[0])
#
# ~\anaconda3\envs\ada\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4355         dtype: float64
#    4356         """
# -> 4357         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4358
#    4359     def _reduce(
#
# ~\anaconda3\envs\ada\lib\site-packages\pandas\core\apply.py in apply(self)
#    1041             return self.apply_str()
#    1042
# -> 1043         return self.apply_standard()
#    1044
#    1045     def agg(self):
#
# ~\anaconda3\envs\ada\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#    1097                 # List[Union[Callable[..., Any], str]]]]]"; expected
#    1098                 # "Callable[[Any], Any]"
# -> 1099                 mapped = lib.map_infer(
#    1100                     values,
#    1101                     f,  # type: ignore[arg-type]
#
# ~\anaconda3\envs\ada\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# ~\AppData\Local\Temp/ipykernel_20508/3408920889.py in <lambda>(x)
#       2
#       3 #Plot an histogram of nationalty by number of quotation
# ----> 4 df_merged['nationality'].apply(lambda x:x[0])
#
# TypeError: 'NoneType' object is not subscriptable

# %% [raw]
# #Count how many speakers has no metadata
#
#
# print('There are {} speakers'.format(len(df_merged)))
# print('{} speakers that have not metadata'.format(len(df_no_metadata)))
#
# print('There is {} % of speakers that has no metadata'.format(100*len(df_no_metadata)/len(df_merged)))
# print(df_no_metadata.sample(50))

# %% [markdown]
# ## Aditionnal metadata from Wikidata

# %% [markdown]
# Script to retrieve metedata from Quotebank entries :

# %% [raw]
# '''
# Execute this script as:
# python query_wikidata_dump.py --input <path-to-wikidata-json-dump> --output <path-to-output-json-file>
# '''
#
# import json
# import sys
# from tqdm import tqdm
# from argparse import ArgumentParser
# import gzip
#
# parser = ArgumentParser()
# parser.add_argument("--input", required=True)
# parser.add_argument("--output", required=True)
# args = parser.parse_args()
#
# # Usage:
#
#
# def main():
#     # Do not enforce encoding here since the input encoding is correct
#     with open(args.output, "w") as output_file:
#         with gzip.open(args.input, 'rb') as s_file:
#             for instance in s_file:
#                 instance = instance.decode('utf-8')
#                 instance = instance[:-2]
#                 if len(instance)==0:
#                     continue
#                 s = json.loads(instance.strip("\n"))
#
#                 if s.get("labels", {}).get("en") is not None:
#                     s["label"] = s["labels"]["en"]["value"]
#                 if s.get("labels") is not None:
#                     del s["labels"]
#                 else:
#                     continue
#
#                 # Occupation
#                 if len(s.get("claims", {}).get("P106", [])) > 0:
#                     tmp = []
#                     for v in s["claims"]["P106"]:
#                         # id: "Q123", "numeric-id": 123
#                         if (
#                             v["mainsnak"].get("datavalue", {}).get("value", {}).get("id")
#                             is not None
#                         ):
#                             tmp.append(v["mainsnak"]["datavalue"]["value"]["id"])
#                     if len(tmp) > 0:
#                         s["occupation"] = tmp
#
#                 # Gender
#                 if len(s.get("claims", {}).get("P21", [])) > 0:
#                     tmp = []
#                     for v in s["claims"]["P21"]:
#                         # id: "Q123", "numeric-id": 123
#                         if (
#                             v["mainsnak"].get("datavalue", {}).get("value", {}).get("id")
#                             is not None
#                         ):
#                             tmp.append(v["mainsnak"]["datavalue"]["value"]["id"])
#                     if len(tmp) > 0:
#                         s["gender"] = tmp
#
#                 # Country of citizenship
#                 if len(s.get("claims", {}).get("P27", [])) > 0:
#                     tmp = []
#                     for v in s["claims"]["P27"]:
#                         # id: "Q123", "numeric-id": 123
#                         if (
#                             v["mainsnak"].get("datavalue", {}).get("value", {}).get("id")
#                             is not None
#                         ):
#                             tmp.append(v["mainsnak"]["datavalue"]["value"]["id"])
#                     if len(tmp) > 0:
#                         s["nationality"] = tmp
#
#                 # Position Held
#                 if len(s.get("claims", {}).get("P39", [])) > 0:
#                     tmp = []
#                     for v in s["claims"]["P39"]:
#                         # id: "Q123", "numeric-id": 123
#                         if (
#                             v["mainsnak"].get("datavalue", {}).get("value", {}).get("id")
#                             is not None
#                         ):
#                             tmp.append(v["mainsnak"]["datavalue"]["value"]["id"])
#                     if len(tmp) > 0:
#                         s["positions_held"] = tmp
#
#                 # Date of Birth
#                 if len(s.get("claims", {}).get("P569", [])) > 0:
#                     tmp = []
#                     for v in s["claims"]["P569"]:
#                         if (
#                             v["mainsnak"].get("datavalue", {}).get("value", {}).get("time")
#                             is not None
#                         ):
#                             tmp.append(v["mainsnak"]["datavalue"]["value"]["time"])
#                     if len(tmp) > 0:
#                         s["date_of_birth"] = tmp
#
#                 # Academic Degree
#                 if len(s.get("claims", {}).get("P512", [])) > 0:
#                     tmp = []
#                     for v in s["claims"]["P512"]:
#                         if (
#                             v["mainsnak"].get("datavalue", {}).get("value", {}).get("id")
#                             is not None
#                         ):
#                             tmp.append(v["mainsnak"]["datavalue"]["value"]["id"])
#                     if len(tmp) > 0:
#                         s["academic_degree"] = tmp
#
#                 # Member of Political Party
#                 if len(s.get("claims", {}).get("P102", [])) > 0:
#                     tmp = []
#                     for v in s["claims"]["P102"]:
#                         if (
#                             v["mainsnak"].get("datavalue", {}).get("value", {}).get("id")
#                             is not None
#                         ):
#                             tmp.append(v["mainsnak"]["datavalue"]["value"]["id"])
#                     if len(tmp) > 0:
#                         s["party"] = tmp
#
#                 # Candidacy in election
#                 if len(s.get("claims", {}).get("P3602", [])) > 0:
#                     tmp = []
#                     for v in s["claims"]["P3602"]:
#                         if (
#                             v["mainsnak"].get("datavalue", {}).get("value", {}).get("id")
#                             is not None
#                         ):
#                             tmp.append(v["mainsnak"]["datavalue"]["value"]["id"])
#                     if len(tmp) > 0:
#                         s["candidacy"] = tmp
#
#                 # US Congress Bio ID
#                 # Get more information on the politicians based on the ID here: https://bioguide.congress.gov
#                 if len(s.get("claims", {}).get("P1157", [])) > 0:
#                     tmp = None
#                     for v in s["claims"]["P1157"]:
#                         if (
#                             v["mainsnak"].get("datavalue", {}).get("value")
#                             is not None
#                         ):
#                             tmp = v["mainsnak"]["datavalue"]["value"]
#                             break
#                     if tmp is not None:
#                         s["US_congress_bio_ID"] = tmp
#
#                 # Ethnic Group
#                 if len(s.get("claims", {}).get("P172", [])) > 0:
#                     tmp = []
#                     for v in s["claims"]["P172"]:
#                         if (
#                             v["mainsnak"].get("datavalue", {}).get("value", {}).get("id")
#                             is not None
#                         ):
#                             tmp.append(v["mainsnak"]["datavalue"]["value"]["id"])
#                     if len(tmp) > 0:
#                         s["ethnic_group"] = tmp
#
#                 # Religion
#                 if len(s.get("claims", {}).get("P140", [])) > 0:
#                     tmp = []
#                     for v in s["claims"]["P140"]:
#                         if (
#                             v["mainsnak"].get("datavalue", {}).get("value", {}).get("id")
#                             is not None
#                         ):
#                             tmp.append(v["mainsnak"]["datavalue"]["value"]["id"])
#                     if len(tmp) > 0:
#                         s["religion"] = tmp
#
#                 # Aliases. Removing leftovers and unnecessary attributes
#                 if len(s.get("aliases", {}).get("en", [])) > 0:
#                     s["aliases"] = [v["value"] for v in s["aliases"]["en"]]
#                 elif s.get("aliases") is not None:
#                     del s["aliases"]
#                 if s.get("descriptions") is not None:
#                     del s["descriptions"]
#                 if s.get("sitelinks") is not None:
#                     del s["sitelinks"]
#                 if s.get("claims") is not None:
#                     del s["claims"]
#
#                 output_file.write(json.dumps(s, ensure_ascii=False) + "\n")
#
# if __name__ == "__main__":
#     main()
